# %% [markdown]
# ### Pre-em

# %%
# tabular_030226

# ================
# imports
# ================

import json
from datetime import datetime, timedelta
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np

# ====================
#load data
# ====================
data_root="Module2/dataset" #make sure it the smaller dataset e.g.miniaireadidatset/dataset

# ===================
#read specific columns which are most important and clean/preprocess/create inputs
# ====================

# %%
data_root = "dataset"

# %% [markdown]
# ### Cleaning

# %%
# =========================
# 1) Participants base table (participants)
# =========================
p_participants = os.path.join(data_root, "participants.tsv")
participants = pd.read_csv(p_participants, sep="\t")


# Keep only what you need + rename into your preferred names
participants = participants[[
    "participant_id",
    "study_group",
    "recommended_split",
    "age",

]].copy()

participants = participants.rename(columns={
    "recommended_split": "Study Split",
    "age": "Age",
    "study_group": "Study Group"
})

df = participants.copy()

#if missing age use median of column
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
df["Age"] = df["Age"].fillna(df["Age"].median())

#turn study group into one hot encoding
# healthy
# pre_diabetes_lifestyle_controlled
# oral_medication_and_or_non_insulin_injectable_medication_controlled
# insulin_dependent
study_group_ohe = pd.get_dummies(
    df["Study Group"],
    prefix="study_group"
)

#one hot encoder
df = df.drop(columns=["Study Group"]).join(study_group_ohe)

# turn recommended split into one hot encoding
split_ohe = pd.get_dummies(
    df["Study Split"],
    prefix="split"
)

df = df.drop(columns=["Study Split"]).join(split_ohe)

# This is the master index
master = df.copy()

# %%
# =========================
# 2) Wearable activity (wam)
# =========================
p_wam = os.path.join(data_root, "wearable_activity_monitor", "manifest.tsv")
wam = pd.read_csv(p_wam, sep="\t")

# Column names vary
col_hr      = "average_heartrate_bpm"                 # heart rate pulse
col_oxy     = "average_oxygen_saturation_pct"         # oxygen saturation
col_pa      = "average_daily_activity"                # physical activity (note the spaces)
col_sleep   = "average_sleep_hours"                   # sleep
col_stress  = "average_stress_level"                 # stress
col_respire = "average_respiratory_rate_bpm"          # respiratory rate


keep_cols = ["participant_id"]
for c in [col_hr, col_oxy, col_pa, col_sleep, col_stress, col_respire]:
    if c in wam.columns:
        keep_cols.append(c)


wam_sub = wam[keep_cols].copy()

# Rename into the "Variable" names you were using
rename_map = {}
if col_hr in wam_sub.columns:      rename_map[col_hr] = "Heart Rate Pulse"
if col_oxy in wam_sub.columns:     rename_map[col_oxy] = "Oxygen Saturation"
if col_pa in wam_sub.columns:      rename_map[col_pa] = "Physical Activity"
if col_sleep in wam_sub.columns:   rename_map[col_sleep] = "Sleep"
if col_stress in wam_sub.columns:  rename_map[col_stress] = "Stress"
if col_respire in wam_sub.columns: rename_map[col_respire] = "Respiratory Rate"


wam_sub = wam_sub.rename(columns=rename_map)


#if none for col_hr, col_oxy, col_pa, col_sleep, col_stress use median of column
for col in ["Heart Rate Pulse", "Oxygen Saturation", "Physical Activity", "Sleep", "Stress"]:
    if col in wam_sub.columns:
        wam_sub[col] = pd.to_numeric(wam_sub[col], errors="coerce")
        wam_sub[col] = wam_sub[col].fillna(wam_sub[col].median())

#if col_respire normalise
if "Respiratory Rate" in wam_sub.columns:
    wam_sub["Respiratory Rate"] = pd.to_numeric(wam_sub["Respiratory Rate"], errors="coerce")
    x = wam_sub["Respiratory Rate"]
    denom = (x.max() - x.min())
    if pd.notna(denom) and denom != 0:
        wam_sub["Respiratory Rate"] = (x - x.min()) / denom

master = master.merge(wam_sub, on="participant_id", how="left")

# %%
# ================================
# 3) Wearable blood glucose (blood glucose)
# =================================
bloodglucose_path = os.path.join(data_root, "wearable_blood_glucose", "manifest.tsv")
bg = pd.read_csv(bloodglucose_path, sep="\t")

blood_glucose = "average_glucose_level_mg_dl" #blood glucose

keep_cols = ["participant_id"]
if blood_glucose in bg.columns:
    keep_cols.append(blood_glucose)

blood_glucose_p = bg[keep_cols].copy()

# Rename into the name
rename_map = {}
if blood_glucose in blood_glucose_p.columns:
    rename_map[blood_glucose] = "Blood Glucose"
blood_glucose_p = blood_glucose_p.rename(columns=rename_map)


#if missing use media
if "Blood Glucose" in blood_glucose_p.columns:
    blood_glucose_p["Blood Glucose"] = pd.to_numeric(blood_glucose_p["Blood Glucose"], errors="coerce")
    blood_glucose_p["Blood Glucose"] = blood_glucose_p["Blood Glucose"].fillna(
        blood_glucose_p["Blood Glucose"].median()
    )


master = master.merge(blood_glucose_p, on="participant_id", how="left")

# %%
# =========================
# 4) Cardiac ECG (ecg) -
# =========================
ecg_path = os.path.join(data_root, "cardiac_ecg", "manifest.tsv",)
ecg = pd.read_csv(ecg_path, sep="\t")

ecg_pr = "PR" #Cardiac ECG PR

keep_cols = ["participant_id"]
if ecg_pr in ecg.columns:
    keep_cols.append(ecg_pr)

ecg_p = ecg[keep_cols].copy()

rename_map = {}
if ecg_pr in ecg_p.columns:
    rename_map[ecg_pr] = "PR Interval"

ecg_p = ecg_p.rename(columns=rename_map)

#if missing use median
if "PR Interval" in ecg_p.columns:
    ecg_p["PR Interval"] = pd.to_numeric(ecg_p["PR Interval"], errors="coerce")
    ecg_p["PR Interval"] = ecg_p["PR Interval"].fillna(ecg_p["PR Interval"].median())

master = master.merge(ecg_p, on="participant_id", how="left")

# %%
# 5) Condition (condition_occurence) -
# =========================
from sklearn.preprocessing import LabelEncoder

condition_path = os.path.join(data_root, "clinical_data", "condition_occurrence.csv")
cond = pd.read_csv(condition_path)

condition_read = "condition_source_value" #condition_source_value
id_col = "person_id"

cond = cond[[id_col, condition_read]].copy()

#need to clean so gets label encoding/ gets rid of everything before comma e.g. mhoccur_rnl,Kidney problems -> Kidney Problems
cond["Condition_clean"] = (
    cond[condition_read]
    .astype(str)
    .str.split(",", n=1)
    .str[-1]
    .str.strip()
    .str.title()
)

# Drop missing/empty conditions (optional but usually sensible)
cond = cond[cond["Condition_clean"].notna() & (cond["Condition_clean"] != "")]

# (Optional) Deduplicate repeated condition entries per person
cond = cond.drop_duplicates(subset=[id_col, "Condition_clean"])

#Multi-hot encode: one column per condition
cond_ohe = pd.get_dummies(cond["Condition_clean"], prefix="cond")

cond_multi = pd.concat([cond[[id_col]].reset_index(drop=True), cond_ohe.reset_index(drop=True)], axis=1)

# Aggregate to one row per person (max turns any repeated 1s into 1)
cond_multi = cond_multi.groupby(id_col, as_index=False).max()

# Rename condition columns to remove "cond_" prefix
new_cols = {}

for c in cond_multi.columns:
    if c.startswith("cond_"):
        new_name = c.replace("cond_", "")
        new_cols[c] = new_name

cond_multi = cond_multi.rename(columns=new_cols)


# Merge into master
master = master.merge(cond_multi, left_on="participant_id", right_on=id_col, how="left").drop(columns=[id_col])

# After merge, participants with no condition rows will have NaNs in the new cond_* columns
# Convert those NaNs to 0s (recommended for ML)
cond_cols = list(new_cols.values())
master[cond_cols] = master[cond_cols].fillna(0).astype(int)

# %%
# =========================
# 6) Measurement
# =========================
p_measurement= os.path.join(data_root, "clinical_data", "measurement.csv")
measurement=pd.read_csv(p_measurement)

#Uses only column called measurement_source_value
person_col="person_id"
type_col="measurement_source_value"
value_col="value_as_number"

measurement=measurement[[person_col, type_col, value_col]].copy()

measurement[value_col]=pd.to_numeric(measurement[value_col],errors="coerce")


#Looks into HB1ac, Red Blood Cell, White Blood Cell, BMI, Glucose, Height, Cholesterol, Insulin
targets = {
    "HbA1c": ["hba1c"],          # output column name "HbA1c"
    "RBC": ["red blood cells", "rbc"],
    "WBC": ["white blood cells", "wbc"],
    "BMI": ["bmi"],
    "Glucose": ["glucose"],
    "Height": ["height"],
    "Cholesterol": ["cholesterol"],
    "Insulin": ["insulin"],
}


# Create Variable column
measurement["Variable"] = pd.NA
src = measurement[type_col].astype(str).str.lower()


for var, keys in targets.items():
    mask = False
    for k in keys:
        mask |= src.str.contains(k, na=False, regex=False)
    measurement.loc[mask, "Variable"] = var

meas = measurement.dropna(subset=["Variable"])

#Gets values from the corresponding columns that variables- HB1ac, Red Blood Cell, White Blood Cell, BMI, Glucose, Height, Cholesterol, Insulin exist
meas_agg = (
    meas
    .groupby([person_col, "Variable"], as_index=False)[value_col]
    .median()
)

meas_wide = (
    meas_agg
    .pivot(index=person_col, columns="Variable", values=value_col)
    .reset_index()
)

# If invalid use median of column for that specific variable

for var in targets.keys():
    if var in meas_wide.columns:
        meas_wide[var] = meas_wide[var].fillna(meas_wide[var].median())

# Save values into master e.g. participant 1068, HB1ac= 6 e.g. one column for each corresponding variable
master = (
    master
    .merge(meas_wide, left_on="participant_id", right_on=person_col, how="left")
    .drop(columns=[person_col])
)

# %%
# =========================
# Done: master dataframe (one row per participant)
# =========================
print("Final shape:", master.shape)
print(master.columns.tolist())
master.head()

###########################################################################################################################
# Out:
# Final shape: (1077, 56)
# ['participant_id', 'Age', 'study_group_healthy', 'study_group_insulin_dependent', 'study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled', 'study_group_pre_diabetes_lifestyle_controlled', 'split_test', 'split_train', 'split_val', 'Heart Rate Pulse', 'Oxygen Saturation', 'Physical Activity', 'Sleep', 'Stress', 'Respiratory Rate', 'Blood Glucose', 'PR Interval', 'Age-Related Macular Degeneration (Am', 'Arthritis (Joint Pain)', 'Cancer (Any Type)', 'Cataracts (In One Or Both Eyes)', 'Chronic Pulmonary (Lung) Problems (E', 'Circulation Problems (Examples: Art', "Dementia (Examples: Alzheimer'S Disea", 'Diabetic Retinopathy (In One Or Both', 'Digestive Problems (Examples: Stomach', 'Do You Use Marijuana Now?', 'Dry Eye (In One Or Both Eyes)', 'Elevated A1C Levels (Elevated Blood Sugar', 'Glaucoma (In One Or Both Eyes)', 'Hearing Impairment', 'Heart Attack', 'High Blood Cholesterol', 'High Blood Pressure', 'Kidney Problems', 'Low Blood Pressure', 'Mild Cognitive Impairment (Known As', 'Multiple Sclerosis', 'Obesity', 'Osteoporosis', 'Other Heart Issues (Examples: Pace', 'Other Neurological Conditions', "Parkinson'S Disease", 'Pre-Diabetes', 'Retinal Vascular Occlusion ("Stroke', 'Stroke', 'Type Ii Diabetes', 'Urinary Problems (Examples: Urinary T', 'BMI', 'Cholesterol', 'Glucose', 'HbA1c', 'Height', 'Insulin', 'RBC', 'WBC']
#    participant_id  Age  study_group_healthy  study_group_insulin_dependent  \
# 0            1001   69                False                          False
# 1            1002   69                 True                          False
# 2            1003   82                False                          False
# 3            1004   61                False                          False
# 4            1005   58                False                           True
#
#    study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                              False
#
#    study_group_pre_diabetes_lifestyle_controlled  split_test  split_train  \
# 0                                           True       False         True
# 1                                          False       False         True
# 2                                          False       False         True
# 3                                          False       False        False
# 4                                          False       False        False
#
#    split_val  Heart Rate Pulse  ...  Type Ii Diabetes  \
# 0      False               NaN  ...                 0
# 1      False               NaN  ...                 0
# 2      False               NaN  ...                 1
# 3       True               NaN  ...                 1
# 4       True               NaN  ...                 1
#
#    Urinary Problems (Examples: Urinary T        BMI  Cholesterol  Glucose  \
# 0                                      0  21.833562    94.341690     99.0
# 1                                      0  30.656419   133.485054     96.0
# 2                                      0  28.345187   105.112772    125.0
# 3                                      0  25.221468    59.674544    132.0
# 4                                      0  26.596278    74.956702    109.0
#
#    HbA1c  Height   Insulin   RBC   WBC
# 0    5.7   162.0  0.430782  4.40  5.01
# 1    5.6   175.2  1.153501  4.71  7.39
# 2    7.8   160.7  0.737438  4.58  7.22
# 3    7.2   174.5  0.158805  4.51  4.07
# 4    9.5   173.0  0.264992  4.91  5.06
#
# [5 rows x 56 columns]

# %% [markdown]
# ### Part A

# %%
df = master.copy()

# %%
#Part A-Train MLP Properly

##############################
#1.)
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GroupKFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
#######################################

########################################
#2.)
import os, random
SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
########################################

#--------------------------------------
# 1.) Build y from one-hot cols
#----------------------------------------
#Goal: Turn 4 one-hot target columns into a single multi-class label

target_cols = [
    "study_group_healthy",
    "study_group_pre_diabetes_lifestyle_controlled",
    "study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled",
    "study_group_insulin_dependent"
]

df[target_cols] = df[target_cols].astype(int)
print(df[target_cols].sum(axis=1).value_counts())

class_names = ["healthy", "prediabetes", "oral_medicated", "insulin_dependent"]

row_sums = df[target_cols].sum(axis=1)
print(row_sums.value_counts())
print("Bad rows (sum!=1):", (row_sums != 1).sum())

##########################

print("just before split section df columns (n):", df.shape[1])
print(df.columns.tolist())

#---------------------------
# 2.) Train/Val/Test Split use provided splits
#---------------------------
#Goal: Build feature matrices and class labels using the datasets pre made split columns

train_df = df[df["split_train"] == 1].copy()
val_df   = df[df["split_val"] == 1].copy()
test_df  = df[df["split_test"] == 1].copy()

#removing the target one-hot columns
drop_cols = target_cols + ["participant_id", "recommended_split", "split_train", "split_val", "split_test"]

#c is each column name, only include in the dataframe
X_train = train_df.drop(columns=[c for c in drop_cols if c in train_df.columns]).copy()
y_train = train_df[target_cols].values.argmax(axis=1)

# Make groups aligned with X_train rows
groups_train = train_df.loc[X_train.index, "participant_id"].to_numpy()

X_val = val_df.drop(columns=[c for c in drop_cols if c in val_df.columns]).copy()
y_val = val_df[target_cols].values.argmax(axis=1)

X_test = test_df.drop(columns=[c for c in drop_cols if c in test_df.columns]).copy()
y_test = test_df[target_cols].values.argmax(axis=1)

##############################

#----------------------------------
# 3.) Preprocessor
#------------------------------------
numeric_features = X_train.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = X_train.select_dtypes(exclude=[np.number]).columns.tolist()

print("X_train columns:", X_train.columns.tolist())
print("numeric_features (count):", len(numeric_features))
print("first numeric:", numeric_features[:20])
print("categorical_features (count):", len(categorical_features))
print("first categorical:", categorical_features[:20])

numeric_pipe = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_pipe = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_pipe, numeric_features),
        ("cat", categorical_pipe, categorical_features),
    ],
    remainder="drop"
)

#Scales numeric columns, one-hot encodes categorical columns, handles missing values
X_train_p = preprocessor.fit_transform(X_train)
X_val_p   = preprocessor.transform(X_val)
X_test_p  = preprocessor.transform(X_test)

#densify if sparse
#checks if its a sparse matrix
X_train_p = X_train_p.toarray() if hasattr(X_train_p, "toarray") else X_train_p
X_val_p   = X_val_p.toarray()   if hasattr(X_val_p, "toarray")   else X_val_p
X_test_p  = X_test_p.toarray()  if hasattr(X_test_p, "toarray")  else X_test_p

# capped class weights
classes = np.unique(y_train)
weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_train)
final_cw = dict(zip(classes, weights))
final_cw = {k: float(min(v, 6.0)) for k, v in final_cw.items()}

print("Train y bincount:", np.bincount(y_train, minlength=4))
print("Train one-hot sums:", train_df[target_cols].sum().to_dict())
#########################


#-----------------------
# 4.) MLP Builder
#------------------------
#Build and train the MLP

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization

import tensorflow as tf

def sparse_focal_loss(gamma=4):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)

        # convert to one-hot
        y_true_onehot = tf.one_hot(y_true, depth=4)

        # numerical stability
        epsilon = 1e-7
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)

        # cross entropy
        ce = -y_true_onehot * tf.math.log(y_pred)

        # focal scaling
        weight = tf.pow(1 - y_pred, gamma)

        fl = weight * ce

        return tf.reduce_sum(fl, axis=1)

    return loss

def build_mlp(n_in, n_out=4, lr=1e-3):
    model = Sequential([
        Input(shape=(n_in,)),
        Dense(256, activation="relu"),
        BatchNormalization(),
        Dropout(0.3),

        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.3),

        Dense(64, activation="relu"),
        BatchNormalization(),
        Dropout(0.2),

        Dense(n_out, activation="softmax")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=sparse_focal_loss(gamma=2.5),
        metrics=["accuracy"]
    )

    return model

mlp = build_mlp(n_in=X_train_p.shape[1], n_out=4)

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(
    monitor="val_loss", mode="min",
    patience=25, restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5,
    patience=5, min_lr=1e-5
)

mlp.fit(
    X_train_p, y_train,
    validation_data=(X_val_p, y_val),
    epochs=50,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
###########################


#--------------------------
# 5.) GroupKFold CV
#--------------------------
#Goal: Estimate performance robustly while precenting leakage between related samples

gkf = GroupKFold(n_splits=5)

fold_acc, fold_f1 = [], []

for fold, (tr_idx, va_idx) in enumerate(gkf.split(X_train, y_train, groups=groups_train), start=1):

    X_tr, X_va = X_train.iloc[tr_idx], X_train.iloc[va_idx]
    y_tr, y_va = y_train[tr_idx], y_train[va_idx]

    # Fit preprocessor on X_tr only
    X_tr_p = preprocessor.fit_transform(X_tr)
    X_va_p = preprocessor.transform(X_va)

    X_tr_p = X_tr_p.toarray() if hasattr(X_tr_p, "toarray") else X_tr_p
    X_va_p = X_va_p.toarray() if hasattr(X_va_p, "toarray") else X_va_p

    classes = np.unique(y_tr)
    weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_tr)
    final_cw = dict(zip(classes, weights))

    # cap weights
    final_cw = {k: float(min(v, 4.5)) for k, v in final_cw.items()}
    print("class_weight:", final_cw)

    mlp = build_mlp(n_in=X_tr_p.shape[1], n_out=4)
    early_stop = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

    mlp.fit(X_tr_p, y_tr, class_weight=final_cw, validation_data=(X_va_p, y_va), epochs=200, batch_size=32,
            callbacks=[early_stop, reduce_lr], verbose=0)

    probs = mlp.predict(X_va_p, verbose=0)

    for t in [0.20, 0.25, 0.30, 0.35]:
        y_pred = np.argmax(probs, axis=1)
        y_pred[probs[:, 3] > t] = 3

        from sklearn.metrics import recall_score
        recall_ins = recall_score(y_va, y_pred, labels=[3], average=None)[0]
        print(f"Threshold {t} → Insulin Recall: {recall_ins:.3f}")

    # pick ONE threshold to score fold metrics (example: fixed at 0.25)
    t = 0.3
    y_pred = np.argmax(probs, axis=1)
    y_pred[probs[:, 3] > t] = 3

    fold_acc.append(accuracy_score(y_va, y_pred))
    fold_f1.append(f1_score(y_va, y_pred, average="weighted"))

    from sklearn.metrics import precision_score, recall_score, f1_score

    probs = mlp.predict(X_va_p, verbose=0)

    for t in [0.20, 0.25, 0.30, 0.35]:
        y_pred = np.argmax(probs, axis=1)
        y_pred[probs[:, 3] > t] = 3

        prec = precision_score(y_va, y_pred, labels=[3], average=None)[0]
        rec  = recall_score(y_va, y_pred, labels=[3], average=None)[0]
        f1   = f1_score(y_va, y_pred, labels=[3], average=None)[0]

        print(f"t={t:.2f}  insulin P={prec:.3f} R={rec:.3f} F1={f1:.3f}")


print("\n=== CV Summary (split_train only) ===")
print("CV Acc:", np.mean(fold_acc), "+/-", np.std(fold_acc))
print("CV F1 :", np.mean(fold_f1),  "+/-", np.std(fold_f1))
###############################


#------------------------
# 6.) Final Mode Training
#-------------------------
#Train one final model on TRAIN, tune/early-stop on VAL, then evaluate on TEST

X_train_p = preprocessor.fit_transform(X_train)
X_val_p   = preprocessor.transform(X_val)
X_test_p  = preprocessor.transform(X_test)

X_train_p = X_train_p.toarray() if hasattr(X_train_p, "toarray") else X_train_p
X_val_p   = X_val_p.toarray() if hasattr(X_val_p, "toarray") else X_val_p
X_test_p  = X_test_p.toarray() if hasattr(X_test_p, "toarray") else X_test_p

# capped class weights
classes = np.unique(y_train)
weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_train)
final_cw = dict(zip(classes, weights))
final_cw = {k: float(min(v, 6.0)) for k, v in final_cw.items()}


#final_mlp = build_mlp(n_in=X_train_p.shape[1], n_out=4, seed=123)
final_mlp = build_mlp(n_in=X_train_p.shape[1], n_out=4)

early_stop = EarlyStopping(monitor="val_accuracy", mode="max", patience=15, restore_best_weights=True)
reduce_lr  = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-5)

final_mlp.fit(
    X_train_p, y_train,
    validation_data=(X_val_p, y_val),
    epochs=200,
    batch_size=32,
    callbacks=[early_stop, reduce_lr],
    class_weight=final_cw,
    verbose=0
)

y_test_pred = final_mlp.predict(X_test_p, verbose=0).argmax(axis=1)
print("Pred counts:", np.bincount(y_test_pred, minlength=4))
print("True counts:", np.bincount(y_test, minlength=4))

# ---------------------------
# 6.1 ) Extra of saving
# ---------------------------
import joblib
import os

os.makedirs("artifacts", exist_ok=True)

# 1) Save the fitted preprocessor (VERY IMPORTANT)
joblib.dump(preprocessor, "artifacts/preprocessor.joblib")

# 2) Save class_names (optional, but nice)
joblib.dump(class_names, "artifacts/class_names.joblib")

# 3) Save model weights
final_mlp.save_weights("artifacts/final_mlp.weights.h5")

print("Saved: preprocessor + model weights to artifacts/")

# ----------------------------
# 7) Held-out test evaluation
# ----------------------------
#Goal: Evaluate once on TEST (data the model never saw during training or early stopping)

y_test_pred = final_mlp.predict(X_test_p, verbose=0).argmax(axis=1)

test_acc = accuracy_score(y_test, y_test_pred)
test_f1  = f1_score(y_test, y_test_pred, average="weighted")

print("\n=== Final Held-out Test Results ===")
print(f"Test Accuracy: {test_acc:.3f}")
print(f"Test W-F1:     {test_f1:.3f}")
print(classification_report(y_test, y_test_pred, target_names=class_names, digits=3))

cm = confusion_matrix(y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(values_format="d", xticks_rotation=45)
plt.title("Confusion Matrix (Test)")
plt.show()
##################################
# Out:
# 1    1077
# Name: count, dtype: int64
# 1    1077
# Name: count, dtype: int64
# Bad rows (sum!=1): 0
# just before split section df columns (n): 56
# ['participant_id', 'Age', 'study_group_healthy', 'study_group_insulin_dependent', 'study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled', 'study_group_pre_diabetes_lifestyle_controlled', 'split_test', 'split_train', 'split_val', 'Heart Rate Pulse', 'Oxygen Saturation', 'Physical Activity', 'Sleep', 'Stress', 'Respiratory Rate', 'Blood Glucose', 'PR Interval', 'Age-Related Macular Degeneration (Am', 'Arthritis (Joint Pain)', 'Cancer (Any Type)', 'Cataracts (In One Or Both Eyes)', 'Chronic Pulmonary (Lung) Problems (E', 'Circulation Problems (Examples: Art', "Dementia (Examples: Alzheimer'S Disea", 'Diabetic Retinopathy (In One Or Both', 'Digestive Problems (Examples: Stomach', 'Do You Use Marijuana Now?', 'Dry Eye (In One Or Both Eyes)', 'Elevated A1C Levels (Elevated Blood Sugar', 'Glaucoma (In One Or Both Eyes)', 'Hearing Impairment', 'Heart Attack', 'High Blood Cholesterol', 'High Blood Pressure', 'Kidney Problems', 'Low Blood Pressure', 'Mild Cognitive Impairment (Known As', 'Multiple Sclerosis', 'Obesity', 'Osteoporosis', 'Other Heart Issues (Examples: Pace', 'Other Neurological Conditions', "Parkinson'S Disease", 'Pre-Diabetes', 'Retinal Vascular Occlusion ("Stroke', 'Stroke', 'Type Ii Diabetes', 'Urinary Problems (Examples: Urinary T', 'BMI', 'Cholesterol', 'Glucose', 'HbA1c', 'Height', 'Insulin', 'RBC', 'WBC']
# X_train columns: ['Age', 'Heart Rate Pulse', 'Oxygen Saturation', 'Physical Activity', 'Sleep', 'Stress', 'Respiratory Rate', 'Blood Glucose', 'PR Interval', 'Age-Related Macular Degeneration (Am', 'Arthritis (Joint Pain)', 'Cancer (Any Type)', 'Cataracts (In One Or Both Eyes)', 'Chronic Pulmonary (Lung) Problems (E', 'Circulation Problems (Examples: Art', "Dementia (Examples: Alzheimer'S Disea", 'Diabetic Retinopathy (In One Or Both', 'Digestive Problems (Examples: Stomach', 'Do You Use Marijuana Now?', 'Dry Eye (In One Or Both Eyes)', 'Elevated A1C Levels (Elevated Blood Sugar', 'Glaucoma (In One Or Both Eyes)', 'Hearing Impairment', 'Heart Attack', 'High Blood Cholesterol', 'High Blood Pressure', 'Kidney Problems', 'Low Blood Pressure', 'Mild Cognitive Impairment (Known As', 'Multiple Sclerosis', 'Obesity', 'Osteoporosis', 'Other Heart Issues (Examples: Pace', 'Other Neurological Conditions', "Parkinson'S Disease", 'Pre-Diabetes', 'Retinal Vascular Occlusion ("Stroke', 'Stroke', 'Type Ii Diabetes', 'Urinary Problems (Examples: Urinary T', 'BMI', 'Cholesterol', 'Glucose', 'HbA1c', 'Height', 'Insulin', 'RBC', 'WBC']
# numeric_features (count): 48
# first numeric: ['Age', 'Heart Rate Pulse', 'Oxygen Saturation', 'Physical Activity', 'Sleep', 'Stress', 'Respiratory Rate', 'Blood Glucose', 'PR Interval', 'Age-Related Macular Degeneration (Am', 'Arthritis (Joint Pain)', 'Cancer (Any Type)', 'Cataracts (In One Or Both Eyes)', 'Chronic Pulmonary (Lung) Problems (E', 'Circulation Problems (Examples: Art', "Dementia (Examples: Alzheimer'S Disea", 'Diabetic Retinopathy (In One Or Both', 'Digestive Problems (Examples: Stomach', 'Do You Use Marijuana Now?', 'Dry Eye (In One Or Both Eyes)']
# categorical_features (count): 0
# first categorical: []
# Train y bincount: [295 164 238  58]
# Train one-hot sums: {'study_group_healthy': 295, 'study_group_pre_diabetes_lifestyle_controlled': 164, 'study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled': 238, 'study_group_insulin_dependent': 58}
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 0.3868 - loss: 1.1380 - val_accuracy: 0.6087 - val_loss: 0.4509
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6596 - loss: 0.5172 - val_accuracy: 0.6646 - val_loss: 0.3948
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7113 - loss: 0.3752 - val_accuracy: 0.6770 - val_loss: 0.3501
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7470 - loss: 0.3353 - val_accuracy: 0.6522 - val_loss: 0.3352
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7510 - loss: 0.2885 - val_accuracy: 0.6832 - val_loss: 0.3181
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7775 - loss: 0.2063 - val_accuracy: 0.7019 - val_loss: 0.3040
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7934 - loss: 0.2331 - val_accuracy: 0.7143 - val_loss: 0.2873
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8556 - loss: 0.1464 - val_accuracy: 0.7205 - val_loss: 0.2727
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8225 - loss: 0.1506 - val_accuracy: 0.7143 - val_loss: 0.2687
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8212 - loss: 0.1610 - val_accuracy: 0.7267 - val_loss: 0.2779
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8477 - loss: 0.1239 - val_accuracy: 0.7205 - val_loss: 0.2807
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8384 - loss: 0.1251 - val_accuracy: 0.7267 - val_loss: 0.2949
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8795 - loss: 0.0964 - val_accuracy: 0.7143 - val_loss: 0.2817
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8543 - loss: 0.1222 - val_accuracy: 0.7019 - val_loss: 0.2890
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8689 - loss: 0.1272 - val_accuracy: 0.7143 - val_loss: 0.3015
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8768 - loss: 0.1032 - val_accuracy: 0.6957 - val_loss: 0.3229
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8742 - loss: 0.1004 - val_accuracy: 0.7143 - val_loss: 0.3014
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8715 - loss: 0.0929 - val_accuracy: 0.7019 - val_loss: 0.3026
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8927 - loss: 0.0802 - val_accuracy: 0.6832 - val_loss: 0.3145
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9152 - loss: 0.0659 - val_accuracy: 0.7081 - val_loss: 0.3202
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8914 - loss: 0.0708 - val_accuracy: 0.7019 - val_loss: 0.3245
# Epoch 22/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8940 - loss: 0.0695 - val_accuracy: 0.7081 - val_loss: 0.3365
# Epoch 23/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8940 - loss: 0.0727 - val_accuracy: 0.6894 - val_loss: 0.3352
# Epoch 24/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9060 - loss: 0.0633 - val_accuracy: 0.6957 - val_loss: 0.3273
# Epoch 25/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9086 - loss: 0.0647 - val_accuracy: 0.6957 - val_loss: 0.3246
# Epoch 26/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9219 - loss: 0.0515 - val_accuracy: 0.7143 - val_loss: 0.3460
# Epoch 27/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9126 - loss: 0.0551 - val_accuracy: 0.7267 - val_loss: 0.3575
# Epoch 28/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9205 - loss: 0.0520 - val_accuracy: 0.7143 - val_loss: 0.3595
# Epoch 29/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9364 - loss: 0.0509 - val_accuracy: 0.7081 - val_loss: 0.3608
# Epoch 30/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9219 - loss: 0.0426 - val_accuracy: 0.6957 - val_loss: 0.3638
# Epoch 31/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9325 - loss: 0.0497 - val_accuracy: 0.7081 - val_loss: 0.3814
# Epoch 32/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9272 - loss: 0.0448 - val_accuracy: 0.6894 - val_loss: 0.3624
# Epoch 33/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9166 - loss: 0.0464 - val_accuracy: 0.6708 - val_loss: 0.3690
# Epoch 34/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9377 - loss: 0.0392 - val_accuracy: 0.7019 - val_loss: 0.3729
# class_weight: {np.int64(0): 0.6239669421487604, np.int64(1): 1.1984126984126984, np.int64(2): 0.7947368421052632, np.int64(3): 3.282608695652174}
# Threshold 0.2 → Insulin Recall: 0.833
# Threshold 0.25 → Insulin Recall: 0.750
# Threshold 0.3 → Insulin Recall: 0.583
# Threshold 0.35 → Insulin Recall: 0.583
# t=0.20  insulin P=0.200 R=0.833 F1=0.323
# t=0.25  insulin P=0.237 R=0.750 F1=0.360
# t=0.30  insulin P=0.250 R=0.583 F1=0.350
# t=0.35  insulin P=0.318 R=0.583 F1=0.412
# class_weight: {np.int64(0): 0.6452991452991453, np.int64(1): 1.143939393939394, np.int64(2): 0.7905759162303665, np.int64(3): 3.2127659574468086}
# Threshold 0.2 → Insulin Recall: 0.636
# Threshold 0.25 → Insulin Recall: 0.545
# Threshold 0.3 → Insulin Recall: 0.545
# Threshold 0.35 → Insulin Recall: 0.455
# t=0.20  insulin P=0.259 R=0.636 F1=0.368
# t=0.25  insulin P=0.273 R=0.545 F1=0.364
# t=0.30  insulin P=0.353 R=0.545 F1=0.429
# t=0.35  insulin P=0.357 R=0.455 F1=0.400
# class_weight: {np.int64(0): 0.6593886462882096, np.int64(1): 1.1615384615384616, np.int64(2): 0.7743589743589744, np.int64(3): 3.02}
# Threshold 0.2 → Insulin Recall: 0.875
# Threshold 0.25 → Insulin Recall: 0.750
# Threshold 0.3 → Insulin Recall: 0.625
# Threshold 0.35 → Insulin Recall: 0.500
# t=0.20  insulin P=0.109 R=0.875 F1=0.194
# t=0.25  insulin P=0.107 R=0.750 F1=0.188
# t=0.30  insulin P=0.116 R=0.625 F1=0.196
# t=0.35  insulin P=0.118 R=0.500 F1=0.190
# class_weight: {np.int64(0): 0.6239669421487604, np.int64(1): 1.143939393939394, np.int64(2): 0.8162162162162162, np.int64(3): 3.3555555555555556}
# Threshold 0.2 → Insulin Recall: 0.846
# Threshold 0.25 → Insulin Recall: 0.692
# Threshold 0.3 → Insulin Recall: 0.462
# Threshold 0.35 → Insulin Recall: 0.462
# t=0.20  insulin P=0.250 R=0.846 F1=0.386
# t=0.25  insulin P=0.265 R=0.692 F1=0.383
# t=0.30  insulin P=0.231 R=0.462 F1=0.308
# t=0.35  insulin P=0.300 R=0.462 F1=0.364
# class_weight: {np.int64(0): 0.648068669527897, np.int64(1): 1.1102941176470589, np.int64(2): 0.7905759162303665, np.int64(3): 3.4318181818181817}
# Threshold 0.2 → Insulin Recall: 0.857
# Threshold 0.25 → Insulin Recall: 0.786
# Threshold 0.3 → Insulin Recall: 0.571
# Threshold 0.35 → Insulin Recall: 0.500
# t=0.20  insulin P=0.286 R=0.857 F1=0.429
# t=0.25  insulin P=0.333 R=0.786 F1=0.468
# t=0.30  insulin P=0.348 R=0.571 F1=0.432
# t=0.35  insulin P=0.350 R=0.500 F1=0.412
#
# === CV Summary (split_train only) ===
# CV Acc: 0.7112582781456953 +/- 0.06164278822898066
# CV F1 : 0.7162617766752057 +/- 0.05515981508151553
# Pred counts: [43 38 62 18]
# True counts: [40 40 41 40]
# Saved: preprocessor + model weights to artifacts/
#
# === Final Held-out Test Results ===
# Test Accuracy: 0.671
# Test W-F1:     0.661
#                    precision    recall  f1-score   support
#
#           healthy      0.884     0.950     0.916        40
#       prediabetes      0.737     0.700     0.718        40
#    oral_medicated      0.468     0.707     0.563        41
# insulin_dependent      0.722     0.325     0.448        40
#
#          accuracy                          0.671       161
#         macro avg      0.703     0.671     0.661       161
#      weighted avg      0.701     0.671     0.661       161

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X_train_p)

plt.figure(figsize=(8,6))

scatter = plt.scatter(
    X_reduced[:, 0],
    X_reduced[:, 1],
    c=y_train,
    cmap="viridis",
    alpha=0.7
)

# Create legend entries manually
class_names = ["healthy", "prediabetes", "oral_medicated", "insulin_dependent"]
handles = []

for i in range(len(class_names)):
    handles.append(
        plt.Line2D(
            [0], [0],
            marker='o',
            color='w',
            label=class_names[i],
            markerfacecolor=scatter.cmap(scatter.norm(i)),
            markersize=8
        )
    )

plt.legend(handles=handles, title="Class")
plt.title("PCA Projection")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score

feature_names = [str(f) for f in preprocessor.get_feature_names_out()]

def class_one_vs_rest_accuracy(y_true, y_pred, class_idx):
    return accuracy_score((y_true == class_idx).astype(int), (y_pred == class_idx).astype(int))

def permutation_importance_per_class(model, X, y, class_idx, n_repeats=3, random_state=0):
    rng = np.random.default_rng(random_state)

    base_prob = model.predict(X, verbose=0)
    base_pred = base_prob.argmax(axis=1)
    base_score = class_one_vs_rest_accuracy(y, base_pred, class_idx)

    importances = np.zeros(X.shape[1], dtype=float)

    for j in range(X.shape[1]):
        drops = []
        for _ in range(n_repeats):
            Xp = X.copy()
            rng.shuffle(Xp[:, j])
            pred = model.predict(Xp, verbose=0).argmax(axis=1)
            drops.append(base_score - class_one_vs_rest_accuracy(y, pred, class_idx))
        importances[j] = np.mean(drops)

    return base_score, importances

for k, cname in enumerate(class_names):
    base, imp = permutation_importance_per_class(final_mlp, X_test_p, y_test, class_idx=k, n_repeats=3)
    top_idx = np.argsort(imp)[::-1][:20]

    print(f"\nClass: {cname} | baseline one-vs-rest acc={base:.3f}")
    for i in top_idx:
        print(f"{feature_names[i]}: {imp[i]:.5f}")
# Out:
# Class: healthy | baseline one-vs-rest acc=0.957
# num__Pre-Diabetes: 0.13872
# num__Type Ii Diabetes: 0.09731
# num__Elevated A1C Levels (Elevated Blood Sugar: 0.09317
# num__WBC: 0.00621
# num__Arthritis (Joint Pain): 0.00621
# num__Heart Rate Pulse: 0.00414
# num__Other Neurological Conditions: 0.00414
# num__Multiple Sclerosis: 0.00207
# num__Kidney Problems: 0.00207
# num__High Blood Cholesterol: 0.00207
# num__Dry Eye (In One Or Both Eyes): 0.00207
# num__Hearing Impairment: 0.00207
# num__Cataracts (In One Or Both Eyes): 0.00207
# num__Circulation Problems (Examples: Art: 0.00207
# num__Urinary Problems (Examples: Urinary T: 0.00000
# num__RBC: 0.00000
# num__Oxygen Saturation: 0.00000
# num__Age: 0.00000
# num__Respiratory Rate: 0.00000
# num__Dementia (Examples: Alzheimer'S Disea: 0.00000
#
# Class: prediabetes | baseline one-vs-rest acc=0.863
# num__Type Ii Diabetes: 0.10766
# num__Pre-Diabetes: 0.10559
# num__Elevated A1C Levels (Elevated Blood Sugar: 0.08075
# num__Diabetic Retinopathy (In One Or Both: 0.01656
# num__Digestive Problems (Examples: Stomach: 0.01242
# num__High Blood Cholesterol: 0.01242
# num__WBC: 0.01035
# num__Dry Eye (In One Or Both Eyes): 0.00621
# num__High Blood Pressure: 0.00621
# num__Cataracts (In One Or Both Eyes): 0.00414
# num__HbA1c: 0.00414
# num__Obesity: 0.00207
# num__BMI: 0.00207
# num__Chronic Pulmonary (Lung) Problems (E: 0.00207
# num__Arthritis (Joint Pain): 0.00207
# num__Do You Use Marijuana Now?: 0.00207
# num__Stress: 0.00207
# num__Glaucoma (In One Or Both Eyes): 0.00207
# num__Physical Activity: 0.00207
# num__Heart Rate Pulse: 0.00207
#
# Class: oral_medicated | baseline one-vs-rest acc=0.720
# num__Type Ii Diabetes: 0.07867
# num__Diabetic Retinopathy (In One Or Both: 0.02277
# num__BMI: 0.02070
# num__Insulin: 0.01863
# num__Stress: 0.01863
# num__PR Interval: 0.01656
# num__Glaucoma (In One Or Both Eyes): 0.01242
# num__Glucose: 0.01242
# num__Sleep: 0.01242
# num__Chronic Pulmonary (Lung) Problems (E: 0.01242
# num__Pre-Diabetes: 0.01035
# num__High Blood Pressure: 0.00828
# num__Digestive Problems (Examples: Stomach: 0.00828
# num__Stroke: 0.00828
# num__Height: 0.00828
# num__RBC: 0.00828
# num__Cataracts (In One Or Both Eyes): 0.00828
# num__HbA1c: 0.00621
# num__High Blood Cholesterol: 0.00414
# num__Do You Use Marijuana Now?: 0.00414
#
# Class: insulin_dependent | baseline one-vs-rest acc=0.801
# num__Diabetic Retinopathy (In One Or Both: 0.03106
# num__High Blood Pressure: 0.01863
# num__Cataracts (In One Or Both Eyes): 0.01449
# num__PR Interval: 0.01449
# num__Stress: 0.01449
# num__Glaucoma (In One Or Both Eyes): 0.01242
# num__BMI: 0.01035
# num__Sleep: 0.01035
# num__High Blood Cholesterol: 0.01035
# num__Cholesterol: 0.01035
# num__Chronic Pulmonary (Lung) Problems (E: 0.01035
# num__Insulin: 0.00828
# num__Physical Activity: 0.00828
# num__RBC: 0.00828
# num__Heart Attack: 0.00621
# num__Stroke: 0.00414
# num__Age-Related Macular Degeneration (Am: 0.00414
# num__Do You Use Marijuana Now?: 0.00414
# num__Obesity: 0.00414
# num__Heart Rate Pulse: 0.00414

# %% [markdown]
# ### Part B

# %%
# ============================================================
# Part B — Handling Hypothesis Questions
# ============================================================

import numpy as np
import pandas as pd
import joblib
import tensorflow as tf
from sklearn.metrics import accuracy_score

# --------------------------
# 0) Utilities
# --------------------------
def densify(X):
    return X.toarray() if hasattr(X, "toarray") else X #makes it dense

def top2_from_probs(probs_row):
    """
    Returns the indices sorted from smallest to largest
    This being healthy, prediabetes, oral-medicated and insulin
    Then reverse the array
    THen picks the secondlargest probability
    Then returns the index of the two highest probaiblity, what the top is and then the margin
    Finds the most likely class, the second most likely class, and tells you how far apart they are.
    """
    order = np.argsort(probs_row)[::-1]
    top = int(order[0])
    runner = int(order[1])
    return top, runner, float(probs_row[top]), float(probs_row[runner]), float(probs_row[top] - probs_row[runner])


def predict_one(model, preprocessor, row_df):
    if isinstance(row_df, dict):
        row_df = pd.DataFrame([row_df])
    else:
        row_df = row_df.copy()

    # force all column names to strings
    row_df.columns = row_df.columns.map(str)

    # align to exactly what the preprocessor expects
    expected_cols = list(preprocessor.feature_names_in_)
    row_df = row_df.reindex(columns=expected_cols, fill_value=np.nan)

    Xp = densify(preprocessor.transform(row_df))
    probs = model.predict(Xp, verbose=0)[0]
    top, runner, top_conf, runner_conf, margin = top2_from_probs(probs)

    return {
        "top_class": IDX_TO_LABEL[top],
        "top_conf": float(top_conf),
        "runner_class": IDX_TO_LABEL[runner],
        "runner_conf": float(runner_conf),
        "margin": float(margin),
        "probs": {IDX_TO_LABEL[i]: float(probs[i]) for i in range(len(probs))}
    }

# %%
# --------------------------
# 1) Import in the MLP weights (+ preprocessor)
# --------------------------
preprocessor = joblib.load("artifacts/preprocessor.joblib") # preprocessing
class_names  = joblib.load("artifacts/class_names.joblib")  # ["healthy","prediabetes","oral_medicated","insulin_dependent"]

# infer n_in robustly (no .toarray() error)
X1 = preprocessor.transform(X_train.iloc[:1])  # X_train from Part A
n_in = densify(X1).shape[1]

mlp_loaded = build_mlp(n_in=n_in, n_out=4)
mlp_loaded.load_weights("artifacts/final_mlp.weights.h5")
print("Loaded weights. Input dim:", n_in)
# Loads the wights
# Out:
# Loaded weights. Input dim: 48
# C:\Users\winon\venv\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# --------------------------
# 2) Apply Features (canonical feature columns = training X columns)
# --------------------------
FEATURE_COLS = X_train.columns.tolist()
print(FEATURE_COLS)
# Out:
# ['Age', 'Heart Rate Pulse', 'Oxygen Saturation', 'Physical Activity', 'Sleep', 'Stress', 'Respiratory Rate', 'Blood Glucose', 'PR Interval', 'Age-Related Macular Degeneration (Am', 'Arthritis (Joint Pain)', 'Cancer (Any Type)', 'Cataracts (In One Or Both Eyes)', 'Chronic Pulmonary (Lung) Problems (E', 'Circulation Problems (Examples: Art', "Dementia (Examples: Alzheimer'S Disea", 'Diabetic Retinopathy (In One Or Both', 'Digestive Problems (Examples: Stomach', 'Do You Use Marijuana Now?', 'Dry Eye (In One Or Both Eyes)', 'Elevated A1C Levels (Elevated Blood Sugar', 'Glaucoma (In One Or Both Eyes)', 'Hearing Impairment', 'Heart Attack', 'High Blood Cholesterol', 'High Blood Pressure', 'Kidney Problems', 'Low Blood Pressure', 'Mild Cognitive Impairment (Known As', 'Multiple Sclerosis', 'Obesity', 'Osteoporosis', 'Other Heart Issues (Examples: Pace', 'Other Neurological Conditions', "Parkinson'S Disease", 'Pre-Diabetes', 'Retinal Vascular Occlusion ("Stroke', 'Stroke', 'Type Ii Diabetes', 'Urinary Problems (Examples: Urinary T', 'BMI', 'Cholesterol', 'Glucose', 'HbA1c', 'Height', 'Insulin', 'RBC', 'WBC']

# %%
# --------------------------
# 3) Set Boundaries (uses your BOUNDARIES dict)
# --------------------------
#################################
#Boundaries

BOUNDARIES = {
    "HbA1c": (4, 6.5),
    "Heart Rate Pulse": (60, 100),
    "Oxygen Saturation": (95, 100),
    "Physical Activity": (3867, 10000),
    "Sleep": (0.29, 0.375),
    "Stress": (0, 100),
    "PR Interval": (120, 200),
    "Blood Glucose": (72, 160),
    "Age": (44, 65),
    "RBC": (3.92, 5.65),
    "WBC": (4, 11),
    "BMI": (18.5, 30),
    "Glucose": (62, 125),
    "Height": (161, 175),
    "Cholesterol": (0, 200),
    "Insulin": (0.5, 3),
    "Respiratory Rate": (0, 1),
}
#################################

def boundary_value(col, level="normal"):
    """
    Checks that the column has boundaries
    Extracts the bounds e.g. defines what is low and high
    If level is low will output lo
    If level is high will output hi
    e.g. this translate the question so low HbA1c will output <4
    """
    if col not in BOUNDARIES:
        raise KeyError(f"'{col}' not found in BOUNDARIES")
    lo, hi = BOUNDARIES[col]
    if level == "low":
        return float(lo)
    if level == "high":
        return float(hi)
    return float((lo + hi) / 2)

    # numeric vars = boundary keys present in master

numeric_query_vars = [k for k in BOUNDARIES.keys() if k in master.columns and k not in drop_cols]

condition_vars = [
    c for c in master.columns
    if c not in drop_cols
    and master[c].dropna().isin([0, 1]).all()
]

condition_vars = list(set(condition_vars))

# %%
# --------------------------
# 4.1) Create Standard Patient (midpoint of each boundary everything else 0)
# --------------------------

def is_binary_column(df, col):
    """
    Checks whether the column is a binary feature e.g. the categories
    Removes missing Values
    Makes sure Column isn't empty
    """
    vals = set(df[col].dropna().unique())
    return vals.issubset({0, 1}) and len(vals) > 0


def make_standard_patient(df_raw, feature_cols):
    """
    Baseline logic:
      - binary column (0/1) -> 0
      - numeric + boundary -> midpoint
      - numeric no boundary -> dataset median
      - otherwise -> 0
    """
    row = {}

    for col in feature_cols: #looks through the model's training column

        # If column doesn't exist in raw df
        if col not in df_raw.columns:
            row[col] = 0.0
            continue

        # 1️⃣ Binary columns → 0
        if is_binary_column(df_raw, col): #makes sure won't have any other categories
            row[col] = 0.0

        # 2️⃣ Numeric with boundary → midpoint #sets any numerical to midpoint
        elif col in BOUNDARIES:
            lo, hi = BOUNDARIES[col]
            row[col] = float((lo + hi) / 2)

        # 3️⃣ Numeric without boundary → median #makes sure there is not outlier
        elif np.issubdtype(df_raw[col].dtype, np.number):
            row[col] = float(df_raw[col].median())

        # 4️⃣ Fallback #if unsure will output 0
        else:
            row[col] = 0.0

    return pd.DataFrame([row], columns=feature_cols)

standard_patient = make_standard_patient(df, FEATURE_COLS)

print("Standard patient created.")
print(standard_patient)
# Out:
# Standard patient created.
#     Age  Heart Rate Pulse  Oxygen Saturation  Physical Activity   Sleep  \
# 0  54.5              80.0               97.5             6933.5  0.3325
#
#    Stress  Respiratory Rate  Blood Glucose  PR Interval  \
# 0    50.0               0.5          126.0        160.0
#
#    Age-Related Macular Degeneration (Am  ...  Type Ii Diabetes  \
# 0                                   0.0  ...               0.0
#
#    Urinary Problems (Examples: Urinary T    BMI  Cholesterol  Glucose  HbA1c  \
# 0                                    0.0  24.25        100.0     93.5   5.25
#
#    Height  Insulin    RBC  WBC
# 0   168.0     1.75  4.785  7.5
#
# [1 rows x 48 columns]

# %%
# --------------------------
# 4.2) Create Standard Patients (for each subgroup)
# --------------------------

def get_true_label_index(df_raw):
    # Converts the 4 on-hot columns into a single integer class label 0,1,2,3
    return df_raw[target_cols].astype(int).values.argmax(axis=1)


def make_standard_subgroup(df_sub, feature_cols):
    """
    Makes a standard patient for each class -> healthy, prediabetes, oral_medicated, insulin
    mode for binary, median for numeric.
    """
    row = {}
    for c in feature_cols:
        if c not in df_sub.columns:
            row[c] = 0.0
            continue

        s = df_sub[c]
        if is_binary_column(df_sub, c):
            # mode for binary e.g. what comes up the most
            vals = s.dropna()
            row[c] = float(vals.mode().iloc[0]) if len(vals) else 0.0
        else:
            # median for numeric e.g. adding up all the values so to find an average
            row[c] = float(pd.to_numeric(s, errors="coerce").median())
    return pd.DataFrame([row], columns=feature_cols)

def build_prototypes_by_true_group(df_raw):
    """
    Splits the dataset into true label groups
    Build prototype one per group
    So will pick only the patients fomr the TRUE class
    Creates a dictionary with healthy, prediabetes, oral_medicated, insulin_dependent

    """
    y_idx = get_true_label_index(df_raw)
    prototypes = {}

    for k, name in enumerate(class_names):
        grp = df_raw.loc[y_idx == k].copy()
        prototypes[name] = make_standard_subgroup(grp, FEATURE_COLS)

    return prototypes

prototypes = build_prototypes_by_true_group(df)
print("Standard Subgroups:", list(prototypes.keys()))
# Out:
# Standard Subgroups: ['healthy', 'prediabetes', 'oral_medicated', 'insulin_dependent']

# %%
# --------------------------
# 4.3) Predict fake patient with MLP
# --------------------------
def predict_one(model, preprocessor, row_df):
    Xp = densify(preprocessor.transform(row_df))
    probs = model.predict(Xp, verbose=0)[0]
    top, runner, top_conf, runner_conf, margin = top2_from_probs(probs)
    return {
        "probs": probs,
        "top_idx": top,
        "top_class": class_names[top],
        "top_conf": top_conf,
        "runner_class": class_names[runner],
        "runner_conf": runner_conf,
        "margin": margin,
    }

# %%
# --------------------------
# 5) Ask Question
# Mode: mixed
# Question: Does HIGH Physical Activity and Type Ii Diabetes affect likelihood of T2DM category?
# --------------------------
import random

def random_query(master, numeric_vars, condition_vars, mode="random"):
    """
    Generate a hypothesis query.
    Returns: (var1, level1, var2, level2, mode_used)
    """

    modes = ["numeric2", "cond2", "mixed", "single"] if mode == "random" else [mode]
    mode_used = random.choice(modes)

    if mode_used == "single":
        if random.random() < 0.5:
            var1 = random.choice(numeric_vars)
            level1 = random.choice(["LOW", "NORMAL", "HIGH"])
        else:
            var1 = random.choice(condition_vars)
            level1 = None

        return var1, level1, None, None, "single"

    if mode_used == "numeric2":
        var1, var2 = random.sample(numeric_vars, 2)
        level1 = random.choice(["LOW", "HIGH"])
        level2 = random.choice(["LOW", "HIGH"])
        return var1, level1, var2, level2, "numeric2"

    if mode_used == "cond2":
        var1, var2 = random.sample(condition_vars, 2)
        return var1, None, var2, None, "cond2"

    if mode_used == "mixed":
        var1 = random.choice(numeric_vars)
        var2 = random.choice(condition_vars)
        level1 = random.choice(["LOW", "HIGH"])
        return var1, level1, var2, None, "mixed"

    raise ValueError("Unknown mode")

# %%
# Generate a hypothesis
var1, level1, var2, level2, mode_used = random_query(
    master=master,
    numeric_vars=numeric_query_vars,
    condition_vars=condition_vars,
    mode="random"
)

print(var1, level1, var2, level2)
# Out:
# Cholesterol HIGH Circulation Problems (Examples: Art None

# %%
# --------------------------
# 6) Change Standard Patient columns for the hypothesis
#    HIGH Physical Activity -> set to boundary high
#    Type Ii Diabetes -> set to 1 (flag)
# --------------------------
def changes_for_var(var, level, condition_vars):
    """
    Returns the 'changes' list used by apply_changes.
    - If level is not None -> numeric boundary variable (LOW/NORMAL/HIGH)
    - Else -> binary variable, set to 1
    """
    if level is None:
        return [{"col": var, "type": "value", "value": 1.0}]
    else:
        return [{"col": var, "type": "boundary", "level": str(level).lower()}]  # expects "low/high/normal"

#fake_patient = apply_changes(standard_patient, hypothesis_changes)

# %%
# Convert variables into change instructions
changes1 = changes_for_var(var1, level1, condition_vars)

changes2 = []
if var2 is not None:
    changes2 = changes_for_var(var2, level2, condition_vars)

hypothesis_changes = changes1 + changes2

print("Hypothesis changes:", hypothesis_changes)
# Out:
# Hypothesis changes: [{'col': 'Cholesterol', 'type': 'boundary', 'level': 'high'}, {'col': 'Circulation Problems (Examples: Art', 'type': 'value', 'value': 1.0}]

# %%
# --------------------------
# 7.1) Sanity Checking Standard Patients (for each subgroup)
# --------------------------
def predict_label_and_probs(row_df):
    res = predict_one(mlp_loaded, preprocessor, row_df)
    return res["top_class"], res["top_conf"], res["probs"]

print("\nPrototype sanity check:")
for name, proto in prototypes.items():
    pred, conf, _ = predict_label_and_probs(proto)
    print(f"Prototype built from TRUE {name:>16} -> model predicts {pred:>16} (conf={conf:.2f})")
# Out:
# Prototype sanity check:
# Prototype built from TRUE          healthy -> model predicts          healthy (conf=0.88)
# Prototype built from TRUE      prediabetes -> model predicts      prediabetes (conf=0.83)
# Prototype built from TRUE   oral_medicated -> model predicts   oral_medicated (conf=0.69)
# Prototype built from TRUE insulin_dependent -> model predicts   oral_medicated (conf=0.64)

# %%
def apply_changes(patient_df, changes):
    out = patient_df.copy()
    for ch in changes:
        col = ch["col"]
        if ch.get("type") == "boundary":
            out.loc[:, col] = boundary_value(col, ch["level"])
        else:
            out.loc[:, col] = ch["value"]
    return out

# %%
# --------------------------
# 7.1) Run hypothesis on all prototypes
# --------------------------
def run_hypothesis_on_all_prototypes(prototypes, changes):
    results = []

    for group_name, proto in prototypes.items():

        base_res = predict_one(mlp_loaded, preprocessor, proto)

        changed = apply_changes(proto, changes)
        changed_res = predict_one(mlp_loaded, preprocessor, changed)

        delta = changed_res["probs"] - base_res["probs"]

        results.append({
            "subgroup": group_name,   # ← renamed here
            "baseline_pred": base_res["top_class"],
            "baseline_conf": base_res["top_conf"],
            "changed_pred": changed_res["top_class"],
            "changed_conf": changed_res["top_conf"],
            "delta_healthy": float(delta[0]),
            "delta_prediabetes": float(delta[1]),
            "delta_oral_medicated": float(delta[2]),
            "delta_insulin_dependent": float(delta[3]),
        })

    return pd.DataFrame(results)

res_df = run_hypothesis_on_all_prototypes(prototypes, hypothesis_changes)
res_df
# Out:
#             subgroup   baseline_pred  baseline_conf changed_pred  \
# 0            healthy         healthy       0.878370      healthy
# 1        prediabetes     prediabetes       0.828908  prediabetes
# 2     oral_medicated  oral_medicated       0.694402  prediabetes
# 3  insulin_dependent  oral_medicated       0.643984  prediabetes
#
#    changed_conf  delta_healthy  delta_prediabetes  delta_oral_medicated  \
# 0      0.851623      -0.026748           0.011861              0.017574
# 1      0.748127      -0.006328          -0.080780              0.096842
# 2      0.530262       0.080915           0.422232             -0.412376
# 3      0.469992       0.028448           0.415144             -0.265229
#
#    delta_insulin_dependent
# 0                -0.002687
# 1                -0.009733
# 2                -0.090771
# 3                -0.178363

# %%
# --------------------------
# 8) Find all dataset patients that fit the hypothesis
#    HIGH Physical Activity = >= upper boundary
#    Type Ii Diabetes = 1
# --------------------------
def subset_dataset(df_raw, changes):
    mask = pd.Series(True, index=df_raw.index)
    for ch in changes:
        col = ch["col"]
        if col not in df_raw.columns:
            raise KeyError(f"Column '{col}' not in df.")
        if ch.get("type") == "boundary":
            lo, hi = BOUNDARIES[col]
            if ch["level"] == "high":
                mask &= df_raw[col].astype(float) >= float(hi)
            elif ch["level"] == "low":
                mask &= df_raw[col].astype(float) <= float(lo)
            else:
                mask &= df_raw[col].astype(float).between(float(lo), float(hi), inclusive="both")
        else:
            mask &= (df_raw[col].astype(float) == float(ch["value"]))
    return df_raw[mask].copy()

sub_df = subset_dataset(df, hypothesis_changes)   # df is your full raw dataset
n_sub = len(sub_df)

# predict subgroup (if any)
if n_sub > 0:
    X_sub = sub_df[FEATURE_COLS].copy()
    X_sub_p = densify(preprocessor.transform(X_sub))
    sub_probs = mlp_loaded.predict(X_sub_p, verbose=0)
    sub_pred = sub_probs.argmax(axis=1)

    # distribution + majority
    counts = np.bincount(sub_pred, minlength=4)
    majority_idx = int(np.argmax(counts))
    majority_name = class_names[majority_idx]
    majority_share = float(counts[majority_idx] / n_sub)

    # confidence summaries
    mean_top_conf = float(np.max(sub_probs, axis=1).mean())
    order = np.argsort(sub_probs, axis=1)[:, ::-1]
    margins = sub_probs[np.arange(n_sub), order[:, 0]] - sub_probs[np.arange(n_sub), order[:, 1]]
    mean_margin = float(margins.mean())
else:
    majority_name = None
    majority_share = None
    mean_top_conf = None
    mean_margin = None

# %%
prototypes = build_prototypes_by_true_group(df)  # dict: class_name -> 1-row df

# %%
def describe_var(var, level, condition_vars):
    """
    Turn a variable + level into readable text for the question header.
    """
    if level is None:
        return str(var)
    return f"{str(level).upper()} {str(var)}"

# %%
# --------------------------
# 9) Output Sentence Block (baseline + fake + dataset)
# --------------------------


def class_distribution_text(pred_labels, class_names):
    counts = np.bincount(pred_labels, minlength=len(class_names))
    total = counts.sum()
    order = np.argsort(counts)[::-1]

    lines = []
    for idx in order:
        if counts[idx] == 0:
            continue
        pct = counts[idx] / total
        lines.append(f"{class_names[idx]}: {counts[idx]}/{total} ({pct:.1%})")

    return ", ".join(lines)


def predicted_class_condition_breakdown(all_pred, sub_pred, class_names):
    """
    For each predicted class in the full dataset:
    how many of those predicted patients fall inside the condition
    """
    total_counts = np.bincount(all_pred, minlength=len(class_names))
    sub_counts = np.bincount(sub_pred, minlength=len(class_names))

    lines = []
    for i, name in enumerate(class_names):
        total = total_counts[i]
        in_condition = sub_counts[i]
        pct = 0.0 if total == 0 else in_condition / total
        lines.append(f"{name}: {in_condition}/{total} ({pct:.1%})")
    return lines
    
def compare_independent_effects(
    df,
    var1, level1,      # example: "Physical Activity", "HIGH"
    var2, level2,      # example: "Type Ii Diabetes", None
    condition_vars,    # set of binary 0/1 columns
    preprocessor,
    mlp,
    drop_cols,
    test_acc,
    prototypes=None,
    show_joint=True
):
    # 1) Base Patient
    # -------------------------
    # QUESTION HEADER (NEW)
    # -------------------------

    X_all = df[FEATURE_COLS].copy()

    s1 = describe_var(var1, level1, set(condition_vars))

    if var2 is None:
        question_line = f"Does {s1} affect likelihood of T2DM category?"
    else:
        s2 = describe_var(var2, level2, set(condition_vars))
        question_line = f"Does {s1} AND {s2} affect likelihood of T2DM category?"
              
    
    base_patient = make_standard_patient(df, FEATURE_COLS)
    base_res = predict_one(mlp, preprocessor, base_patient)

    # 1.1) Fake Patient(Median)
    # Base fake patient (median/midpoint baseline)
    base_patient = make_standard_patient(df, FEATURE_COLS)

    # Build changes for question

    changes1 = changes_for_var(var1, level1, condition_vars)

    changes2 = []
    if var2 is not None:
        changes2 = changes_for_var(var2, level2, condition_vars)
    
    changes_joint = changes1 + changes2


    # Fake patient that matches the full question (joint)
    fake_question_patient = apply_changes(base_patient, changes_joint)
    fake_question_res = predict_one(mlp, preprocessor, fake_question_patient)

    fake_aligned = fake_question_patient.reindex(columns=base_patient.columns, fill_value=np.nan)

    changed_cols = fake_aligned.iloc[0].ne(base_patient.iloc[0])
    print("Changed columns:", list(base_patient.columns[changed_cols]))

    # 2) Changed Patient (Var1 only)
    changes1 = []
    if level1 is not None:  # var1 is numeric
        changes1.append({"col": var1, "type": "boundary", "level": level1})
    else: # var1 is binary
        changes1.append({"col": var1, "type": "value", "value": 1.0})

    patient1 = apply_changes(base_patient, changes1)
    res1 = predict_one(mlp, preprocessor, patient1)

    
    # 3) Changed Patient (Var2 only)

    res2 = None
    sub_df2 = pd.DataFrame()
    
    if var2 is not None:
        changes2 = []
        if level2 is not None:
            changes2.append({"col": var2, "type": "boundary", "level": level2})
        else:
            changes2.append({"col": var2, "type": "value", "value": 1.0})
    
        patient2 = apply_changes(base_patient, changes2)
        res2 = predict_one(mlp, preprocessor, patient2)
    
    # 4) Changed Patient (Joint)
    if show_joint:
        changes_joint = changes1 + changes2
        patient_joint = apply_changes(base_patient, changes_joint)
        res_joint = predict_one(mlp, preprocessor, patient_joint)

    # 5) Subsetting the dataset
    sub_df1 = subset_dataset(df, changes1)
    sub_df2 = subset_dataset(df, changes2)
    sub_df_joint = subset_dataset(df, changes_joint) if show_joint else pd.DataFrame()

    def get_impact_description(delta_probs):
        if abs(delta_probs) > 0.3: return "High"
        if abs(delta_probs) > 0.1: return "Moderate"
        return "Low"

    def get_confidence_description(conf):
        if conf > 0.8: return "High"
        if conf > 0.5: return "Moderate"
        return "Low"

    report = question_line
    report += f"Baseline prediction for average patient: {base_res['top_class']} (conf={base_res['top_conf']:.2f})\n\n"

    # Var1 report
    # Var1 report
    var1_desc = f"{level1 or ''} {var1}".strip()
    report += f"Effect of {var1_desc}:\n"
    report += f"  Predicted class: {res1['top_class']} (conf={res1['top_conf']:.2f})\n"
    report += f"  Delta to baseline: {get_impact_description(res1['top_conf'] - base_res['top_conf'])} ({res1['top_conf'] - base_res['top_conf']:.2f})\n"
    
    if not sub_df1.empty:
        X_sub1_p = densify(preprocessor.transform(sub_df1[FEATURE_COLS]))
        sub_pred1 = mlp.predict(X_sub1_p, verbose=0).argmax(axis=1)
    
        dist_text = class_distribution_text(sub_pred1, class_names)
        report += (
            f"  Among patients with {var1_desc} ({len(sub_df1)} patients), "
            f"the predicted class distribution is: {dist_text}.\n"
        )
    
        lines1 = predicted_class_condition_breakdown(all_pred, sub_pred1, class_names)
        report += f"  Out of all predicted patients:\n"
        for line in lines1:
            report += f"    - {line} have {var1_desc}\n"
        report += "\n"
    else:
        report += f"  No patients found in dataset with {var1_desc}.\n\n"
    


    
    # Var2 report
    # Var2 report
    if var2 is not None:
        var2_desc = f"{level2 or ''} {var2}".strip()
        report += f"Effect of {var2_desc}:\n"
        report += f"  Predicted class: {res2['top_class']} (conf={res2['top_conf']:.2f})\n"
        report += f"  Delta to baseline: {get_impact_description(res2['top_conf'] - base_res['top_conf'])} ({res2['top_conf'] - base_res['top_conf']:.2f})\n"
    
        if not sub_df2.empty:
            X_sub2_p = densify(preprocessor.transform(sub_df2[FEATURE_COLS]))
            sub_pred2 = mlp.predict(X_sub2_p, verbose=0).argmax(axis=1)
    
            dist_text = class_distribution_text(sub_pred2, class_names)
            report += (
                f"  Among patients with {var2_desc} ({len(sub_df2)} patients), "
                f"the predicted class distribution is: {dist_text}.\n"
            )
    
            lines2 = predicted_class_condition_breakdown(all_pred, sub_pred2, class_names)
            report += f"  Out of all predicted patients:\n"
            for line in lines2:
                report += f"    - {line} have {var2_desc}\n"
            report += "\n"
        else:
            report += f"  No patients found in dataset with {var2_desc}.\n\n"
            

    # Joint report
    # Joint report
    if show_joint and var2 is not None:
        joint_desc = f"{var1_desc} AND {var2_desc}"
        report += f"Combined effect of {joint_desc}:\n"
        report += f"  Predicted class: {res_joint['top_class']} (conf={res_joint['top_conf']:.2f})\n"
        report += f"  Delta to baseline: {get_impact_description(res_joint['top_conf'] - base_res['top_conf'])} ({res_joint['top_conf'] - base_res['top_conf']:.2f})\n"
    
        if not sub_df_joint.empty:
            X_sub_joint_p = densify(preprocessor.transform(sub_df_joint[FEATURE_COLS]))
            sub_pred_joint = mlp.predict(X_sub_joint_p, verbose=0).argmax(axis=1)
    
            dist_text = class_distribution_text(sub_pred_joint, class_names)
            report += (
                f"  Among patients with {joint_desc} ({len(sub_df_joint)} patients), "
                f"the predicted class distribution is: {dist_text}.\n"
            )
    
            lines_joint = predicted_class_condition_breakdown(all_pred, sub_pred_joint, class_names)
            report += f"  Out of all predicted patients:\n"
            for line in lines_joint:
                report += f"    - {line} have {joint_desc}\n"
            report += "\n"
        else:
            report += f"  No patients found in dataset with {joint_desc}.\n\n"

    
    # -------------------------
    # Subgroup prototype fake patients (NEW)
    # -------------------------
    if prototypes is not None:
        report += "Fake patients by TRUE subgroup (before → after applying question):\n"

        for true_group_name, proto in prototypes.items():
            base_p = predict_one(mlp, preprocessor, proto)

            changed_proto = apply_changes(proto, changes_joint)
            changed_p = predict_one(mlp, preprocessor, changed_proto)

            report += (
                f"  - Prototype TRUE {true_group_name}: "
                f"{base_p['top_class']} ({base_p['top_conf']:.2f}) → "
                f"{changed_p['top_class']} ({changed_p['top_conf']:.2f}) "
                f"[Δhealthy={changed_p['probs'][0]-base_p['probs'][0]:+.2f}, "
                f"Δpred={changed_p['probs'][1]-base_p['probs'][1]:+.2f}, "
                f"Δoral={changed_p['probs'][2]-base_p['probs'][2]:+.2f}, "
                f"Δins={changed_p['probs'][3]-base_p['probs'][3]:+.2f}]"
                "\n"
            )

        report += "\n"

    
    return report, base_res, fake_question_res, sub_df_joint, 5

import random
import pandas as pd
import json

def run_n_random_questions(
    master,
    numeric_vars,
    condition_vars,
    preprocessor, mlp, drop_cols,
    test_acc,
    n=5,
    mode="random",
    show_joint=True,
    seed=10,
):
    random.seed(seed)

    results = []

    # force at least 2 single-variable questions
    mode_plan = ["single", "single"] + ["random"] * (n - 2)
    random.shuffle(mode_plan)

    for i in range(1, n + 1):
        chosen_mode = mode_plan[i - 1]

        var1, level1, var2, level2, mode_used = random_query(
            master=master,
            numeric_vars=numeric_vars,
            condition_vars=condition_vars,
            mode=chosen_mode
        )

        s1 = describe_var(var1, level1, set(condition_vars))

        if var2 is None:
            question_text = f"Does {s1} affect likelihood of T2DM category?"
        else:
            s2 = describe_var(var2, level2, set(condition_vars))
            question_text = f"Does {s1} AND {s2} affect likelihood of T2DM category?"

        report, base_res, fake_question_res, sub_df_joint, extra_val = compare_independent_effects(
            df=master,
            var1=var1, level1=level1,
            var2=var2, level2=level2,
            condition_vars=set(condition_vars),
            preprocessor=preprocessor,
            mlp=mlp,
            drop_cols=drop_cols,
            test_acc=test_acc,
            show_joint=show_joint,
            prototypes=prototypes
        )

        results.append({
            "run_id": i,
            "mode_used": mode_used,
            "var1": var1,
            "level1": level1,
            "var2": var2,
            "level2": level2,
            "question_text": question_text,
            "report": report,
            "baseline_top_class": base_res["top_class"],
            "baseline_top_conf": base_res["top_conf"],
            "fake_top_class": fake_question_res["top_class"],
            "fake_top_conf": fake_question_res["top_conf"],
            "runner_up_class": fake_question_res["runner_class"],
            "margin": fake_question_res["margin"],
            "subset_joint_size": len(sub_df_joint) if sub_df_joint is not None else 0
        })

    return results
    
results = run_n_random_questions(
    master=master,
    numeric_vars=numeric_query_vars,
    condition_vars=condition_vars,
    preprocessor=preprocessor,
    mlp=mlp_loaded,
    drop_cols=drop_cols,
    test_acc=test_acc,
    n=5,
    mode="random",
    show_joint=True,
    seed=10
)

for r in results:
    print("\n" + "=" * 60)
    print(f"Question {r['run_id']} | Mode={r['mode_used']}")
    print("Question:", r["question_text"])
    print()
    print(r["report"])

df_results = pd.DataFrame(results)
df_results.to_csv("random_question_results.csv", index=False)
# Out:
# Changed columns: ['PR Interval', 'Cholesterol']
# Changed columns: ['Age-Related Macular Degeneration (Am', 'Heart Attack']
# Changed columns: ['Blood Glucose']
# Changed columns: ['Sleep']
# Changed columns: ['Retinal Vascular Occlusion ("Stroke', 'Glucose']
#
# ============================================================
# Question 1 | Mode=numeric2
# Question: Does HIGH PR Interval AND HIGH Cholesterol affect likelihood of T2DM category?
#
# Does HIGH PR Interval AND HIGH Cholesterol affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH PR Interval:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH PR Interval (923 patients), the predicted class distribution is: healthy: 326/923 (35.3%), oral_medicated: 261/923 (28.3%), prediabetes: 230/923 (24.9%), insulin_dependent: 106/923 (11.5%).
#   Out of all predicted patients:
#     - healthy: 326/376 (86.7%) have HIGH PR Interval
#     - prediabetes: 230/285 (80.7%) have HIGH PR Interval
#     - oral_medicated: 261/317 (82.3%) have HIGH PR Interval
#     - insulin_dependent: 106/99 (107.1%) have HIGH PR Interval
#
# Effect of HIGH Cholesterol:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Cholesterol (1072 patients), the predicted class distribution is: healthy: 369/1072 (34.4%), oral_medicated: 312/1072 (29.1%), prediabetes: 262/1072 (24.4%), insulin_dependent: 129/1072 (12.0%).
#   Out of all predicted patients:
#     - healthy: 369/376 (98.1%) have HIGH Cholesterol
#     - prediabetes: 262/285 (91.9%) have HIGH Cholesterol
#     - oral_medicated: 312/317 (98.4%) have HIGH Cholesterol
#     - insulin_dependent: 129/99 (130.3%) have HIGH Cholesterol
#
# Combined effect of HIGH PR Interval AND HIGH Cholesterol:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH PR Interval AND HIGH Cholesterol (919 patients), the predicted class distribution is: healthy: 323/919 (35.1%), oral_medicated: 261/919 (28.4%), prediabetes: 229/919 (24.9%), insulin_dependent: 106/919 (11.5%).
#   Out of all predicted patients:
#     - healthy: 323/376 (85.9%) have HIGH PR Interval AND HIGH Cholesterol
#     - prediabetes: 229/285 (80.4%) have HIGH PR Interval AND HIGH Cholesterol
#     - oral_medicated: 261/317 (82.3%) have HIGH PR Interval AND HIGH Cholesterol
#     - insulin_dependent: 106/99 (107.1%) have HIGH PR Interval AND HIGH Cholesterol
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.88) [Δhealthy=-0.00, Δpred=+0.00, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.84) [Δhealthy=-0.00, Δpred=+0.01, Δoral=-0.00, Δins=-0.00]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.61) [Δhealthy=+0.01, Δpred=+0.08, Δoral=-0.09, Δins=+0.01]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.60) [Δhealthy=+0.01, Δpred=+0.05, Δoral=-0.05, Δins=-0.01]
#
#
#
# ============================================================
# Question 2 | Mode=cond2
# Question: Does Heart Attack AND Age-Related Macular Degeneration (Am affect likelihood of T2DM category?
#
# Does Heart Attack AND Age-Related Macular Degeneration (Am affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of Heart Attack:
#   Predicted class: healthy (conf=0.80)
#   Delta to baseline: Low (-0.08)
#   Among patients with Heart Attack (68 patients), the predicted class distribution is: oral_medicated: 32/68 (47.1%), insulin_dependent: 19/68 (27.9%), healthy: 9/68 (13.2%), prediabetes: 8/68 (11.8%).
#   Out of all predicted patients:
#     - healthy: 9/376 (2.4%) have Heart Attack
#     - prediabetes: 8/285 (2.8%) have Heart Attack
#     - oral_medicated: 32/317 (10.1%) have Heart Attack
#     - insulin_dependent: 19/99 (19.2%) have Heart Attack
#
# Effect of Age-Related Macular Degeneration (Am:
#   Predicted class: healthy (conf=0.87)
#   Delta to baseline: Low (-0.01)
#   Among patients with Age-Related Macular Degeneration (Am (60 patients), the predicted class distribution is: insulin_dependent: 18/60 (30.0%), healthy: 18/60 (30.0%), prediabetes: 14/60 (23.3%), oral_medicated: 10/60 (16.7%).
#   Out of all predicted patients:
#     - healthy: 18/376 (4.8%) have Age-Related Macular Degeneration (Am
#     - prediabetes: 14/285 (4.9%) have Age-Related Macular Degeneration (Am
#     - oral_medicated: 10/317 (3.2%) have Age-Related Macular Degeneration (Am
#     - insulin_dependent: 18/99 (18.2%) have Age-Related Macular Degeneration (Am
#
# Combined effect of Heart Attack AND Age-Related Macular Degeneration (Am:
#   Predicted class: healthy (conf=0.69)
#   Delta to baseline: Moderate (-0.19)
#   Among patients with Heart Attack AND Age-Related Macular Degeneration (Am (11 patients), the predicted class distribution is: oral_medicated: 5/11 (45.5%), insulin_dependent: 4/11 (36.4%), healthy: 2/11 (18.2%).
#   Out of all predicted patients:
#     - healthy: 2/376 (0.5%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - prediabetes: 0/285 (0.0%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - oral_medicated: 5/317 (1.6%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - insulin_dependent: 4/99 (4.0%) have Heart Attack AND Age-Related Macular Degeneration (Am
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.73) [Δhealthy=-0.15, Δpred=+0.11, Δoral=+0.03, Δins=+0.01]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.77) [Δhealthy=-0.00, Δpred=-0.06, Δoral=+0.08, Δins=-0.02]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.54) [Δhealthy=+0.04, Δpred=+0.10, Δoral=-0.16, Δins=+0.03]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.51) [Δhealthy=+0.03, Δpred=+0.08, Δoral=-0.14, Δins=+0.02]
#
#
#
# ============================================================
# Question 3 | Mode=single
# Question: Does HIGH Blood Glucose affect likelihood of T2DM category?
#
# Does HIGH Blood Glucose affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Blood Glucose:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Blood Glucose (948 patients), the predicted class distribution is: healthy: 364/948 (38.4%), oral_medicated: 258/948 (27.2%), prediabetes: 253/948 (26.7%), insulin_dependent: 73/948 (7.7%).
#   Out of all predicted patients:
#     - healthy: 364/376 (96.8%) have HIGH Blood Glucose
#     - prediabetes: 253/285 (88.8%) have HIGH Blood Glucose
#     - oral_medicated: 258/317 (81.4%) have HIGH Blood Glucose
#     - insulin_dependent: 73/99 (73.7%) have HIGH Blood Glucose
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.87) [Δhealthy=-0.01, Δpred=+0.01, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.83) [Δhealthy=-0.00, Δpred=-0.00, Δoral=-0.00, Δins=+0.00]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.67) [Δhealthy=+0.01, Δpred=+0.02, Δoral=-0.02, Δins=+0.00]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.58) [Δhealthy=+0.00, Δpred=+0.02, Δoral=-0.06, Δins=+0.04]
#
#
#
# ============================================================
# Question 4 | Mode=single
# Question: Does HIGH Sleep affect likelihood of T2DM category?
#
# Does HIGH Sleep affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Sleep:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Sleep (328 patients), the predicted class distribution is: healthy: 116/328 (35.4%), oral_medicated: 106/328 (32.3%), prediabetes: 78/328 (23.8%), insulin_dependent: 28/328 (8.5%).
#   Out of all predicted patients:
#     - healthy: 116/376 (30.9%) have HIGH Sleep
#     - prediabetes: 78/285 (27.4%) have HIGH Sleep
#     - oral_medicated: 106/317 (33.4%) have HIGH Sleep
#     - insulin_dependent: 28/99 (28.3%) have HIGH Sleep
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.88) [Δhealthy=-0.00, Δpred=-0.00, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.82) [Δhealthy=+0.00, Δpred=-0.01, Δoral=+0.00, Δins=+0.01]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.68) [Δhealthy=+0.00, Δpred=+0.02, Δoral=-0.01, Δins=-0.01]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.62) [Δhealthy=+0.00, Δpred=+0.01, Δoral=-0.02, Δins=+0.01]
#
#
#
# ============================================================
# Question 5 | Mode=mixed
# Question: Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect likelihood of T2DM category?
#
# Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Glucose:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Glucose (870 patients), the predicted class distribution is: healthy: 354/870 (40.7%), prediabetes: 245/870 (28.2%), oral_medicated: 208/870 (23.9%), insulin_dependent: 63/870 (7.2%).
#   Out of all predicted patients:
#     - healthy: 354/376 (94.1%) have HIGH Glucose
#     - prediabetes: 245/285 (86.0%) have HIGH Glucose
#     - oral_medicated: 208/317 (65.6%) have HIGH Glucose
#     - insulin_dependent: 63/99 (63.6%) have HIGH Glucose
#
# Effect of Retinal Vascular Occlusion ("Stroke:
#   Predicted class: prediabetes (conf=0.55)
#   Delta to baseline: High (-0.33)
#   Among patients with Retinal Vascular Occlusion ("Stroke (15 patients), the predicted class distribution is: insulin_dependent: 7/15 (46.7%), prediabetes: 3/15 (20.0%), healthy: 3/15 (20.0%), oral_medicated: 2/15 (13.3%).
#   Out of all predicted patients:
#     - healthy: 3/376 (0.8%) have Retinal Vascular Occlusion ("Stroke
#     - prediabetes: 3/285 (1.1%) have Retinal Vascular Occlusion ("Stroke
#     - oral_medicated: 2/317 (0.6%) have Retinal Vascular Occlusion ("Stroke
#     - insulin_dependent: 7/99 (7.1%) have Retinal Vascular Occlusion ("Stroke
#
# Combined effect of HIGH Glucose AND Retinal Vascular Occlusion ("Stroke:
#   Predicted class: prediabetes (conf=0.55)
#   Delta to baseline: High (-0.33)
#   Among patients with HIGH Glucose AND Retinal Vascular Occlusion ("Stroke (10 patients), the predicted class distribution is: insulin_dependent: 3/10 (30.0%), prediabetes: 3/10 (30.0%), healthy: 3/10 (30.0%), oral_medicated: 1/10 (10.0%).
#   Out of all predicted patients:
#     - healthy: 3/376 (0.8%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - prediabetes: 3/285 (1.1%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - oral_medicated: 1/317 (0.3%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - insulin_dependent: 3/99 (3.0%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → prediabetes (0.74) [Δhealthy=-0.67, Δpred=+0.65, Δoral=+0.01, Δins=+0.01]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.90) [Δhealthy=-0.00, Δpred=+0.07, Δoral=-0.05, Δins=-0.02]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.47) [Δhealthy=-0.01, Δpred=+0.04, Δoral=-0.23, Δins=+0.19]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → insulin_dependent (0.50) [Δhealthy=-0.01, Δpred=-0.01, Δoral=-0.20, Δins=+0.22]

# %%
results.append({
    "i": i,
    "mode_used": mode_used,
    "var1": var1,
    "level1": level1,
    "var2": var2,
    "level2": level2,
    "report": report
})

r = results[0]

report, base_res, fake_question_res, sub_df_joint, proto_changes = compare_independent_effects(
    df=master,
    var1=r["var1"], level1=r["level1"],
    var2=r["var2"], level2=r["level2"],
    condition_vars=set(condition_vars),
    preprocessor=preprocessor,
    mlp=mlp_loaded,
    drop_cols=drop_cols,
    test_acc=test_acc,
    show_joint=True
)
# Out:
# Changed columns: ['PR Interval', 'Cholesterol']

# %%
import numpy as np

# ===========================
# Conclusion template builder
# ===========================

def severity_from_probs(probs_row):
    """
    Severity = P(prediabetes) + P(oral_medicated) + P(insulin_dependent)
    Assumes class order: [healthy, prediabetes, oral_medicated, insulin_dependent]
    """
    p = np.asarray(probs_row, dtype=float)
    return float(p[1] + p[2] + p[3])


def describer1_from_delta_sev(delta_sev):
    # Effect direction/strength on severity
    if delta_sev < -0.15: return "very strongly decreases"
    if delta_sev < -0.05: return "decreases"
    if delta_sev <= 0.05: return "is unlikely to change"
    if delta_sev <= 0.15: return "increases"
    return "very strongly increases"


def describer2_from_max_shift(max_shift):
    # Probability shift magnitude
    if max_shift < 0.03: return "minimal"
    if max_shift < 0.10: return "mixed"
    return "substantial"


def describer4_from_transitions(n_transitions):
    # Class transitions count
    if n_transitions == 0: return "no"
    if n_transitions <= 2: return "some"
    return "many"


def describer5_from_delta_sev(delta_sev):
    # Increase in severity magnitude (non-negative framing)
    if delta_sev <= 0.0: return "no"
    if delta_sev < 0.05: return "minimal"
    if delta_sev < 0.15: return "moderate"
    return "large"


def describer6_from_n(n):
    # Evidential strength from subgroup size
    if n is None: return "unknown"
    if n < 20: return "weak"
    if n < 100: return "moderate"
    return "strong"


def describer7_final_likelihood(delta_sev, n_transitions, n_joint, tol=0.05):
    """
    Final likelihood of meaningful effect:
      - downweight if subgroup is tiny
      - upweight if severity delta is large and many transitions
    """
    if n_joint is None:
        return "unknown"

    # tiny subgroup => cap
    tiny = (n_joint < 20)

    # baseline by severity
    if abs(delta_sev) <= tol and n_transitions == 0:
        base = "unlikely"
    elif abs(delta_sev) <= 0.15 and n_transitions <= 2:
        base = "likely"
    else:
        base = "very likely"

    if tiny and base == "very likely":
        return "likely"  # cap due to low evidence
    if tiny and base == "likely":
        return "unlikely"  # cap further

    return base


def prediction_certainty(top_conf, margin, conf_thr=0.75, margin_thr=0.20):
    if top_conf >= conf_thr and margin >= margin_thr:
        return "High"
    if top_conf >= 0.55 and margin >= 0.10:
        return "Moderate"
    return "Low"


def model_reliability_from_acc(test_acc):
    if test_acc is None:
        return "Unknown"
    if test_acc < 0.60:
        return "Low"
    if test_acc < 0.75:
        return "Moderate"
    return "High"


def build_conclusion_block(
    question_variables,          # str e.g. "HbA1c=LOW AND Oxygen Saturation=LOW"
    base_probs,                  # np.array shape (4,)
    changed_probs,               # np.array shape (4,)
    changed_top_class,           # bool
    changed_top_conf,            # float
    changed_margin,              # float
    joint_subgroup_n=None,       # int
    prototype_transition_count=0,# int 0..4
    test_acc=None                # float
):
    """
    Returns a formatted conclusion block matching your template.
    """
    base_probs = np.asarray(base_probs, dtype=float)
    changed_probs = np.asarray(changed_probs, dtype=float)

    sev_base = severity_from_probs(base_probs)
    sev_changed = severity_from_probs(changed_probs)
    delta_sev = sev_changed - sev_base

    max_shift = float(np.max(np.abs(changed_probs - base_probs)))

    # transitions: fake patient class change counts as 1, plus prototype transitions
    n_transitions = int(changed_top_class) + int(prototype_transition_count)

    d1 = describer1_from_delta_sev(delta_sev)
    d2 = describer2_from_max_shift(max_shift)
    d4 = describer4_from_transitions(n_transitions)
    d5 = describer5_from_delta_sev(delta_sev)
    d6 = describer6_from_n(joint_subgroup_n)
    d7 = describer7_final_likelihood(delta_sev, n_transitions, joint_subgroup_n)

    pred_cert = prediction_certainty(changed_top_conf, changed_margin)
    model_rel = model_reliability_from_acc(test_acc)

    # Build text
    lines = []
    lines.append("=== Conclusion ===============================\n")
    lines.append("In this model,")
    lines.append(f"({question_variables}) {d1} the predicted T2DM severity")
    lines.append(f"(Severity: {sev_base:.3f} → {sev_changed:.3f}, Δ={delta_sev:+.3f}).\n")
    lines.append("Both controlled model probes and real-patient subgroup analysis showed")
    lines.append(f"({d2}) probability shifts, ({d4}) class transitions, and ({d5}) increase in severity.")
    lines.append(f"The subgroup size (n={joint_subgroup_n}) provides ({d6}) evidential strength.")
    lines.append(f"Therefore, this hypothesis is **{d7.upper()}** to meaningfully affect likelihood of T2DM.\n")
    lines.append(f"Prediction certainty: {pred_cert} (top_conf={changed_top_conf:.2f}, margin={changed_margin:.2f})")
    lines.append(f"Model reliability: {model_rel}" + (f" (test_acc={test_acc:.2f})" if test_acc is not None else ""))
    lines.append("\n==============================================")

    return "\n".join(lines)

# %%
import numpy as np

# ===========================
# Conclusion template builder
# ===========================

def severity_from_probs(probs_row):
    """
    Severity = P(prediabetes) + P(oral_medicated) + P(insulin_dependent)
    Assumes class order: [healthy, prediabetes, oral_medicated, insulin_dependent]
    """
    p = np.asarray(probs_row, dtype=float)
    return float(p[1] + p[2] + p[3])


def describer1_from_delta_sev(delta_sev):
    if delta_sev < -0.15: return "very strongly decreases"
    if delta_sev < -0.05: return "decreases"
    if delta_sev <= 0.05: return "is unlikely to change"
    if delta_sev <= 0.15: return "increases"
    return "very strongly increases"


def describer2_from_max_shift(max_shift):
    if max_shift < 0.03: return "minimal"
    if max_shift < 0.10: return "mixed"
    return "substantial"


def describer4_from_transitions(n_transitions):
    if n_transitions == 0: return "no"
    if n_transitions <= 2: return "some"
    return "many"


def describer5_from_delta_sev(delta_sev):
    if delta_sev <= 0.0: return "no"
    if delta_sev < 0.05: return "minimal"
    if delta_sev < 0.15: return "moderate"
    return "large"


def describer6_from_n(n):
    if n is None: return "unknown"
    if n < 20: return "weak"
    if n < 100: return "moderate"
    return "strong"


def describer7_final_likelihood(delta_sev, n_transitions, n_joint, tol=0.05):
    if n_joint is None:
        return "unknown"

    tiny = (n_joint < 20)

    if abs(delta_sev) <= tol and n_transitions == 0:
        base = "unlikely"
    elif abs(delta_sev) <= 0.15 and n_transitions <= 2:
        base = "likely"
    else:
        base = "very likely"

    if tiny and base == "very likely":
        return "likely"
    if tiny and base == "likely":
        return "unlikely"

    return base


def prediction_certainty(top_conf, margin, conf_thr=0.75, margin_thr=0.20):
    if top_conf >= conf_thr and margin >= margin_thr:
        return "High"
    if top_conf >= 0.55 and margin >= 0.10:
        return "Moderate"
    return "Low"


def model_reliability_from_acc(test_acc):
    if test_acc is None:
        return "Unknown"
    if test_acc < 0.60:
        return "Low"
    if test_acc < 0.75:
        return "Moderate"
    return "High"


def build_conclusion_block(
    question_variables,
    base_probs,
    changed_probs,
    base_top_class,              # str, e.g. "healthy"
    changed_top_class,           # str, e.g. "prediabetes"
    changed_top_conf,
    changed_margin,
    joint_subgroup_n=None,
    prototype_transition_count=0,
    test_acc=None
):
    """
    Returns a formatted conclusion block matching your template.
    """
    base_probs = np.asarray(base_probs, dtype=float)
    changed_probs = np.asarray(changed_probs, dtype=float)

    sev_base = severity_from_probs(base_probs)
    sev_changed = severity_from_probs(changed_probs)
    delta_sev = sev_changed - sev_base

    max_shift = float(np.max(np.abs(changed_probs - base_probs)))

    # 1 if predicted class changed, else 0
    class_changed = int(base_top_class != changed_top_class)
    n_transitions = class_changed + int(prototype_transition_count)

    d1 = describer1_from_delta_sev(delta_sev)
    d2 = describer2_from_max_shift(max_shift)
    d4 = describer4_from_transitions(n_transitions)
    d5 = describer5_from_delta_sev(delta_sev)
    d6 = describer6_from_n(joint_subgroup_n)
    d7 = describer7_final_likelihood(delta_sev, n_transitions, joint_subgroup_n)

    pred_cert = prediction_certainty(changed_top_conf, changed_margin)
    model_rel = model_reliability_from_acc(test_acc)

    lines = []
    lines.append("=== Conclusion ===============================\n")
    lines.append("In this model,")
    lines.append(f"({question_variables}) {d1} the predicted T2DM severity")
    lines.append(f"(Severity: {sev_base:.3f} → {sev_changed:.3f}, Δ={delta_sev:+.3f}).\n")
    lines.append("Both controlled model probes and real-patient subgroup analysis showed")
    lines.append(f"({d2}) probability shifts, ({d4}) class transitions, and ({d5}) increase in severity.")
    lines.append(f"The subgroup size (n={joint_subgroup_n}) provides ({d6}) evidential strength.")
    lines.append(f"Therefore, this hypothesis is **{d7.upper()}** to meaningfully affect likelihood of T2DM.\n")
    lines.append(f"Prediction certainty: {pred_cert} (top_conf={changed_top_conf:.2f}, margin={changed_margin:.2f})")
    lines.append(f"Model reliability: {model_rel}" + (f" (test_acc={test_acc:.2f})" if test_acc is not None else ""))
    lines.append("\n==============================================")

    return "\n".join(lines)

# %%
PartA_conclusion_results = []

for idx, r in enumerate(results[0:5], start=1):

    report, base_res, fake_question_res, sub_df_joint, proto_changes = compare_independent_effects(
        df=master,
        var1=r["var1"], level1=r["level1"],
        var2=r["var2"], level2=r["level2"],
        condition_vars=set(condition_vars),
        preprocessor=preprocessor,
        mlp=mlp_loaded,
        drop_cols=drop_cols,
        test_acc=test_acc,
        show_joint=True
    )

    question_vars = f"{r['var1']}={r['level1']} AND {r['var2']}={r['level2']}"

    conclusion_text = build_conclusion_block(
        question_variables=question_vars,
        base_probs=base_res["probs"],
        changed_probs=fake_question_res["probs"],
        base_top_class=base_res["top_class"],
        changed_top_class=fake_question_res["top_class"],
        changed_top_conf=fake_question_res["top_conf"],
        changed_margin=fake_question_res["margin"],
        joint_subgroup_n=len(sub_df_joint),
        prototype_transition_count=prototype_transition_count,
        test_acc=test_acc
    )
 
    print("\n" + "="*60)
    print(f"Question {idx}")
    print(question_vars)
    print("="*60)
    print(conclusion_text)

    PartA_conclusion_results.append({
        "question_num": idx,
        "question_vars": question_vars,
        "conclusion": conclusion_text
    })
# Out:
# Changed columns: ['PR Interval', 'Cholesterol']
#
# ============================================================
# Question 1
# PR Interval=HIGH AND Cholesterol=HIGH
# ============================================================
# === Conclusion ===============================
#
# In this model,
# (PR Interval=HIGH AND Cholesterol=HIGH) is unlikely to change the predicted T2DM severity
# (Severity: 0.121 → 0.083, Δ=-0.038).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (mixed) probability shifts, (no) class transitions, and (no) increase in severity.
# The subgroup size (n=919) provides (strong) evidential strength.
# Therefore, this hypothesis is **UNLIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.92, margin=0.86)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# Changed columns: ['Age-Related Macular Degeneration (Am', 'Heart Attack']
#
# ============================================================
# Question 2
# Heart Attack=None AND Age-Related Macular Degeneration (Am=None
# ============================================================
# === Conclusion ===============================
#
# In this model,
# (Heart Attack=None AND Age-Related Macular Degeneration (Am=None) very strongly increases the predicted T2DM severity
# (Severity: 0.121 → 0.312, Δ=+0.191).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (substantial) probability shifts, (no) class transitions, and (large) increase in severity.
# The subgroup size (n=11) provides (weak) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Moderate (top_conf=0.69, margin=0.52)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# Changed columns: ['Blood Glucose']
#
# ============================================================
# Question 3
# Blood Glucose=HIGH AND None=None
# ============================================================
# === Conclusion ===============================
#
# In this model,
# (Blood Glucose=HIGH AND None=None) increases the predicted T2DM severity
# (Severity: 0.121 → 0.216, Δ=+0.095).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (mixed) probability shifts, (no) class transitions, and (moderate) increase in severity.
# The subgroup size (n=948) provides (strong) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.78, margin=0.68)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# Changed columns: ['Sleep']
#
# ============================================================
# Question 4
# Sleep=HIGH AND None=None
# ============================================================
# === Conclusion ===============================
#
# In this model,
# (Sleep=HIGH AND None=None) is unlikely to change the predicted T2DM severity
# (Severity: 0.121 → 0.127, Δ=+0.006).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (minimal) probability shifts, (no) class transitions, and (minimal) increase in severity.
# The subgroup size (n=328) provides (strong) evidential strength.
# Therefore, this hypothesis is **UNLIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.87, margin=0.80)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# Changed columns: ['Retinal Vascular Occlusion ("Stroke', 'Glucose']
#
# ============================================================
# Question 5
# Glucose=HIGH AND Retinal Vascular Occlusion ("Stroke=None
# ============================================================
# === Conclusion ===============================
#
# In this model,
# (Glucose=HIGH AND Retinal Vascular Occlusion ("Stroke=None) very strongly increases the predicted T2DM severity
# (Severity: 0.121 → 0.624, Δ=+0.503).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (substantial) probability shifts, (some) class transitions, and (large) increase in severity.
# The subgroup size (n=10) provides (weak) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low (top_conf=0.54, margin=0.17)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================

# %% [markdown]
# # End of Part 1

# %% [markdown]
# # Start of Part 2

# %% [markdown]
# ## Pre Em

# %%
# =========================
# Imports
# =========================

# --- Standard library 
from datetime import datetime
import re
import json
import ast


# --- Third-party ---
from IPython.display import Markdown, display
from aisuite import Client

# --- Local / project ---
import research_tools

# %%
import os
from dotenv import load_dotenv

# Clear existing environment key
os.environ.pop("OPENAI_API_KEY", None)

# Reload only from .env
load_dotenv(override=True)

print("Now using:", os.getenv("OPENAI_API_KEY")[:12] + "...")
# Out:
# Now using: sk-proj-FCPx...

# %%
from openai import OpenAI
import os

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.responses.create(
    model="gpt-4o-mini",
    input="ping"
)

print(response.output_text)
# Out:
# It looks like you're testing the connection! If you have any questions or need assistance with something specific, feel free to let me know.

# %%
CLIENT = Client()

# %% [markdown]
# ## Starting Agents

# %%
def planner_agent(topic: str, model: str = "openai:o4-mini") -> list[str]:
    """
    Generates a plan as a Python list of steps (strings) for a research workflow.

    Args:
        topic (str): Research topic to investigate.
        model (str): Language model to use.

    Returns:
        List[str]: A list of executable step strings.
    """
    
    # Build the user prompt
    user_prompt = f"""
    You are a planning agent responsible for organizing a research workflow with multiple intelligent agents.

    🧠 Available agents:
    - A research agent who can search the web, Wikipedia,pubmed and arXiv.
    - A writer agent who can draft research summaries.
    - An editor agent who can reflect and revise the drafts.

    🎯 Your job is to write a clear, step-by-step research plan **as a valid Python list**, where each step is a string.
    Each step should be atomic, executable, and must rely only on the capabilities of the above agents.
    - Return a clear, step by step research plan as a valid Pythin list where each step is a string.
    - Avoid vague steps like "do more research"- be more specific about quieries, outputs anc checls
    
    
    🚫 DO NOT include irrelevant tasks like "create CSV", "set up a repo", "install packages", etc.
    ✅ DO include real research-related tasks (e.g., search, summarize, draft, revise).
    ✅ DO assume tool use is available.
    ✅ DO NOT include explanation text — return ONLY the Python list.
    ✅ The final step should be to generate a Markdown document containing the complete research report.

    Topic: "{topic}"
    """

    # Add the user prompt to the messages list
    messages = [{"role": "user", "content": user_prompt}]

    # Call the LLM
    response = CLIENT.chat.completions.create( 
        # Pass in the model
        model=model,
        # Define the messages. Remember this is meant to be a user prompt!
        messages=messages,
        # Keep responses creative
        temperature=1, 
    )

    # Extract message from response
    steps_str = response.choices[0].message.content.strip()

    # Parse steps
    steps = ast.literal_eval(steps_str)

    return steps

# %%
def research_agent(task: str, model: str = "openai:gpt-4o", return_messages: bool = False):
    """
    Executes a research task using tools via aisuite (no manual loop).
    Returns either the assistant text, or (text, messages) if return_messages=True.
    """
    print("==================================")  
    print("🔍 Research Agent")                 
    print("==================================")

    current_time = datetime.now().strftime('%Y-%m-%d')

    prompt = f"""
    
    You are an advanced research assistant
    
    Available tools:
    - arxiv_tool (search scientific papers)
    - tavily_tool (web search)
    - wikipedia_tool (encyclopedic summaries)
    - pubmed_tool (search biomedical papers)
    
    Task:
    {task}
    
    Guidelines:
    - Use tools when necessary.
    - Cite sources clearly with URLs.
    - Use an academic tone.
    - Provide a structured, well-organised research summary.
    
    """
    
    # Create the messages dict to pass to the LLM. Remember this is a user prompt!
    messages = [{"role": "user", "content": prompt}]

    # Save all of your available tools in the tools list. These can be found in the research_tools module.
    # You can identify each tool in your list like this: 
    # research_tools.<name_of_tool>, where <name_of_tool> is replaced with the function name of the tool.
    tools = [
        research_tools.arxiv_search_tool,
        research_tools.tavily_search_tool,
        research_tools.wikipedia_search_tool,
        research_tools.pubmed_search_tool
        
    ]
    
    # Call the model with tools enabled
    response = CLIENT.chat.completions.create(  
        # Set the model
        model=model,
        # Pass in the messages. You already defined this!
        messages=messages,
        # Pass in the tools list. You already defined this!
        tools=tools,
        # Set the LLM to automatically choose the tools
        tool_choice="auto",
        # Set the max turns to 6
        max_turns=6
    )  
    

    content = response.choices[0].message.content
    print("✅ Output:\n", content)

    
    return (content, messages) if return_messages else content

# %%
def writer_agent(task: str, model: str = "openai:gpt-4o") -> str: # @REPLACE def writer_agent(task: str, model: str = None) -> str:
    """
    Executes writing tasks, such as drafting, expanding, or summarizing text.
    """
    print("==================================")
    print("✍️ Writer Agent")
    print("==================================")

    ### START CODE HERE ###
    
    # Create the system prompt.
    # This should assign the LLM the role of a writing agent specialized in generating well-structured academic or technical content
    system_prompt = f"""
    
    You are a writing agent that focuses on generating academic or technical content
   
   Guidelines:
   -Use clear section headings
   -Ensure logical flow and coherence
   -Avoid filler langauge
   -Provide structured paragraphs
   """


    # Define the system msg by using the system_prompt and assigning the role of system
    system_msg = {"role":"system", "content":system_prompt}

    # Define the user msg. In this case the user prompt should be the task passed to the function
    user_msg = {"role":"user", "content":task}

    # Add both system and user messages to the messages list
    messages = [system_msg, user_msg]
    

    response = CLIENT.chat.completions.create(
        model=model, 
        messages=messages,
        temperature=1.0
    )

    return response.choices[0].message.content

# %%
def editor_agent(task: str, model: str = "openai:gpt-4o") -> str:
    """
    Executes editorial tasks such as reflection, critique, or revision.
    """
    print("==================================")
    print("🧠 Editor Agent")
    print("==================================")
    
    system_prompt = f"""
    
    You are an editor agent whose task is to reflect on, critque and improve drafts
    
    Guidelines:
   -Use clear section headings
   -Ensure logical flow and coherence
   -Avoid filler langauge
   -Provide structured paragraphs
   
    """
    
    # Define the system msg by using the system_prompt and assigning the role of system
    system_msg = {"role":"system", "content":system_prompt}
    
    # Define the user msg. In this case the user prompt should be the task passed to the function
    user_msg = {"role":"user","content":task}
    
    # Add both system and user messages to the messages list
    messages = [system_msg, user_msg]
    
    response = CLIENT.chat.completions.create(
        model=model, 
        messages=messages,
        temperature=0.7 
    )
    
    return response.choices[0].message.content

# %%
#Summarising Agent
def summarising_agent(task: str, model: str = "openai:gpt-4o") -> str:
    """
    Produces a structured, concise summary of a research paper or draft.
    """
    print("==================================")
    print("🧠 Summarising Agent")
    print("==================================")
    
    system_prompt = f"""
    
    You are a research summarisation agent.

    Your task is to produce a clear, concise, and structured summary of the provided content.

    Guidelines:
    - Extract only the most important information.
    - Preserve factual accuracy.
    - Do NOT introduce new information.
    - Do NOT critique or rewrite beyond summarising.
    - Use clear section headings:
        • Key Findings
        • Conclusions
    - Keep the summary concise and focused.
    """

    # Define the system msg by using the system_prompt and assigning the role of system
    system_msg = {"role":"system", "content":system_prompt}
    
    # Define the user msg. In this case the user prompt should be the task passed to the function
    user_msg = {"role":"user","content":task}
    
    # Add both system and user messages to the messages list
    messages = [system_msg, user_msg]
    
    response = CLIENT.chat.completions.create(
        model=model, 
        messages=messages,
        temperature=0.3 
    )
    
    return response.choices[0].message.content

# %%
import json

def final_summary_agent(task: str, model: str = "openai:gpt-4o") -> str:
    """
    Produces a final structured summary for a T2DM hypothesis,
    based only on the evidence provided in the task/context.
    """
    print("==================================")
    print("🧾 Final Summary Agent")
    print("==================================")

    system_prompt = """
You are a final summary agent for a medical hypothesis evaluation workflow.

Your role is to read the provided research/context and produce a final, structured conclusion
about whether the hypothesis meaningfully affects predicted Type 2 Diabetes Mellitus (T2DM) likelihood or severity.

You must base your answer ONLY on the provided evidence.
Do not invent facts, numbers, or effects that are not stated or strongly implied.
If evidence is weak, inconsistent, or missing, say so clearly.

Return the answer in exactly this format:

In the OpenAI model,

(<hypothesis>) is <description1> to change the predicted T2DM severity.

The first variable showed:
<brief summary of the first variable's individual effect>

The second variable showed:
<brief summary of the second variable's individual effect>

The combination of the variables showed:
<brief summary of the combined effect>

Therefore, this hypothesis is <description2> to meaningfully affect likelihood of T2DM.

Prediction certainty: <High / Moderate / Low>
Model reliability: <High / Moderate / Low>

Rules:
- Keep the wording cautious and evidence-based.
- Keep each section concise.
- "description1" should be one of:
  likely, somewhat likely, unlikely, not clearly likely, plausibly associated
- "description2" should be one of:
  likely, moderately supported, weakly supported, unlikely, insufficiently supported
- "Prediction certainty" reflects how clear and consistent the conclusion is from the provided evidence.
- "Model reliability" reflects how dependable the underlying evidence/context appears.
- If one variable has much stronger evidence than the other, say that explicitly.
- If the combination effect is mostly driven by one variable, say so.
"""

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": task}
        ],
        temperature=0.2
    )

    return response.choices[0].message.content

# %%
agent_registry = {
    "research_agent": research_agent,
    "editor_agent": editor_agent,
    "writer_agent": writer_agent,
    "summarising_agent": summarising_agent,
    "final_summary_agent": final_summary_agent
}

def clean_json_block(raw: str) -> str:
    """
    Clean the contents of a JSON block that may come wrapped with Markdown backticks.
    """
    raw = raw.strip()
    if raw.startswith("```"):
        raw = re.sub(r"^```(?:json)?\n?", "", raw)
        raw = re.sub(r"\n?```$", "", raw)
    return raw.strip()

# %%
def executor_agent(topic, model: str = "openai:gpt-4o", limit_steps: bool = True):

    plan_steps = planner_agent(topic)

    max_steps = 4   # ← add this back

    if limit_steps:
        plan_steps = plan_steps[:max_steps]

    plan_steps.append(
        "Summarise all findings from previous steps into a concise synthesis with key quantitative takeaways and limitations"
    )

    history = []

    print("==================================")
    print("🎯 Editor Agent")
    print("==================================")

    for i, step in enumerate(plan_steps):

        agent_decision_prompt = f"""
        You are an execution manager for a multi-agent research team.

        Given the following instruction, identify which agent should perform it and extract the clean task.

        Return only a valid JSON object with two keys:
        - "agent": one of ["research_agent", "editor_agent", "writer_agent", "summarising_agent"]
        - "task": a string with the instruction that the agent should follow

        Only respond with a valid JSON object. Do not include explanations or markdown formatting.

        Instruction: "{step}"
        """
        response = CLIENT.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": agent_decision_prompt}],
            temperature=0,
        )

        raw_content = response.choices[0].message.content
        cleaned_json = clean_json_block(raw_content)
        agent_info = json.loads(cleaned_json)

        agent_name = agent_info["agent"]
        task = agent_info["task"]

        context = "\n".join([
            f"Step {j+1} executed by {a}:\n{r}" 
            for j, (s, a, r) in enumerate(history)
        ])
        enriched_task = f"""
        You are {agent_name}.

        Here is the context of what has been done so far:
        {context}

        Your next task is:
        {task}
        """

        print(f"\n🛠️ Executing with agent: `{agent_name}` on task: {task}")

        if agent_name in agent_registry:
            output = agent_registry[agent_name](enriched_task)
            history.append((step, agent_name, output))
        else:
            output = f"⚠️ Unknown agent: {agent_name}"
            history.append((step, agent_name, output))

        print(f"✅ Output:\n{output}")

    return history

# %%
print(question_vars)
# Out:
# Glucose=HIGH AND Retinal Vascular Occlusion ("Stroke=None

# %%
from IPython.display import Markdown, display
import pandas as pd

def make_question_text(r):
    left = f"{r['level1']} {r['var1']}" if r["level1"] is not None else r["var1"]
    right = f"{r['level2']} {r['var2']}" if r["level2"] is not None else r["var2"]
    return f"Does {left} AND {right} affect your likelihood of Type 2 Diabetes?"

question_list = [make_question_text(r) for r in results[:5]]

executor_runs = []

for idx, question_vars in enumerate(question_list, start=1):
    print("\n" + "=" * 70)
    print(f"Running executor_agent for Question {idx}")
    print(question_vars)
    print("=" * 70)

    executor_history = executor_agent(question_vars, limit_steps=True)
    md = executor_history[-1][-1].strip("`")

    executor_runs.append({
        "question_num": idx,
        "question_vars": question_vars,
        "executor_history": executor_history,
        "final_markdown": md
    })

for run in executor_runs:
    print("\n" + "=" * 70)
    print(f"Final output for Question {run['question_num']}")
    print(run["question_vars"])
    print("=" * 70)
    display(Markdown(run["final_markdown"]))

executor_summary_df = pd.DataFrame([
    {
        "question_num": run["question_num"],
        "question_vars": run["question_vars"],
        "final_markdown": run["final_markdown"]
    }
    for run in executor_runs
])

executor_summary_df.to_csv("executor_5_question_outputs.csv", index=False)
# Out:
# ======================================================================
# Running executor_agent for Question 1
# Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ==================================
# 🎯 Editor Agent
# ==================================
#
# 🛠️ Executing with agent: `research_agent` on task: Identify the relevant variables: PR Interval and Cholesterol.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  ### Research Summary: PR Interval and Cholesterol
#
# #### PR Interval
#
# **Definition and Clinical Significance**
# The PR interval is a component of the electrocardiogram (ECG), measured from the onset of the P wave to the beginning of the QRS complex. It reflects the time taken for electrical conduction from the atria to the ventricles, typically ranging between 120 to 200 milliseconds. Alterations in the PR interval can signal various cardiac pathologies. A prolonged PR interval, often termed first-degree atrioventricular block, suggests delayed electrical conduction through the atrioventricular node or bundle of His ([Wikipedia - PR Interval](https://en.wikipedia.org/wiki/PR_interval)).
#
# **Research Highlights**
# 1. **Cardiac Resynchronization Therapy (CRT)**: A prolonged baseline PR interval often correlates with worse outcomes in patients undergoing CRT, predicting increased all-cause mortality and heart failure hospitalization ([PubMed, Pattara Rattanawong et al., 2018](https://pubmed.ncbi.nlm.nih.gov/30328947/)).
# 2. **Atrial Fibrillation (AF) Risk**: Prolonged PR intervals are linked to an increased risk of adverse cardiovascular outcomes, including atrial fibrillation and heart failure, although results can vary depending on specific population studies ([PubMed, Chun Shing Kwok et al., 2016](https://pubmed.ncbi.nlm.nih.gov/26879241/)).
# 3. **Device-Implanted Patients**: In a large dataset of patients with implanted cardiac devices, prolonged PR intervals were independently associated with higher incidences of AF and heart failure hospitalizations ([PubMed, Hirad Yarmohammadi et al., 2023](https://pubmed.ncbi.nlm.nih.gov/36993911/)).
#
# #### Cholesterol
#
# **Role in the Body**
# Cholesterol is a sterol vital to animal cell structures, notably cell membranes, and serves as a precursor for steroid hormones, bile acids, and vitamin D. It is prominently synthesized in the liver and is found in high concentrations within the brain and spinal cord ([Wikipedia - Cholesterol](https://en.wikipedia.org/wiki/Cholesterol)).
#
# **Research Highlights**
# 1. **Lipid Nanoparticle Delivery**: Cationic cholesterol has been used to enhance mRNA delivery in lung tissues, pointing toward potential therapeutic roles in pulmonary medicine ([PubMed, Afsane Radmand et al., 2024](https://pubmed.ncbi.nlm.nih.gov/38437539/)).
# 2. **Cell Signaling**: Cholesterol regulates cellular processes through its interaction with membrane proteins and its metabolites, affecting cell signaling pathways and homeostasis, particularly in neurons and endocrine tissues ([PubMed, Colin R Jefcoate et al., 2018](https://pubmed.ncbi.nlm.nih.gov/29691317/)).
# 3. **Coronary Heart Disease**: There's robust evidence linking cholesterol, particularly Low-Density Lipoprotein (LDL), with coronary heart disease (CHD). Lifestyle modifications that reduce cholesterol levels, such as diet and exercise, are critical in CHD prevention strategies ([PubMed, R G Troxler and H A Schwertner, 1985](https://pubmed.ncbi.nlm.nih.gov/3896224/)).
#
# ### Conclusion
# The PR interval and cholesterol are pivotal variables in cardiovascular health. The PR interval's role as a predictor of cardiac outcomes renders it a valuable ECG metric, while cholesterol's fundamental biological functions make it a central focus in cardiovascular disease management and prevention. The intersection of these variables with modern therapeutic approaches, such as lipid nanoparticles, highlights ongoing advances in treatment methodologies.
# ✅ Output:
# ### Research Summary: PR Interval and Cholesterol
#
# #### PR Interval
#
# **Definition and Clinical Significance**
# The PR interval is a component of the electrocardiogram (ECG), measured from the onset of the P wave to the beginning of the QRS complex. It reflects the time taken for electrical conduction from the atria to the ventricles, typically ranging between 120 to 200 milliseconds. Alterations in the PR interval can signal various cardiac pathologies. A prolonged PR interval, often termed first-degree atrioventricular block, suggests delayed electrical conduction through the atrioventricular node or bundle of His ([Wikipedia - PR Interval](https://en.wikipedia.org/wiki/PR_interval)).
#
# **Research Highlights**
# 1. **Cardiac Resynchronization Therapy (CRT)**: A prolonged baseline PR interval often correlates with worse outcomes in patients undergoing CRT, predicting increased all-cause mortality and heart failure hospitalization ([PubMed, Pattara Rattanawong et al., 2018](https://pubmed.ncbi.nlm.nih.gov/30328947/)).
# 2. **Atrial Fibrillation (AF) Risk**: Prolonged PR intervals are linked to an increased risk of adverse cardiovascular outcomes, including atrial fibrillation and heart failure, although results can vary depending on specific population studies ([PubMed, Chun Shing Kwok et al., 2016](https://pubmed.ncbi.nlm.nih.gov/26879241/)).
# 3. **Device-Implanted Patients**: In a large dataset of patients with implanted cardiac devices, prolonged PR intervals were independently associated with higher incidences of AF and heart failure hospitalizations ([PubMed, Hirad Yarmohammadi et al., 2023](https://pubmed.ncbi.nlm.nih.gov/36993911/)).
#
# #### Cholesterol
#
# **Role in the Body**
# Cholesterol is a sterol vital to animal cell structures, notably cell membranes, and serves as a precursor for steroid hormones, bile acids, and vitamin D. It is prominently synthesized in the liver and is found in high concentrations within the brain and spinal cord ([Wikipedia - Cholesterol](https://en.wikipedia.org/wiki/Cholesterol)).
#
# **Research Highlights**
# 1. **Lipid Nanoparticle Delivery**: Cationic cholesterol has been used to enhance mRNA delivery in lung tissues, pointing toward potential therapeutic roles in pulmonary medicine ([PubMed, Afsane Radmand et al., 2024](https://pubmed.ncbi.nlm.nih.gov/38437539/)).
# 2. **Cell Signaling**: Cholesterol regulates cellular processes through its interaction with membrane proteins and its metabolites, affecting cell signaling pathways and homeostasis, particularly in neurons and endocrine tissues ([PubMed, Colin R Jefcoate et al., 2018](https://pubmed.ncbi.nlm.nih.gov/29691317/)).
# 3. **Coronary Heart Disease**: There's robust evidence linking cholesterol, particularly Low-Density Lipoprotein (LDL), with coronary heart disease (CHD). Lifestyle modifications that reduce cholesterol levels, such as diet and exercise, are critical in CHD prevention strategies ([PubMed, R G Troxler and H A Schwertner, 1985](https://pubmed.ncbi.nlm.nih.gov/3896224/)).
#
# ### Conclusion
# The PR interval and cholesterol are pivotal variables in cardiovascular health. The PR interval's role as a predictor of cardiac outcomes renders it a valuable ECG metric, while cholesterol's fundamental biological functions make it a central focus in cardiovascular disease management and prevention. The intersection of these variables with modern therapeutic approaches, such as lipid nanoparticles, highlights ongoing advances in treatment methodologies.
#
# 🛠️ Executing with agent: `research_agent` on task: Load the trained model and preprocessing pipeline.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  ### Research Summary: Machine Learning Applications in PR Interval and Cholesterol Research
#
# #### Overview
# The integration of machine learning into cardiovascular health studies, particularly concerning PR interval and cholesterol, is emerging as a significant field of research. Machine learning techniques offer advanced predictive capabilities in clinical applications, especially for non-invasive diagnostics and risk assessment.
#
# #### Recent Research Insights
#
# 1. **Machine Learning and PR Interval**:
#     - **ECG-Based Predictions**: Studies have developed machine learning models using electrocardiography (ECG) to predict cardiovascular outcomes such as myocardial blood flow reserve, providing significant prognostic value ([Source](https://www.sciencedirect.com/science/article/pii/S2666379124004762)).
#     - **Cardiovascular Detection**: Machine learning models incorporating ECG metrics enhanced predictive accuracy for cardiovascular disease compared to models relying solely on demographic and clinical data ([Source](https://pmc.ncbi.nlm.nih.gov/articles/PMC8139412/)).
#
# 2. **Machine Learning in Cholesterol and Cardiovascular Health**:
#     - **Cholesterol Level Prediction**: Machine learning models have been utilized to predict elevated cholesterol levels, which is crucial for early intervention and management of cardiovascular diseases ([Source](https://www.semanticscholar.org/paper/Modeling-Cholesterol-Levels-Using-Machine-Learning%3A-Albugg/c1ec1920c8c638b2288ce70851eb0845b039d3cf)).
#     - **ML for Gallbladder Polyp Assessment**: In clinical settings, machine learning models combining radiomics with deep learning showcase the potential to predict the nature of gallbladder polyps, discriminating between cholesterol and adenomatous polyps effectively ([PubMed](https://pubmed.ncbi.nlm.nih.gov/38623640/)).
#
# 3. **Broader Machine Learning Applications in Biology**:
#     - **Machine Learning Validation**: Within the field of biology, standardized recommendations have been proposed for the validation of machine learning models to ensure reliability and reproducibility in model predictions ([Arxiv](https://arxiv.org/abs/2006.16189v4)).
#     - **Active Learning for Data Streams**: Advancements in online active learning focus on continuously selecting and labeling data in streams, which can enhance real-time predictive models in clinical settings ([Arxiv](https://arxiv.org/abs/2302.08893v4)).
#
# #### Conclusion
# The confluence of machine learning with ECG data and cholesterol studies presents transformative potential in cardiovascular health research. Current studies emphasize the utility of machine learning in enhancing diagnostic accuracy, predicting cardiovascular events, and improving patient stratification for personalized therapeutic strategies. The ongoing development of machine learning frameworks in this domain underscores the importance of robust model validation and interpretability, paving the way for more precise and actionable health insights.
#
# By leveraging these developing technologies, there is an opportunity to significantly improve existing cardiac care strategies and cholesterol management practices, ensuring improved outcomes for patients with cardiovascular concerns.
# ✅ Output:
# ### Research Summary: Machine Learning Applications in PR Interval and Cholesterol Research
#
# #### Overview
# The integration of machine learning into cardiovascular health studies, particularly concerning PR interval and cholesterol, is emerging as a significant field of research. Machine learning techniques offer advanced predictive capabilities in clinical applications, especially for non-invasive diagnostics and risk assessment.
#
# #### Recent Research Insights
#
# 1. **Machine Learning and PR Interval**:
#     - **ECG-Based Predictions**: Studies have developed machine learning models using electrocardiography (ECG) to predict cardiovascular outcomes such as myocardial blood flow reserve, providing significant prognostic value ([Source](https://www.sciencedirect.com/science/article/pii/S2666379124004762)).
#     - **Cardiovascular Detection**: Machine learning models incorporating ECG metrics enhanced predictive accuracy for cardiovascular disease compared to models relying solely on demographic and clinical data ([Source](https://pmc.ncbi.nlm.nih.gov/articles/PMC8139412/)).
#
# 2. **Machine Learning in Cholesterol and Cardiovascular Health**:
#     - **Cholesterol Level Prediction**: Machine learning models have been utilized to predict elevated cholesterol levels, which is crucial for early intervention and management of cardiovascular diseases ([Source](https://www.semanticscholar.org/paper/Modeling-Cholesterol-Levels-Using-Machine-Learning%3A-Albugg/c1ec1920c8c638b2288ce70851eb0845b039d3cf)).
#     - **ML for Gallbladder Polyp Assessment**: In clinical settings, machine learning models combining radiomics with deep learning showcase the potential to predict the nature of gallbladder polyps, discriminating between cholesterol and adenomatous polyps effectively ([PubMed](https://pubmed.ncbi.nlm.nih.gov/38623640/)).
#
# 3. **Broader Machine Learning Applications in Biology**:
#     - **Machine Learning Validation**: Within the field of biology, standardized recommendations have been proposed for the validation of machine learning models to ensure reliability and reproducibility in model predictions ([Arxiv](https://arxiv.org/abs/2006.16189v4)).
#     - **Active Learning for Data Streams**: Advancements in online active learning focus on continuously selecting and labeling data in streams, which can enhance real-time predictive models in clinical settings ([Arxiv](https://arxiv.org/abs/2302.08893v4)).
#
# #### Conclusion
# The confluence of machine learning with ECG data and cholesterol studies presents transformative potential in cardiovascular health research. Current studies emphasize the utility of machine learning in enhancing diagnostic accuracy, predicting cardiovascular events, and improving patient stratification for personalized therapeutic strategies. The ongoing development of machine learning frameworks in this domain underscores the importance of robust model validation and interpretability, paving the way for more precise and actionable health insights.
#
# By leveraging these developing technologies, there is an opportunity to significantly improve existing cardiac care strategies and cholesterol management practices, ensuring improved outcomes for patients with cardiovascular concerns.
#
# 🛠️ Executing with agent: `research_agent` on task: Create a baseline synthetic patient from dataset averages.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  ### Synthetic Baseline Patient Model Using Average Health Parameters
#
# #### Overview
# Creating a baseline synthetic patient involves utilizing average health statistics to simulate a typical individual's medical profile. Such a model can be valuable in medical research and simulations, facilitating the development and testing of new treatments and interventions. Here, we derive the model using averages from American health statistics as well as insights from relevant biomedical research.
#
# #### Key Health Statistics and Parameters
#
# 1. **General Health Indicators**:
#    - **Life Expectancy**: In the United States, the life expectancy at birth as per WHO is a critical health indicator used in synthetic patient modeling [[WHO Data](https://data.who.int/countries/840)].
#    - **Health Spending**: The United States spends significantly more on health per capita ($12,555), compared to the OECD average ($4,986) [[OECD Report](https://www.oecd.org/content/dam/oecd/en/publications/reports/2025/07/health-at-a-glance-2023_39bcb58d/united-states_1bd99de8/4268c3ef-en.pdf)].
#
# 2. **Diet and Metabolism**:
#    - **Cholesterol Levels**: Machine learning models have been developed for predicting elevated cholesterol levels applicable in synthetic modeling for cholesterol management [[Semantic Scholar](https://www.semanticscholar.org/paper/Modeling-Cholesterol-Levels-Using-Machine-Learning%3A-Albugg/c1ec1920c8c638b2288ce70851eb0845b039d3cf)].
#
# 3. **Cardiovascular Metrics**:
#    - **PR Interval**: Synthetic patients can utilize average PR interval data to simulate standard cardiac timing, significant in cardiovascular research [[Wikipedia - PR Interval](https://en.wikipedia.org/wiki/PR_interval)].
#
# 4. **Mental and Physical Health Considerations**:
#    - **Chronic Conditions**: Reports indicate an increased prevalence of chronic conditions, crucial for integrating into synthetic patient profiles to reflect common health challenges [[America's Health Rankings](https://www.unitedhealthgroup.com/newsroom/posts/2023/2023-12-05-ahr-annual-report-2023.html)].
#
# #### Synthetic Data Utilization
#
# - **RINet Development**: Leveraging synthetic data to train machine learning models for estimating clinical reference intervals helps in managing variability of age, gender, and ethnicity in patient datasets, useful for crafting synthetic profiles [[PubMed](https://pubmed.ncbi.nlm.nih.gov/41519188/)].
#
# #### Implications and Conclusion
#
# The synthetic baseline patient model offers a standardized framework for medical research, allowing for controlled, reproducible studies in cardiovascular and metabolic health. By utilizing synthesized average health statistics, researchers can establish reference models that accurately represent population norms. Consequently, these advances foster improved understanding of disease mechanics and therapeutic interventions, ultimately enhancing personalized medicine strategies.
#
# Future work should aim at refining these models with more granular, real-world data and expanding their application across diverse pathophysiological conditions.
# ✅ Output:
# ### Synthetic Baseline Patient Model Using Average Health Parameters
#
# #### Overview
# Creating a baseline synthetic patient involves utilizing average health statistics to simulate a typical individual's medical profile. Such a model can be valuable in medical research and simulations, facilitating the development and testing of new treatments and interventions. Here, we derive the model using averages from American health statistics as well as insights from relevant biomedical research.
#
# #### Key Health Statistics and Parameters
#
# 1. **General Health Indicators**:
#    - **Life Expectancy**: In the United States, the life expectancy at birth as per WHO is a critical health indicator used in synthetic patient modeling [[WHO Data](https://data.who.int/countries/840)].
#    - **Health Spending**: The United States spends significantly more on health per capita ($12,555), compared to the OECD average ($4,986) [[OECD Report](https://www.oecd.org/content/dam/oecd/en/publications/reports/2025/07/health-at-a-glance-2023_39bcb58d/united-states_1bd99de8/4268c3ef-en.pdf)].
#
# 2. **Diet and Metabolism**:
#    - **Cholesterol Levels**: Machine learning models have been developed for predicting elevated cholesterol levels applicable in synthetic modeling for cholesterol management [[Semantic Scholar](https://www.semanticscholar.org/paper/Modeling-Cholesterol-Levels-Using-Machine-Learning%3A-Albugg/c1ec1920c8c638b2288ce70851eb0845b039d3cf)].
#
# 3. **Cardiovascular Metrics**:
#    - **PR Interval**: Synthetic patients can utilize average PR interval data to simulate standard cardiac timing, significant in cardiovascular research [[Wikipedia - PR Interval](https://en.wikipedia.org/wiki/PR_interval)].
#
# 4. **Mental and Physical Health Considerations**:
#    - **Chronic Conditions**: Reports indicate an increased prevalence of chronic conditions, crucial for integrating into synthetic patient profiles to reflect common health challenges [[America's Health Rankings](https://www.unitedhealthgroup.com/newsroom/posts/2023/2023-12-05-ahr-annual-report-2023.html)].
#
# #### Synthetic Data Utilization
#
# - **RINet Development**: Leveraging synthetic data to train machine learning models for estimating clinical reference intervals helps in managing variability of age, gender, and ethnicity in patient datasets, useful for crafting synthetic profiles [[PubMed](https://pubmed.ncbi.nlm.nih.gov/41519188/)].
#
# #### Implications and Conclusion
#
# The synthetic baseline patient model offers a standardized framework for medical research, allowing for controlled, reproducible studies in cardiovascular and metabolic health. By utilizing synthesized average health statistics, researchers can establish reference models that accurately represent population norms. Consequently, these advances foster improved understanding of disease mechanics and therapeutic interventions, ultimately enhancing personalized medicine strategies.
#
# Future work should aim at refining these models with more granular, real-world data and expanding their application across diverse pathophysiological conditions.
#
# 🛠️ Executing with agent: `editor_agent` on task: Modify the synthetic patient to reflect HIGH PR Interval and HIGH Cholesterol.
# ==================================
# 🧠 Editor Agent
# ==================================
# ✅ Output:
# ### Modified Synthetic Baseline Patient Model: High PR Interval and High Cholesterol
#
# #### Overview
#
# Incorporating specific health conditions such as a high PR interval and elevated cholesterol levels into synthetic patient models is crucial for understanding the implications of these factors on cardiovascular health. This modification helps researchers study the potential risks and outcomes associated with these conditions, and facilitates the testing of targeted interventions.
#
# #### Key Health Statistics and Parameters
#
# 1. **Baseline Characteristics**:
#    - **Age and Demographics**: Our synthetic patient represents an average middle-aged adult, as this demographic is commonly affected by high cholesterol and prolonged PR intervals.
#    - **Lifestyle Factors**: Includes a sedentary lifestyle and a diet high in saturated fats, contributing to elevated cholesterol levels.
#
# 2. **Electrocardiogram (ECG) Metrics**:
#    - **PR Interval**: For this model, the PR interval is set at 220 milliseconds, exceeding the normal range of 120 to 200 milliseconds, indicating a first-degree atrioventricular block. This alteration is significant for studying its correlation with cardiac events such as atrial fibrillation and heart failure.
#
# 3. **Cholesterol Levels**:
#    - **Lipid Profile**: The synthetic patient displays elevated LDL cholesterol levels (>160 mg/dL) and reduced HDL levels (<40 mg/dL), reflecting a common dyslipidemic profile associated with increased risk for coronary heart disease. Incorporating these values allows for the examination of lipid-lowering interventions and their effects on cardiovascular outcomes.
#
# 4. **Associated Health Conditions**:
#    - **Hypertension**: Often coexists with high cholesterol and is a risk factor for extending the PR interval.
#    - **Pre-Diabetes**: Common metabolic condition in patients with high cholesterol, influencing cardiovascular risk.
#
# #### Synthetic Data Utilization
#
# - **Machine Learning Integration**: The synthetic patient data can be used to train and validate machine learning models that predict cardiovascular events. This involves incorporating high PR interval and cholesterol parameters to improve risk stratification and treatment personalization.
# - **Simulation of Interventions**: Models can simulate the effects of lifestyle changes or pharmaceutical interventions, such as statins and beta-blockers, on cholesterol levels and PR interval duration.
#
# #### Implications and Conclusion
#
# By modifying the synthetic patient model to include a high PR interval and elevated cholesterol, researchers can better understand the direct and indirect impacts of these conditions on cardiovascular health. This model serves as a basis for testing hypotheses related to cardiac and metabolic interventions, offering insights into disease progression and prevention strategies.
#
# Future developments should focus on enhancing the model's accuracy by integrating emerging data from real-world patient populations and expanding its applicability to diverse demographic and genetic profiles. This will improve the precision of predictive models and the effectiveness of tailored healthcare interventions.
#
# 🛠️ Executing with agent: `summarising_agent` on task: Summarise all findings from previous steps into a concise synthesis with key quantitative takeaways and limitations
# ==================================
# 🧠 Summarising Agent
# ==================================
# ✅ Output:
# ### Key Findings
#
# #### PR Interval and Cholesterol
# - **PR Interval**: The PR interval, a crucial ECG component, reflects atrial to ventricular conduction time. Prolonged PR intervals are linked to adverse outcomes such as increased mortality and heart failure, particularly in patients undergoing cardiac resynchronization therapy and those with implanted devices.
# - **Cholesterol**: Cholesterol is vital for cellular structures and hormone synthesis. High LDL cholesterol is strongly associated with coronary heart disease, and lifestyle modifications are essential for management. Cationic cholesterol shows promise in enhancing mRNA delivery for therapeutic applications.
#
# #### Machine Learning Applications
# - **PR Interval**: Machine learning models using ECG data improve predictions of cardiovascular outcomes, offering enhanced diagnostic accuracy over traditional methods.
# - **Cholesterol**: Predictive models for cholesterol levels aid in early intervention, while machine learning assists in differentiating gallbladder polyp types.
# - **Broader Applications**: Machine learning frameworks are advancing in biology, emphasizing model validation and real-time data stream processing for clinical applications.
#
# #### Synthetic Baseline Patient Model
# - **General Model**: Utilizes average health statistics to simulate typical patient profiles, aiding in research and treatment development.
# - **Modified Model**: Focuses on high PR interval and cholesterol, reflecting common cardiovascular risk profiles. This model aids in studying the effects of interventions and disease progression.
#
# ### Conclusions
#
# - The integration of machine learning with cardiovascular metrics like the PR interval and cholesterol levels is transforming diagnostics and risk assessment, offering personalized therapeutic strategies.
# - Synthetic patient models, particularly those incorporating specific conditions like high PR interval and cholesterol, provide valuable insights into cardiovascular health and facilitate the testing of targeted interventions.
# - Future research should enhance these models with real-world data and expand their applicability across diverse populations to improve predictive accuracy and healthcare outcomes.
#
# ======================================================================
# Running executor_agent for Question 2
# Does Heart Attack AND Age-Related Macular Degeneration (Am affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ==================================
# 🎯 Editor Agent
# ==================================
#
# 🛠️ Executing with agent: `research_agent` on task: Identify the relevant variables related to heart attack, age-related macular degeneration, and Type 2 Diabetes in the dataset.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  To adequately identify the relevant variables related to heart attack, age-related macular degeneration, and Type 2 Diabetes, it's essential to explore the risk factors associated with each condition. Here is a structured summary based on the data obtained from Wikipedia:
#
# ### Heart Attack
#
# Heart attacks, or myocardial infarctions, occur due to the interruption of blood flow to a part of the heart, causing damage to the heart muscle. Key variables and risk factors typically associated with heart attacks include:
#
# - **Cholesterol Levels**: Particularly low-density lipoprotein (LDL) which transports fat molecules around the body, is a crucial variable [source](https://en.wikipedia.org/wiki/Low-density_lipoprotein).
# - Other variables include high blood pressure, smoking, physical inactivity, obesity, and diabetes.
#
# ### Age-related Macular Degeneration (AMD)
#
# Age-related macular degeneration is a medical condition resulting in blurred or loss of vision in the center of the visual field. It primarily affects older adults. Relevant variables associated with AMD include:
#
# - **Age**: One of the most significant factors, as it primarily affects older individuals.
# - **Genetic Factors**: Family history of AMD can increase the risk.
# - **Lifestyle Factors**: Smoking and dietary habits can influence the risk [source](https://en.wikipedia.org/wiki/Macular_degeneration).
#
# ### Type 2 Diabetes
#
# Type 2 Diabetes (T2D) is characterized by insulin resistance and is often associated with various metabolic conditions. Relevant variables to consider include:
#
# - **Insulin Resistance**: A condition where the body's cells become less responsive to insulin.
# - **Obesity**: Particularly central obesity, where fat is accumulated around the abdomen.
# - **Physical Inactivity**: Sedentary lifestyle is a known risk factor.
# - **Genetic Factors**: Family history and genetics also play a significant role [source](https://en.wikipedia.org/wiki/Type_1_diabetes).
#
# In summary, the variables relevant to these conditions are diverse and include a mixture of biological, genetic, and lifestyle-related factors. Ensuring a comprehensive dataset that captures these variables would be critical for in-depth analysis and research.
# ✅ Output:
# To adequately identify the relevant variables related to heart attack, age-related macular degeneration, and Type 2 Diabetes, it's essential to explore the risk factors associated with each condition. Here is a structured summary based on the data obtained from Wikipedia:
#
# ### Heart Attack
#
# Heart attacks, or myocardial infarctions, occur due to the interruption of blood flow to a part of the heart, causing damage to the heart muscle. Key variables and risk factors typically associated with heart attacks include:
#
# - **Cholesterol Levels**: Particularly low-density lipoprotein (LDL) which transports fat molecules around the body, is a crucial variable [source](https://en.wikipedia.org/wiki/Low-density_lipoprotein).
# - Other variables include high blood pressure, smoking, physical inactivity, obesity, and diabetes.
#
# ### Age-related Macular Degeneration (AMD)
#
# Age-related macular degeneration is a medical condition resulting in blurred or loss of vision in the center of the visual field. It primarily affects older adults. Relevant variables associated with AMD include:
#
# - **Age**: One of the most significant factors, as it primarily affects older individuals.
# - **Genetic Factors**: Family history of AMD can increase the risk.
# - **Lifestyle Factors**: Smoking and dietary habits can influence the risk [source](https://en.wikipedia.org/wiki/Macular_degeneration).
#
# ### Type 2 Diabetes
#
# Type 2 Diabetes (T2D) is characterized by insulin resistance and is often associated with various metabolic conditions. Relevant variables to consider include:
#
# - **Insulin Resistance**: A condition where the body's cells become less responsive to insulin.
# - **Obesity**: Particularly central obesity, where fat is accumulated around the abdomen.
# - **Physical Inactivity**: Sedentary lifestyle is a known risk factor.
# - **Genetic Factors**: Family history and genetics also play a significant role [source](https://en.wikipedia.org/wiki/Type_1_diabetes).
#
# In summary, the variables relevant to these conditions are diverse and include a mixture of biological, genetic, and lifestyle-related factors. Ensuring a comprehensive dataset that captures these variables would be critical for in-depth analysis and research.
#
# 🛠️ Executing with agent: `research_agent` on task: Load the trained classifier and preprocessing objects.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  To proceed with the task of loading the trained classifier and preprocessing objects, we need to obtain them from their respective sources. However, as an AI model with the tools available to me, direct access to specific trained models and preprocessing objects isn't feasible without explicit access details or files provided. Typically, this process would involve loading these items from a storage medium or database where they have been saved after training.
#
# Nevertheless, I can guide you on how to approach this task and suggest further resources if necessary.
#
# ### Steps for Loading a Trained Classifier and Preprocessing Objects
#
# #### 1. **Identify Storage Location**:
#    - Determine where the model and preprocessing objects have been saved. This could be on a local machine's disk, a cloud storage service, or a specialized model hosting service.
#
# #### 2. **Utilize Appropriate Libraries**:
#    - For models trained in Python, particularly with libraries like `scikit-learn`, `TensorFlow`, or `PyTorch`, use specific functions from these libraries to load models.
#
#    Examples include:
#    - `joblib.load('model.pkl')` for scikit-learn models.
#    - `keras.models.load_model('model.h5')` for TensorFlow/Keras models.
#    - `torch.load('model.pth')` for PyTorch models.
#
# #### 3. **Load Preprocessing Objects**:
#    - Similarly, preprocessing objects such as scalers, encoders, etc., can be loaded using similar functions if they were saved using libraries like `joblib` or `pickle`.
#
# #### 4. **Verify Compatibility**:
#    - Ensure that there is compatibility between the library versions used for training and those in use currently. Inconsistencies in library versions could cause errors.
#
# #### 5. **Testing and Validation**:
#    - Once loaded, it is good practice to test the classifier on a portion of data to verify that it loads correctly and performs as expected.
#
# ### Consideration of Academic Resources
#
# If you're looking to explore more about these steps and the tools involved, several academic resources and documentation can provide in-depth knowledge:
# - [Scikit-learn Documentation on Model Persistence](https://scikit-learn.org/stable/modules/model_persistence.html)
# - [Keras Guide on Saving and Loading Models](https://keras.io/guides/serialization_and_saving/)
# - [PyTorch Documentation for Saving and Loading Models](https://pytorch.org/tutorials/beginner/saving_loading_models.html)
#
# Should you need further assistance on this task or related queries involving data loading or sourcing additional research information, please feel free to let me know!
# ✅ Output:
# To proceed with the task of loading the trained classifier and preprocessing objects, we need to obtain them from their respective sources. However, as an AI model with the tools available to me, direct access to specific trained models and preprocessing objects isn't feasible without explicit access details or files provided. Typically, this process would involve loading these items from a storage medium or database where they have been saved after training.
#
# Nevertheless, I can guide you on how to approach this task and suggest further resources if necessary.
#
# ### Steps for Loading a Trained Classifier and Preprocessing Objects
#
# #### 1. **Identify Storage Location**:
#    - Determine where the model and preprocessing objects have been saved. This could be on a local machine's disk, a cloud storage service, or a specialized model hosting service.
#
# #### 2. **Utilize Appropriate Libraries**:
#    - For models trained in Python, particularly with libraries like `scikit-learn`, `TensorFlow`, or `PyTorch`, use specific functions from these libraries to load models.
#
#    Examples include:
#    - `joblib.load('model.pkl')` for scikit-learn models.
#    - `keras.models.load_model('model.h5')` for TensorFlow/Keras models.
#    - `torch.load('model.pth')` for PyTorch models.
#
# #### 3. **Load Preprocessing Objects**:
#    - Similarly, preprocessing objects such as scalers, encoders, etc., can be loaded using similar functions if they were saved using libraries like `joblib` or `pickle`.
#
# #### 4. **Verify Compatibility**:
#    - Ensure that there is compatibility between the library versions used for training and those in use currently. Inconsistencies in library versions could cause errors.
#
# #### 5. **Testing and Validation**:
#    - Once loaded, it is good practice to test the classifier on a portion of data to verify that it loads correctly and performs as expected.
#
# ### Consideration of Academic Resources
#
# If you're looking to explore more about these steps and the tools involved, several academic resources and documentation can provide in-depth knowledge:
# - [Scikit-learn Documentation on Model Persistence](https://scikit-learn.org/stable/modules/model_persistence.html)
# - [Keras Guide on Saving and Loading Models](https://keras.io/guides/serialization_and_saving/)
# - [PyTorch Documentation for Saving and Loading Models](https://pytorch.org/tutorials/beginner/saving_loading_models.html)
#
# Should you need further assistance on this task or related queries involving data loading or sourcing additional research information, please feel free to let me know!
#
# 🛠️ Executing with agent: `research_agent` on task: Create a baseline synthetic patient using dataset averages or medians.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  Based on the academic search conducted, we have gathered relevant data from recent studies concerning the key variables associated with heart attack, age-related macular degeneration (AMD), and Type 2 Diabetes (T2D). Here is a summary of the findings:
#
# ### Heart Attack
# - **Cholesterol Levels (LDL)**:
#   - A study analyzing the FOURIER-OLE trial reveals that long-term achievement of lower LDL-C levels (<20 mg/dL) is associated with reduced cardiovascular risk [Source](https://pubmed.ncbi.nlm.nih.gov/36779348/).
#   - Another study suggests a personalized lipid-lowering strategy significantly improves LDL-C management and reduces major cardiovascular events [Source](https://pubmed.ncbi.nlm.nih.gov/39855642/).
#
# ### Age-related Macular Degeneration (AMD)
# - **Age and Lifestyle Factors**:
#   - A study on melatonin indicates its usage is associated with a reduced risk of developing AMD. This reflects the significant role of lifestyle choices and supplements [Source](https://pubmed.ncbi.nlm.nih.gov/38842832/).
#
# ### Type 2 Diabetes
# - **Insulin Resistance and Obesity**:
#   - Research indicates that metabolic markers, including phospholipid metabolites, could offer diagnostic insights into obesity-associated insulin resistance common in T2D [Source](https://pubmed.ncbi.nlm.nih.gov/31640727/).
#
# ### Creating a Baseline Synthetic Patient
# To create a baseline synthetic patient profile, we can now consider the average values for key variables:
#
# 1. **Heart Attack Risks**:
#    - LDL Cholesterol: Baseline data suggests aiming for LDL-C levels below 55 mg/dL is beneficial for patients at risk.
#
# 2. **Age-related Macular Degeneration**:
#    - Lifestyle Interventions: Use of lifestyle changes such as supplements can lower progression risk.
#
# 3. **Type 2 Diabetes**:
#    - Obesity and Insulin Resistance: Monitoring and managing obesity-related metabolic markers are critical.
#
# This synthesized baseline profile will ideally involve median or averaged values for these critical factors to simulate a typical patient likely to develop these conditions. Further refinement would require specific demographic data, which could be included if drawn from a targeted dataset or broader population health data.
# ✅ Output:
# Based on the academic search conducted, we have gathered relevant data from recent studies concerning the key variables associated with heart attack, age-related macular degeneration (AMD), and Type 2 Diabetes (T2D). Here is a summary of the findings:
#
# ### Heart Attack
# - **Cholesterol Levels (LDL)**:
#   - A study analyzing the FOURIER-OLE trial reveals that long-term achievement of lower LDL-C levels (<20 mg/dL) is associated with reduced cardiovascular risk [Source](https://pubmed.ncbi.nlm.nih.gov/36779348/).
#   - Another study suggests a personalized lipid-lowering strategy significantly improves LDL-C management and reduces major cardiovascular events [Source](https://pubmed.ncbi.nlm.nih.gov/39855642/).
#
# ### Age-related Macular Degeneration (AMD)
# - **Age and Lifestyle Factors**:
#   - A study on melatonin indicates its usage is associated with a reduced risk of developing AMD. This reflects the significant role of lifestyle choices and supplements [Source](https://pubmed.ncbi.nlm.nih.gov/38842832/).
#
# ### Type 2 Diabetes
# - **Insulin Resistance and Obesity**:
#   - Research indicates that metabolic markers, including phospholipid metabolites, could offer diagnostic insights into obesity-associated insulin resistance common in T2D [Source](https://pubmed.ncbi.nlm.nih.gov/31640727/).
#
# ### Creating a Baseline Synthetic Patient
# To create a baseline synthetic patient profile, we can now consider the average values for key variables:
#
# 1. **Heart Attack Risks**:
#    - LDL Cholesterol: Baseline data suggests aiming for LDL-C levels below 55 mg/dL is beneficial for patients at risk.
#
# 2. **Age-related Macular Degeneration**:
#    - Lifestyle Interventions: Use of lifestyle changes such as supplements can lower progression risk.
#
# 3. **Type 2 Diabetes**:
#    - Obesity and Insulin Resistance: Monitoring and managing obesity-related metabolic markers are critical.
#
# This synthesized baseline profile will ideally involve median or averaged values for these critical factors to simulate a typical patient likely to develop these conditions. Further refinement would require specific demographic data, which could be included if drawn from a targeted dataset or broader population health data.
#
# 🛠️ Executing with agent: `research_agent` on task: Modify the synthetic patient to reflect the conditions of having a heart attack and age-related macular degeneration.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  ### Modification of a Synthetic Patient Profile to Reflect Heart Attack and Age-related Macular Degeneration Conditions
#
# To modify the synthetic patient profile in order to reflect both heart attack (myocardial infarction) and age-related macular degeneration (AMD), it's imperative to consider the relevant comorbidities and risk factors associated with these conditions. Recent research and scholarly articles provide insights into the intersection of cardiovascular disease and AMD, as well as their shared risk factors. Below is a synthesis of findings from various studies and sources.
#
# #### Heart Attack Risk Factors
#
# 1. **Cholesterol Levels and Lipid Management**
#    - Studies such as the FOURIER-OLE trial emphasize the relationship between sustained low LDL cholesterol levels and reduced cardiovascular risks (PubMed: [36779348](https://pubmed.ncbi.nlm.nih.gov/36779348/)).
#
# 2. **Body Mass Index and Metabolic Markers**
#    - Metabolomic phenotyping has shown that body mass index (BMI) is crucial in profiling cardiovascular risks, including myocardial infarction (PubMed: [37308902](https://pubmed.ncbi.nlm.nih.gov/37308902/)).
#
# #### Age-related Macular Degeneration (AMD) Risk Factors
#
# 1. **Visual Disability and Cardiovascular Disease**
#    - Research demonstrates a notable association between AMD with visual impairment and heightened risks of myocardial infarction and overall cerebrovascular diseases (PubMed: [37119082](https://pubmed.ncbi.nlm.nih.gov/37119082/)).
#
# 2. **Obesity and Comorbidities**
#    - The relationship between obesity, metabolic BMI, and risks of both AMD and cardiovascular diseases underscores the importance of metabolic health in these patients (PubMed: [37308902](https://pubmed.ncbi.nlm.nih.gov/37308902/)).
#
# #### Intersection of Heart Disease and AMD
#
# 1. **Comorbidity Challenges**
#    - Studies reveal a significant overlap in risk factors for AMD and cardiovascular diseases, further complicating patient profiles and necessitating comprehensive management strategies (PubMed: [19516892](https://pubmed.ncbi.nlm.nih.gov/19516892/)).
#
# 2. **Potential for Shared Pathophysiology**
#    - There is evidence to suggest shared pathophysiological pathways in the development of AMD and cardiovascular diseases, demanding integrated care strategies for individuals displaying both conditions.
#
# #### Recommendations for a Synthetic Patient Profile
#
# Based on the insights from current research, a synthetic patient profile with both heart attack and age-related macular degeneration should consider the following average values and characteristics:
#
# - **LDL Cholesterol Levels**: Aim for levels below 55 mg/dL, as lower levels have been associated with reduced cardiovascular risks.
#
# - **Metabolic Profile**: Incorporate obesity-related metabolic markers that predispose individuals to AMD and cardiovascular diseases. A metabolomic approach may offer robust insights into individual risk stratification.
#
# - **Age and Visual Impairment**: Acknowledge increased risks of cardiovascular diseases in patients with AMD who also exhibit visual disabilities.
#
# - **Lifestyle Factors**: Highlight the significance of healthy lifestyle choices, given the shared risk factors between AMD and cardiovascular diseases.
#
# In conclusion, the modified synthetic patient should accurately reflect the nuanced relationship between these conditions, leveraging comprehensive management frameworks informed by ongoing research into their shared risk factors and pathophysiology. Further research and real-world data would refine these profiles, ensuring they align with clinical expectations and outcomes.
# ✅ Output:
# ### Modification of a Synthetic Patient Profile to Reflect Heart Attack and Age-related Macular Degeneration Conditions
#
# To modify the synthetic patient profile in order to reflect both heart attack (myocardial infarction) and age-related macular degeneration (AMD), it's imperative to consider the relevant comorbidities and risk factors associated with these conditions. Recent research and scholarly articles provide insights into the intersection of cardiovascular disease and AMD, as well as their shared risk factors. Below is a synthesis of findings from various studies and sources.
#
# #### Heart Attack Risk Factors
#
# 1. **Cholesterol Levels and Lipid Management**
#    - Studies such as the FOURIER-OLE trial emphasize the relationship between sustained low LDL cholesterol levels and reduced cardiovascular risks (PubMed: [36779348](https://pubmed.ncbi.nlm.nih.gov/36779348/)).
#
# 2. **Body Mass Index and Metabolic Markers**
#    - Metabolomic phenotyping has shown that body mass index (BMI) is crucial in profiling cardiovascular risks, including myocardial infarction (PubMed: [37308902](https://pubmed.ncbi.nlm.nih.gov/37308902/)).
#
# #### Age-related Macular Degeneration (AMD) Risk Factors
#
# 1. **Visual Disability and Cardiovascular Disease**
#    - Research demonstrates a notable association between AMD with visual impairment and heightened risks of myocardial infarction and overall cerebrovascular diseases (PubMed: [37119082](https://pubmed.ncbi.nlm.nih.gov/37119082/)).
#
# 2. **Obesity and Comorbidities**
#    - The relationship between obesity, metabolic BMI, and risks of both AMD and cardiovascular diseases underscores the importance of metabolic health in these patients (PubMed: [37308902](https://pubmed.ncbi.nlm.nih.gov/37308902/)).
#
# #### Intersection of Heart Disease and AMD
#
# 1. **Comorbidity Challenges**
#    - Studies reveal a significant overlap in risk factors for AMD and cardiovascular diseases, further complicating patient profiles and necessitating comprehensive management strategies (PubMed: [19516892](https://pubmed.ncbi.nlm.nih.gov/19516892/)).
#
# 2. **Potential for Shared Pathophysiology**
#    - There is evidence to suggest shared pathophysiological pathways in the development of AMD and cardiovascular diseases, demanding integrated care strategies for individuals displaying both conditions.
#
# #### Recommendations for a Synthetic Patient Profile
#
# ...
#    - **Endothelial Glycocalyx**: Evidence of degradation due to chronic hyperglycemia, leading to increased vascular permeability.
#
# 2. **Technological Monitoring**:
#    - **Glucose Monitoring**: Utilizes advanced glucose sensors for real-time monitoring, though adherence is inconsistent, affecting management effectiveness.
#
# 3. **Lifestyle and Behavioral Factors**:
#    - **Diet**: High in carbohydrates and saturated fats, exacerbating glucose dysregulation.
#    - **Physical Activity**: Sedentary lifestyle, contributing to poor metabolic control.
#
# #### Conclusion
#
# This synthetic patient profile illustrates a high-risk individual for retinal vascular occlusion due to persistently high glucose levels and associated metabolic dysfunctions. It underscores the need for comprehensive management strategies, including optimized glucose control, inflammation reduction, and lifestyle modifications. This profile can serve as a model for developing targeted interventions and evaluating the efficacy of new technologies in managing complex conditions like RVO in diabetic patients.
#
# ---
#
# This synthesized profile is based on current research and data insights, and should be adapted as new findings emerge to refine the understanding of high glucose impacts on retinal health.
#
# 🛠️ Executing with agent: `summarising_agent` on task: Summarise all findings from previous steps into a concise synthesis with key quantitative takeaways and limitations
# ==================================
# 🧠 Summarising Agent
# ==================================
# ✅ Output:
# ### Key Findings
#
# 1. **Glucose and Retinal Vascular Occlusion**:
#    - Persistent hyperglycemia is linked to diabetic retinopathy and retinal vascular occlusion through inflammation and endothelial dysfunction.
#    - The TyG index, a marker of insulin resistance, is significant in assessing the risk for retinal vein occlusion.
#    - Elevated homocysteine levels, often due to folate deficiency, are risk factors for retinal vascular diseases.
#
# 2. **Demographics and Disease Prevalence**:
#    - Retinal diseases, including diabetic retinopathy, predominantly affect males over 60, with a prevalence increase with age.
#    - Diabetic retinopathy accounts for about 60.84% of retinal disease cases, with a male predominance of 73.65%.
#
# 3. **Technological Advances**:
#    - Non-enzymatic glucose sensors using graphene heterostructures show promise for continuous glucose monitoring, critical for managing at-risk populations.
#
# 4. **Synthetic Patient Profile**:
#    - A typical high-risk patient is a 65-year-old male with type 2 diabetes, poor glucose management, and a history of retinal vascular occlusion.
#    - Key indicators include elevated HbA1c (around 8.5%), high TyG index, and elevated homocysteine levels.
#
# ### Conclusions
#
# - The relationship between glucose levels and retinal vascular occlusion is complex, involving metabolic, physiological, and lifestyle factors.
# - Effective management requires comprehensive strategies, including optimized glucose control, inflammation reduction, and lifestyle modifications.
# - Technological advancements in glucose monitoring can aid in better management and prevention of retinal vascular diseases.
# - Further research is needed to refine synthetic patient profiles and develop targeted interventions for high-risk individuals.
#
# ### Limitations
#
# - The findings are based on existing studies and may not encompass all variables affecting retinal vascular occlusion.
# - Synthetic patient profiles are generalized and may not represent all individual variations or comorbid conditions.
# - Continuous updates and research are necessary to adapt to new insights and technological advancements.
#
# ======================================================================
# Final output for Question 1
# Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ### Key Findings
#
# #### PR Interval and Cholesterol
# - **PR Interval**: The PR interval, a crucial ECG component, reflects atrial to ventricular conduction time. Prolonged PR intervals are linked to adverse outcomes such as increased mortality and heart failure, particularly in patients undergoing cardiac resynchronization therapy and those with implanted devices.
# - **Cholesterol**: Cholesterol is vital for cellular structures and hormone synthesis. High LDL cholesterol is strongly associated with coronary heart disease, and lifestyle modifications are essential for management. Cationic cholesterol shows promise in enhancing mRNA delivery for therapeutic applications.
#
# #### Machine Learning Applications
# - **PR Interval**: Machine learning models using ECG data improve predictions of cardiovascular outcomes, offering enhanced diagnostic accuracy over traditional methods.
# - **Cholesterol**: Predictive models for cholesterol levels aid in early intervention, while machine learning assists in differentiating gallbladder polyp types.
# - **Broader Applications**: Machine learning frameworks are advancing in biology, emphasizing model validation and real-time data stream processing for clinical applications.
#
# #### Synthetic Baseline Patient Model
# - **General Model**: Utilizes average health statistics to simulate typical patient profiles, aiding in research and treatment development.
# - **Modified Model**: Focuses on high PR interval and cholesterol, reflecting common cardiovascular risk profiles. This model aids in studying the effects of interventions and disease progression.
#
# ### Conclusions
#
# - The integration of machine learning with cardiovascular metrics like the PR interval and cholesterol levels is transforming diagnostics and risk assessment, offering personalized therapeutic strategies.
# - Synthetic patient models, particularly those incorporating specific conditions like high PR interval and cholesterol, provide valuable insights into cardiovascular health and facilitate the testing of targeted interventions.
# - Future research should enhance these models with real-world data and expand their applicability across diverse populations to improve predictive accuracy and healthcare outcomes.
# ======================================================================
# Final output for Question 2
# Does Heart Attack AND Age-Related Macular Degeneration (Am affect your likelihood of Type 2 Diabetes?
# ======================================================================
# **Key Findings**
#
# 1. **Heart Attack:**
#    - **Cholesterol Levels:** Lower LDL cholesterol levels (<20 mg/dL) are linked to reduced cardiovascular risk. Personalized lipid-lowering strategies improve LDL-C management and reduce major cardiovascular events.
#    - **Risk Factors:** High blood pressure, smoking, physical inactivity, obesity, and diabetes are significant contributors.
#
# 2. **Age-related Macular Degeneration (AMD):**
#    - **Age and Lifestyle:** Older age and lifestyle factors, such as smoking and dietary habits, are significant risk factors. Melatonin usage may reduce AMD risk.
#    - **Genetic Factors:** Family history increases susceptibility.
#
# 3. **Type 2 Diabetes (T2D):**
#    - **Insulin Resistance and Obesity:** Central obesity and sedentary lifestyle are key risk factors. Metabolic markers, including phospholipid metabolites, offer insights into obesity-associated insulin resistance.
#    - **Genetic Influence:** Family history plays a critical role.
#
# 4. **Intersection of Heart Disease and AMD:**
#    - **Comorbidities:** Shared risk factors and potential pathophysiological pathways exist between AMD and cardiovascular diseases, necessitating integrated care strategies.
#
# **Conclusions**
#
# - **Synthetic Patient Profile:** A baseline synthetic patient should consider LDL cholesterol levels below 55 mg/dL, incorporate obesity-related metabolic markers, and account for age and visual impairment risks. Lifestyle modifications are crucial for managing shared risk factors.
#
# - **Quantitative Takeaways:** Achieving LDL levels <20 mg/dL significantly reduces cardiovascular risks. Lifestyle interventions, such as melatonin, may lower AMD progression risk.
#
# - **Limitations:** The synthesis relies on data from academic studies and may not fully capture the complexity of individual patient profiles. Further research and real-world data are needed to refine synthetic patient models and ensure alignment with clinical outcomes.
# ======================================================================
# Final output for Question 3
# Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?
# ======================================================================
# **Key Findings**
#
# 1. **Blood Glucose and Diabetes Severity**: Blood glucose levels are crucial for energy production and are tightly regulated in the body. Chronic elevations in blood glucose, or hyperglycemia, are linked to diabetes mellitus and its complications, such as heart disease, stroke, and kidney failure.
#
# 2. **Monitoring and Management**: Continuous Glucose Monitoring (CGM) systems and machine learning models are instrumental in predicting and managing blood glucose levels, improving diabetes management.
#
# 3. **Insulin Regulation**: Effective blood glucose regulation is achieved through insulin and glucagon therapies, with research supporting both single and dual therapy approaches.
#
# 4. **Comorbidities and Lifestyle Factors**: Diabetes often coexists with other health issues, complicating management. Factors like genetics, diet, obesity, and conditions such as PCOS impact blood glucose levels and diabetes severity.
#
# 5. **Synthetic Patient Profile**: A baseline synthetic patient profile was created, focusing on a patient with high blood glucose levels but no comorbid conditions. This profile aids in understanding diabetes severity in isolation and evaluating management strategies.
#
# 6. **Data Sources for Synthetic Profiles**: Various datasets provide median glucose levels and other health metrics, essential for constructing synthetic patient profiles and modeling diabetes management.
#
# **Conclusions**
#
# - **Quantitative Takeaways**:
#   - Median glucose levels for healthy individuals are 107 mg/dL, while for diabetics, it is 140 mg/dL.
#   - The synthetic patient profile includes a fasting blood glucose of 180 mg/dL, postprandial glucose of 250 mg/dL, and HbA1c of 8.5%.
#
# - **Limitations**:
#   - The synthetic patient profile isolates high blood glucose without considering the complex interplay of comorbid conditions.
#   - Data and findings are based on existing datasets and may not capture all real-world variabilities.
#
# This synthesis highlights the importance of understanding and managing blood glucose levels to control diabetes severity and improve patient outcomes. It also underscores the need for further research to develop comprehensive diabetes management strategies that consider both isolated and comorbid conditions.
# ======================================================================
# Final output for Question 4
# Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ### Key Findings
#
# 1. **Sleep Patterns and Type 2 Diabetes (T2D)**
#    - Short sleep duration (<5 hours) significantly increases the risk of developing T2D compared to normal sleep durations (7-8 hours).
#    - Irregular sleep patterns, as measured by accelerometers, also elevate T2D risk, particularly in individuals with a lower genetic predisposition.
#    - Obstructive Sleep Apnea (OSA) is linked to abnormal glucose metabolism and T2D, though treatment results with CPAP are mixed.
#    - Fetal and pediatric sleep studies suggest early sleep disturbances could contribute to adult metabolic disorders like T2D.
#
# 2. **Predictive Modeling and Machine Learning**
#    - Machine learning models using electronic medical records can predict T2D risk, with enhanced outcomes when incorporating sleep and behavioral factors.
#
# 3. **Synthetic Patient Data Generation**
#    - Techniques like binary dataset generation and models ensuring fairness and privacy (e.g., FFPDG) are crucial for creating realistic synthetic patient data.
#    - Methods such as MCRAGE help balance imbalanced datasets, improving the fairness and efficacy of healthcare prediction models.
#
# 4. **Modifying Synthetic Patient Data**
#    - Adjusting synthetic data to reflect high sleep duration (>9 hours) and absence of other medical conditions allows focused analysis on sleep's impact on health outcomes.
#
# ### Conclusions
#
# - **Sleep and T2D**: Sleep duration and regularity are critical factors influencing T2D risk, necessitating public health strategies to improve sleep hygiene.
# - **Machine Learning**: Predictive models incorporating sleep data can enhance T2D risk assessment, though practical application requires robust computational environments.
# - **Synthetic Data**: Generating synthetic patient data with considerations for realism, privacy, and fairness is vital for research without compromising patient privacy.
# - **Data Modification**: Modifying synthetic data to isolate specific variables like sleep duration is essential for precise analysis in health outcome studies.
#
# ### Limitations
#
# - The complexity of interactions between sleep disorders and T2D requires further longitudinal and objective studies.
# - Machine learning models need continuous validation against comprehensive datasets to ensure alignment with scientific insights.
# - Synthetic data generation methods must continually address biases and computational challenges to remain effective in real-world applications.
# ======================================================================
# Final output for Question 5
# Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ### Key Findings
#
# 1. **Glucose and Retinal Vascular Occlusion**:
#    - Persistent hyperglycemia is linked to diabetic retinopathy and retinal vascular occlusion through inflammation and endothelial dysfunction.
#    - The TyG index, a marker of insulin resistance, is significant in assessing the risk for retinal vein occlusion.
#    - Elevated homocysteine levels, often due to folate deficiency, are risk factors for retinal vascular diseases.
#
# 2. **Demographics and Disease Prevalence**:
#    - Retinal diseases, including diabetic retinopathy, predominantly affect males over 60, with a prevalence increase with age.
#    - Diabetic retinopathy accounts for about 60.84% of retinal disease cases, with a male predominance of 73.65%.
#
# 3. **Technological Advances**:
#    - Non-enzymatic glucose sensors using graphene heterostructures show promise for continuous glucose monitoring, critical for managing at-risk populations.
#
# 4. **Synthetic Patient Profile**:
#    - A typical high-risk patient is a 65-year-old male with type 2 diabetes, poor glucose management, and a history of retinal vascular occlusion.
#    - Key indicators include elevated HbA1c (around 8.5%), high TyG index, and elevated homocysteine levels.
#
# ### Conclusions
#
# - The relationship between glucose levels and retinal vascular occlusion is complex, involving metabolic, physiological, and lifestyle factors.
# - Effective management requires comprehensive strategies, including optimized glucose control, inflammation reduction, and lifestyle modifications.
# - Technological advancements in glucose monitoring can aid in better management and prevention of retinal vascular diseases.
# - Further research is needed to refine synthetic patient profiles and develop targeted interventions for high-risk individuals.
#
# ### Limitations
#
# - The findings are based on existing studies and may not encompass all variables affecting retinal vascular occlusion.
# - Synthetic patient profiles are generalized and may not represent all individual variations or comorbid conditions.
# - Continuous updates and research are necessary to adapt to new insights and technological advancements.

# %% [markdown]
# ## Summary

# %%
from IPython.display import Markdown, display
import pandas as pd

def build_summary_context(history, max_chars=4000):
    parts = []
    for i, (step, agent, output) in enumerate(history):
        parts.append(
            f"Step {i+1}\n"
            f"Output: {str(output)[:800]}"
        )
    text = "\n\n".join(parts)
    return text[-max_chars:]


def make_question_text(r):
    left = f"{r['level1']} {r['var1']}" if r["level1"] is not None else r["var1"]
    right = f"{r['level2']} {r['var2']}" if r["level2"] is not None else r["var2"]
    return f"Does {left} AND {right} affect your likelihood of Type 2 Diabetes?"

# %%
from IPython.display import Markdown, display

all_final_outputs = []

for run in executor_runs:
    hypothesis = run["question_vars"]
    executor_history = run["executor_history"]

    summary_context = build_summary_context(executor_history)

    final_task = f"""
Hypothesis:
{hypothesis}

Context from previous agent outputs:
{summary_context}

Produce a final answer in exactly this format:

In the OpenAI model,

({hypothesis}) is <description1> to change the predicted T2DM severity.

The first variable showed:
<summary>

The second variable showed:
<summary>

The combination of the variables showed:
<summary>

Therefore, this hypothesis is <description2> to meaningfully affect likelihood of T2DM.

Prediction certainty: <High / Moderate / Low>

Model reliability: <High / Moderate / Low>
"""

    final_output = final_summary_agent(final_task)

    all_final_outputs.append({
        "question_num": run["question_num"],
        "hypothesis": hypothesis,
        "final_output": final_output
    })

    print("\n" + "=" * 70)
    print(f"Question {run['question_num']}")
    print(hypothesis)
    print("=" * 70)
    display(Markdown(final_output))
# Out:
# ==================================
# 🧾 Final Summary Agent
# ==================================
#
# ======================================================================
# Question 1
# Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?
# ======================================================================
# In the OpenAI model,
#
# (Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?) is not clearly likely to change the predicted T2DM severity.
#
# The first variable showed:
# The PR interval, particularly when prolonged, is associated with adverse cardiovascular outcomes such as increased mortality and heart failure. However, there is no direct evidence linking a high PR interval to an increased likelihood of Type 2 Diabetes Mellitus.
#
# The second variable showed:
# High cholesterol, especially elevated LDL cholesterol, is strongly associated with coronary heart disease. While lifestyle modifications for cholesterol management are crucial, there is no direct evidence provided linking high cholesterol to an increased likelihood of Type 2 Diabetes Mellitus.
#
# The combination of the variables showed:
# There is no clear evidence or research provided that directly links the combination of a high PR interval and high cholesterol to an increased likelihood of Type 2 Diabetes Mellitus. The effects on cardiovascular health are noted, but not specifically on T2DM.
#
# Therefore, this hypothesis is insufficiently supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ==================================
# 🧾 Final Summary Agent
# ==================================
#
# ======================================================================
# Question 2
# Does Heart Attack AND Age-Related Macular Degeneration (Am affect your likelihood of Type 2 Diabetes?
# ======================================================================
# In the OpenAI model,
#
# (Does Heart Attack AND Age-Related Macular Degeneration (AMD) affect your likelihood of Type 2 Diabetes?) is not clearly likely to change the predicted T2DM severity.
#
# The first variable showed:
# Heart attacks are associated with risk factors such as high LDL cholesterol levels, high blood pressure, smoking, physical inactivity, obesity, and diabetes, which are significant contributors to cardiovascular risk.
#
# The second variable showed:
# Age-related macular degeneration is influenced by older age, lifestyle factors like smoking and dietary habits, and genetic factors. There is no direct evidence linking AMD to T2DM in the provided context.
#
# The combination of the variables showed:
# There is no clear evidence in the provided context that the combination of heart attack and AMD directly affects the likelihood of developing T2DM. The shared risk factors like smoking and obesity may indirectly relate to T2DM, but this is not explicitly supported by the evidence.
#
# Therefore, this hypothesis is insufficiently supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ==================================
# 🧾 Final Summary Agent
# ==================================
#
# ======================================================================
# Question 3
# Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?
# ======================================================================
# In the OpenAI model,
#
# (Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?) is likely to change the predicted T2DM severity.
#
# The first variable showed:
# High blood glucose levels are crucial for energy production and are tightly regulated in the body. Chronic elevations in blood glucose, or hyperglycemia, are linked to diabetes mellitus and its complications, such as heart disease, stroke, and kidney failure.
#
# The second variable showed:
# The term "None" is unclear in this context, but it seems to imply the absence of other comorbid conditions. There is no direct evidence provided on how the absence of comorbid conditions alone affects T2DM likelihood.
#
# The combination of the variables showed:
# The combination of high blood glucose with no additional comorbid conditions primarily highlights the impact of hyperglycemia on diabetes severity. The effect is mostly driven by the high blood glucose levels.
#
# Therefore, this hypothesis is moderately supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Moderate
#
# Model reliability: Moderate
# ==================================
# 🧾 Final Summary Agent
# ==================================
#
# ======================================================================
# Question 4
# Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?
# ======================================================================
# In the OpenAI model,
#
# (Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# High sleep duration, typically more than 9 hours, was not directly linked to increased T2DM risk. Most research focuses on short sleep duration as a risk factor.
#
# The second variable showed:
# The absence of additional medical conditions was intended to isolate the effect of sleep duration, but no specific evidence was provided regarding its impact on T2DM risk.
#
# The combination of the variables showed:
# There is insufficient evidence to suggest that high sleep duration without other medical conditions significantly affects T2DM likelihood. The focus on short sleep duration as a risk factor is more prevalent in existing research.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ==================================
# 🧾 Final Summary Agent
# ==================================
#
# ======================================================================
# Question 5
# Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?
# ======================================================================
# In the OpenAI model,
#
# (Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# Persistent hyperglycemia is linked to diabetic retinopathy and retinal vascular occlusion through inflammation and endothelial dysfunction, indicating a connection to retinal diseases but not directly altering T2DM severity.
#
# The second variable showed:
# Retinal vascular occlusion is influenced by metabolic factors like insulin resistance and elevated homocysteine levels, which are risk factors for retinal diseases but do not directly impact T2DM severity.
#
# The combination of the variables showed:
# While both high glucose levels and retinal vascular occlusion are associated with retinal diseases, there is no clear evidence that their combination directly affects the likelihood or severity of T2DM.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Moderate

# %% [markdown]
# # End of Part 2

# %% [markdown]
# # Start of Part 3

# %%
df=master

# %% [markdown]
# ## Part 3A

# %%
def generate_dataframe_code_agent(task: str, model: str = "openai:o4-mini") -> str:
    """
    Generates Python pandas code for a specific dataframe manipulation task.

    Args:
        task (str): The dataframe task to generate code for.
        model (str): Language model to use.

    Returns:
        str: Python code as a string.
    """
    user_prompt = f"""
You are a Python data-processing assistant.

Write ONLY valid Python code.
Do not include explanations.
Do not include markdown fences.
Assume `df` already exists as a pandas DataFrame.

Rules:
- Produce executable pandas code.
- Prefer clear variable names.
- Add short comments for each section.
- Print useful diagnostics when appropriate.
- Do not redefine df.
- Do not import unnecessary packages.

Task: Write pandas code to convert these one-hot columns into a single multiclass target y:
- study_group_healthy
- study_group_pre_diabetes_lifestyle_controlled
- study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled
- study_group_insulin_dependent

Requirements:
- Cast the columns to int
- Verify each row has exactly one active class
- Print invalid row count where sum != 1
- Create:
    class_names = ["healthy", "prediabetes", "oral_medicated", "insulin_dependent"]
- Create y as the class index using idxmax or numpy
- Print y value counts
- Print df shape and columns before split
- Return only Python code
"""
    messages = [{"role": "user", "content": user_prompt}]

    response = CLIENT.chat.completions.create(
        model=model,
        messages=messages,
        temperature=1
    )

    code_str = response.choices[0].message.content.strip()
    return code_str

# %% [markdown]
# B

# %%
def generate_target_code_agent(model: str = "openai:o4-mini") -> str:
    """
    Generates Python code for building y from the 4 one-hot target columns.
    """
    user_prompt = """
You are a Python machine learning assistant.

Write ONLY valid Python code.
Do not include explanations.
Do not include markdown fences.

Assume:
- `df` already exists as a pandas DataFrame

Your output must look very similar in style and structure to this format:
- section header comments
- short Goal comment
- exact variable name `target_cols`
- exact variable name `class_names`
- print diagnostics

You MUST generate code equivalent to this step:

#--------------------------------------
# 1.) Build y from one-hot cols
#----------------------------------------
#Goal: Turn 4 one-hot target columns into a single multi-class label

target_cols = [
    "study_group_healthy",
    "study_group_pre_diabetes_lifestyle_controlled",
    "study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled",
    "study_group_insulin_dependent"
]

df[target_cols] = df[target_cols].astype(int)
print(df[target_cols].sum(axis=1).value_counts())

class_names = ["healthy", "prediabetes", "oral_medicated", "insulin_dependent"]

row_sums = df[target_cols].sum(axis=1)
print(row_sums.value_counts())
print("Bad rows (sum!=1):", (row_sums != 1).sum())

##########################

print("just before split section df columns (n):", df.shape[1])
print(df.columns.tolist())

Rules:
- Use EXACTLY the 4 target column names shown above
- Use EXACTLY the 4 class names shown above
- Keep the same notebook-style formatting
- Keep the same comment style
- Do not add extra steps
- Return only Python code
"""

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=1,
    )

    return response.choices[0].message.content.strip()

# %% [markdown]
# C

# %%
def splitting_code_agent(model: str = "openai:o4-mini") -> str:
    """
   Build feature matrices and class labels using the datasets pre made split columns
    """
    user_prompt = """
You are a Python machine learning assistant.

Write ONLY valid Python code.
Do not include explanations.
Do not include markdown fences.

Assume:
- `df` already exists as a pandas DataFrame

Your output must look very similar in style and structure to this format:
- section header comments
- short Goal comment
- exact variable name `target_cols`
- exact variable name `class_names`
- print diagnostics

You MUST generate code equivalent to this step:

#---------------------------
# 2.) Train/Val/Test Split use provided splits
#---------------------------
#Goal: Build feature matrices and class labels using the datasets pre made split columns

train_df = df[df["split_train"] == 1].copy()
val_df   = df[df["split_val"] == 1].copy()
test_df  = df[df["split_test"] == 1].copy()

#removing the target one-hot columns
drop_cols = target_cols + ["participant_id", "recommended_split", "split_train", "split_val", "split_test", "target"]

#c is each column name, only include in the dataframe
X_train = train_df.drop(columns=[c for c in drop_cols if c in train_df.columns]).copy()
y_train = train_df[target_cols].values.argmax(axis=1)

# Make groups aligned with X_train rows
groups_train = train_df.loc[X_train.index, "participant_id"].to_numpy()

X_val = val_df.drop(columns=[c for c in drop_cols if c in val_df.columns]).copy()
y_val = val_df[target_cols].values.argmax(axis=1)

X_test = test_df.drop(columns=[c for c in drop_cols if c in test_df.columns]).copy()
y_test = test_df[target_cols].values.argmax(axis=1)

##############################

Rules:
- Use EXACTLY the 3 split column names shown above
- Keep the same notebook-style formatting
- Keep the same comment style
- Do not add extra steps
- Return only Python code
- Remove anything regarding 'targets' from X_train!
"""

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=1,
    )

    return response.choices[0].message.content.strip()

# %% [markdown]
# D

# %%
def generate_preprocessor_code_agent(model: str = "openai:o4-mini") -> str:
    """
    Generates Python code for preprocessing tabular data
    using numeric/categorical pipelines and a ColumnTransformer.
    """
    user_prompt = """
You are a Python machine learning coding assistant.

Write ONLY valid Python code.
Do not include explanations.
Do not include markdown fences.

Assume the following variables already exist:
- X_train
- X_val
- X_test
- y_train
- train_df
- target_cols
- np
- Pipeline
- SimpleImputer
- StandardScaler
- OneHotEncoder
- ColumnTransformer
- compute_class_weight

Task:
Write code for this pipeline step in a clean notebook style.

Required behavior:
1. Identify numeric and categorical features from X_train
   - numeric_features = X_train.select_dtypes(include=[np.number]).columns.tolist()
   - categorical_features = X_train.select_dtypes(exclude=[np.number]).columns.tolist()

2. Print diagnostics:
   - X_train columns
   - count of numeric features
   - first 20 numeric features
   - count of categorical features
   - first 20 categorical features

3. Build:
   - numeric_pipe with median imputation + StandardScaler
   - categorical_pipe with most_frequent imputation + OneHotEncoder(handle_unknown="ignore")

4. Build a ColumnTransformer named preprocessor with:
   - ("num", numeric_pipe, numeric_features)
   - ("cat", categorical_pipe, categorical_features)
   - remainder="drop"

5. Fit on X_train and transform X_train, X_val, X_test into:
   - X_train_p
   - X_val_p
   - X_test_p

6. If outputs are sparse, convert them to dense arrays using:
   - .toarray() if available

7. Compute balanced class weights from y_train using compute_class_weight
   - store in classes
   - store raw weights in weights
   - create final_cw = dict(zip(classes, weights))
   - cap each weight at 6.0
   - ensure values are floats

8. Print diagnostics:
   - np.bincount(y_train, minlength=4)
   - train_df[target_cols].sum().to_dict()

Style requirements:
- Use section comments in this exact style:
  # ----------------------------------
  # 3.) Preprocessor
  # ------------------------------------
- Include a short Goal comment
- Keep the code compact but readable
- Return only Python code
"""

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=1,
    )

    return response.choices[0].message.content.strip()

# %% [markdown]
# E

# %%
def generate_best_mlp_agent(task: str, model: str = "openai:o4-mini") -> str:
    user_prompt = f"""
You are an expert tabular deep learning engineer.

Your job is to design the best-performing MLP pipeline for this task:

{task}

Context:
- This is a multiclass classification problem with 4 classes.
- The data has already been preprocessed.
- Data is already split into train/validation/test.
- The solution must be practical, reproducible, and aimed at maximizing validation performance.
- Use ONLY these existing variables:
  - X_train_p
  - X_val_p
  - X_test_p
  - y_train
  - y_val
  - y_test
  - np
  - tf
- Class weights may already exist as `final_cw`.
- Do NOT redefine X_train, X_val, X_test.

Optimization objective:
- Maximize validation macro F1 score.
- Secondary goals: stable training, reasonable training time, and good minority-class performance.

You must produce Python code that defines BOTH:
1. A reusable function exactly named:
   build_mlp
2. A Python dictionary exactly named:
   best_params

Requirements:
1. Define a reusable function exactly named build_mlp with EXACTLY this signature:

def build_mlp(
    n_in,
    n_out=4,
    hidden_units=[256, 128, 64],
    dropout_rates=[0.3, 0.3, 0.2],
    activation="relu",
    normalization="batch",
    lr=1e-3,
    optimizer_name="adam",
    loss_name="sparse_categorical_crossentropy"
):

2. Do not rename these arguments.
3. Later pipeline steps will call build_mlp using n_in and n_out.
4. Use n_in to set the input shape.
5. Use n_out to set the output layer size.
6. The final output layer MUST be:
   tf.keras.layers.Dense(n_out, activation="softmax")
7. The model MUST compile with:
   - loss="sparse_categorical_crossentropy"
   - metrics=["accuracy"]
8. Do NOT use tf.keras.metrics.Precision, tf.keras.metrics.Recall, tf.keras.metrics.AUC, TopK metrics, or confusion-matrix-based metrics.
9. Do NOT use categorical_crossentropy, binary_crossentropy, or one-hot labels.
10. Store the winning hyperparameters in best_params using these exact keys:
   - hidden_units
   - dropout_rates
   - activation
   - normalization
   - lr
   - optimizer_name
   - loss_name
   - batch_size

11. Use the existing preprocessed matrices only.
12. Do not create a preprocessing pipeline.
13. Do not use OneHotEncoder.
14. Do not use ColumnTransformer.
15. Use early stopping.
16. Track results for all tried configurations.
17. Choose the best model using validation macro F1 computed AFTER prediction on y_val:
   - get validation probabilities from model.predict(X_val_p)
   - convert to predicted class ids with argmax(axis=1)
   - compute macro F1 from y_val and predicted labels
18. Evaluate the selected best model on validation and test sets.
19. Print a concise summary of why the selected configuration won.
20. build_mlp and best_params must remain available in scope.

Rules:
- Return ONLY valid Python code.
- Do not include markdown fences.
- Assume standard ML Python libraries are available.
- Prefer robust, realistic defaults over overly experimental choices.
- Include comments.
- If loss_name is "sparse_categorical_crossentropy", do not pass label_smoothing.
- Use plain "sparse_categorical_crossentropy" or tf.keras.losses.SparseCategoricalCrossentropy() with no extra arguments.
- Make the code deterministic where practical by setting random seeds.
"""
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=1,
    )
    return response.choices[0].message.content.strip()

# %%
def generate_groupkfold_code_agent(model: str = "openai:o4-mini") -> str:
    """
    Generates Python code for GroupKFold cross-validation
    with preprocessing inside each fold and MLP training.
    """
    user_prompt = """
You are a Python machine learning coding assistant.

Write ONLY valid Python code.
Do not include explanations.
Do not include markdown fences.

Assume these variables already exist:
- X_train
- y_train
- groups_train
- preprocessor
- build_mlp
- np
- GroupKFold
- compute_class_weight
- EarlyStopping
- accuracy_score
- f1_score

Task:
Write code for this exact notebook section:

# --------------------------
# 5.) GroupKFold CV
# --------------------------
# Goal: Estimate performance robustly while preventing leakage between related samples

Requirements:
1. Create:
   - gkf = GroupKFold(n_splits=5)
   - fold_acc, fold_f1 = [], []

2. Loop over:
   - for fold, (tr_idx, va_idx) in enumerate(gkf.split(X_train, y_train, groups=groups_train), start=1):

3. Inside each fold:
   - create X_tr, X_va using X_train.iloc[tr_idx] and X_train.iloc[va_idx]
   - create y_tr, y_va using y_train indexing (NO ".iloc" is need for y_train)
   - fit preprocessor on X_tr only
   - transform X_tr and X_va
   - densify sparse matrices with toarray() if available

4. Compute balanced class weights from y_tr
   - create classes = np.unique(y_tr)
   - compute weights using:
     compute_class_weight(class_weight="balanced", classes=classes, y=y_tr)
   - create final_cw from dict(zip(classes, weights))
   - cap weights at 4.5
   - print class_weight
   
5. Build and train the MLP:
   - build the model exactly like this pattern:

     mlp = build_mlp(
         n_in=X_tr_p.shape[1],
         n_out=4,
         hidden_units=best_params.get("hidden_units", [256, 128, 64]),
         dropout_rates=best_params.get("dropout_rates", [0.3, 0.3, 0.2]),
         activation=best_params.get("activation", "relu"),
         normalization=best_params.get("normalization", "batch"),
         lr=best_params.get("lr", 1e-3),
         optimizer_name=best_params.get("optimizer_name", "adam"),
         loss_name=best_params.get("loss_name", "sparse_categorical_crossentropy"),
     )

   - create:
     early_stop = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

   - create:
     reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-5)

   - set:
     batch_size = best_params.get("batch_size", 32)

   - fit with:
       class_weight=final_cw
       validation_data=(X_va_p, y_va)
       epochs=best_params.get("epochs", 200)
       batch_size=batch_size
       callbacks=[early_stop, reduce_lr]
       verbose=0     
    
6. Predict probabilities on X_va_p

7. For thresholds [0.20, 0.25, 0.30, 0.35]:
   - create y_pred from argmax
   - override class to 3 where probs[:, 3] > t
   - compute insulin recall using recall_score(y_va, y_pred, labels=[3], average=None)[0]
   - print threshold and insulin recall

8. Then choose one fixed threshold t = 0.30 to score fold metrics:
   - y_pred = np.argmax(probs, axis=1)
   - y_pred[probs[:, 3] > t] = 3
   - append accuracy_score to fold_acc
   - append weighted f1_score to fold_f1

9. Then print insulin precision, recall, and f1 for thresholds [0.20, 0.25, 0.30, 0.35]
   - import precision_score, recall_score, f1_score locally before this block
   - compute and print insulin P/R/F1

10. After all folds, print:
   - CV mean and std for accuracy
   - CV mean and std for weighted F1

11. Also create feedback variables:
    - cv_summary: a dictionary containing the computed mean/std metrics
    - cv_feedback: a dictionary summarizing the main weakness and priority
    - round_score = cv_summary["mean_f1"]

Example structure only (do not hardcode values):
   -    cv_summary = {
        "mean_acc": 0.981,
        "std_acc": 0.015,
        "mean_f1": 0.982,
        "std_f1": 0.014,
        "mean_insulin_recall_030": 0.74,
        "mean_insulin_precision_030": 0.89,
        "mean_insulin_f1_030": 0.80,}

    - cv_feedback = {
    "main_issue": "low insulin recall" if mean_insulin_recall_030 < threshold else "balanced",
    "priority": "improve class 3 recall without collapsing precision",
    "fold_f1": [...]
}

   -round_score = cv_summary["mean_f1"]
   
Style requirements:
- Keep formatting similar to a clean notebook
- Include short comments
- Return only Python code
"""

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=1,
    )

    return response.choices[0].message.content.strip()

# %% [markdown]
# F

# %%
def revise_mlp_agent(task: str, prior_code: str, cv_summary: dict, cv_feedback: dict, model: str = "openai:o4-mini") -> str:
    user_prompt = f"""
You are a Python machine learning coding assistant.

Write ONLY valid Python code.
Do not include explanations.
Do not include markdown fences.

Task:
Improve the current MLP for a 4-class tabular classification problem.

Current objective:
{task}

Current MLP code:
{prior_code}

Cross-validation summary:
{cv_summary}

Cross-validation feedback:
{cv_feedback}

Requirements:
1. Return only Python code.
2. Define:
   - build_mlp
   - best_params
3. Keep the same function signature expected by the notebook.
4. Try to improve weighted F1, but specifically address:
   - insulin_dependent recall
   - confusion with oral_medicated
5. Prefer stable, realistic changes:
   - hidden_units
   - dropout_rates
   - lr
   - batch_size
   - normalization
   - optimizer_name
   - loss_name
6. Do not invent new external dependencies.

Compatibility requirement:
- Do not use label_smoothing with SparseCategoricalCrossentropy.
- Use plain "sparse_categorical_crossentropy" or tf.keras.losses.SparseCategoricalCrossentropy() with no extra arguments.

"""
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=1,
    )
    return response.choices[0].message.content.strip()

# %% [markdown]
# G

# %%
def run_mlp_feedback_loop(scope, initial_mlp_code, n_rounds=3, task="Improve the MLP"):
    best_code = initial_mlp_code
    best_score = -1
    best_cv_summary = None
    best_cv_feedback = None
    round_history = []

    mlp_code = initial_mlp_code

    for round_idx in range(1, n_rounds + 1):
        print(f"\n=== Feedback round {round_idx} ===")

        # load current MLP code into scope
        exec(mlp_code, scope)

        # run CV evaluation
        gkf_code = generate_groupkfold_code_agent()
        exec(gkf_code, scope)

        cv_summary = scope["cv_summary"]
        cv_feedback = scope["cv_feedback"]
        round_score = scope["round_score"]

        print("cv_summary:", cv_summary)
        print("cv_feedback:", cv_feedback)
        print("round_score:", round_score)

        round_history.append({
            "round": round_idx,
            "score": round_score,
            "cv_summary": cv_summary,
            "cv_feedback": cv_feedback,
            "mlp_code": mlp_code,
        })

        if round_score > best_score:
            best_score = round_score
            best_code = mlp_code
            best_cv_summary = cv_summary
            best_cv_feedback = cv_feedback

        if round_idx < n_rounds:
            mlp_code = revise_mlp_agent(
                task=task,
                prior_code=mlp_code,
                cv_summary=cv_summary,
                cv_feedback=cv_feedback,
            )

    return {
        "best_code": best_code,
        "best_score": best_score,
        "best_cv_summary": best_cv_summary,
        "best_cv_feedback": best_cv_feedback,
        "round_history": round_history,
    }

# %% [markdown]
# H

# %%
def generate_final_training_code_agent(model: str = "openai:o4-mini") -> str:
    """
    Generates Python code for final model training on TRAIN,
    early stopping on VAL, evaluation on TEST, and artifact saving.
    """
    user_prompt = """
You are a Python machine learning coding assistant.

Write ONLY valid Python code.
Do not include explanations.
Do not include markdown fences.

Assume these variables already exist:
- preprocessor
- X_train
- X_val
- X_test
- y_train
- y_val
- y_test
- build_mlp
- compute_class_weight
- EarlyStopping
- ReduceLROnPlateau
- np
- class_names

Task:
Write code for this notebook section:

# ------------------------
# 6.) Final Model Training
# -------------------------
# Goal: Train one final model on TRAIN, tune/early-stop on VAL, then evaluate on TEST

Requirements:
1. Fit the preprocessor on X_train only, then transform:
   - X_train_p
   - X_val_p
   - X_test_p

2. Convert sparse outputs to dense arrays using .toarray() if available.

3. Compute balanced class weights from y_train:
   - classes = np.unique(y_train)
   - weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_train)
   - final_cw = dict(zip(classes, weights))
   - cap each class weight at 6.0
   - keep values as floats

4. Build final model:
   - final_mlp = build_mlp(n_in=X_train_p.shape[1], n_out=4)

5. Create callbacks:
   - early_stop = EarlyStopping(monitor="val_accuracy", mode="max", patience=15, restore_best_weights=True)
   - reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-5)

6. Train final_mlp with:
   - X_train_p, y_train
   - validation_data=(X_val_p, y_val)
   - epochs=200
   - batch_size=32
   - callbacks=[early_stop, reduce_lr]
   - class_weight=final_cw
   - verbose=0

7. Predict on X_test_p and create:
   - y_test_pred = final_mlp.predict(X_test_p, verbose=0).argmax(axis=1)

8. Print:
   - predicted class counts using np.bincount(y_test_pred, minlength=4)
   - true class counts using np.bincount(y_test, minlength=4)

9. Add a subsection for saving artifacts with this exact section style:

# ---------------------------
# 6.1 ) Extra of saving
# ---------------------------

10. In the saving section:
   - import joblib
   - import os
   - create artifacts directory with os.makedirs("artifacts", exist_ok=True)
   - save fitted preprocessor to artifacts/preprocessor.joblib
   - save class_names to artifacts/class_names.joblib
   - save model weights to artifacts/final_mlp.weights.h5
   - print a short confirmation message

Style requirements:
- Keep formatting similar to a clean notebook
- Include short comments
- Return only Python code
"""

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=1,
    )

    return response.choices[0].message.content.strip()

# %% [markdown]
# I

# %%
def generate_test_evaluation_code_agent(model: str = "openai:o4-mini") -> str:
    """
    Generates Python code for held-out test evaluation
    of the final trained multiclass model.
    """
    user_prompt = """
You are a Python machine learning coding assistant.

Write ONLY valid Python code.
Do not include explanations.
Do not include markdown fences.

Assume these variables already exist:
- final_mlp
- X_test_p
- y_test
- class_names
- accuracy_score
- f1_score
- classification_report
- confusion_matrix
- ConfusionMatrixDisplay
- plt

Task:
Write code for this notebook section:

# ----------------------------
# 7) Held-out test evaluation
# ----------------------------
# Goal: Evaluate once on TEST (data the model never saw during training or early stopping)

Requirements:
1. Predict test classes:
   - y_test_pred = final_mlp.predict(X_test_p, verbose=0).argmax(axis=1)

2. Compute:
   - test_acc = accuracy_score(y_test, y_test_pred)
   - test_f1 = f1_score(y_test, y_test_pred, average="weighted")

3. Print:
   - a header line for final held-out test results
   - test accuracy formatted to 3 decimals
   - test weighted F1 formatted to 3 decimals
   - classification_report(y_test, y_test_pred, target_names=class_names, digits=3)

4. Build confusion matrix:
   - cm = confusion_matrix(y_test, y_test_pred)
   - disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
   - disp.plot(values_format="d", xticks_rotation=45)
   - plt.title("Confusion Matrix (Test)")
   - plt.show()

Style requirements:
- Keep formatting similar to a clean notebook
- Include short comments
- Return only Python code
"""

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=1,
    )

    return response.choices[0].message.content.strip()

# %% [markdown]
# J

# %%
def run_generated_pipeline(df):

    from sklearn.pipeline import Pipeline
    from sklearn.impute import SimpleImputer
    from sklearn.preprocessing import StandardScaler, OneHotEncoder
    from sklearn.compose import ColumnTransformer
    from sklearn.utils.class_weight import compute_class_weight
    from sklearn.model_selection import GroupKFold
    from sklearn.metrics import (
        accuracy_score,
        f1_score,
        precision_score,
        recall_score,
        classification_report,
        confusion_matrix,
        ConfusionMatrixDisplay,
    )
    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


    import numpy as np
    import pandas as pd
    import tensorflow as tf
    import matplotlib.pyplot as plt
    import scipy
    
    scope = {
    "df": df,    
    "np": np,
    "pd": pd,
    "tf": tf,    
    "plt": plt,   
    "scipy": scipy,
    "Pipeline": Pipeline,
    "SimpleImputer": SimpleImputer,
    "StandardScaler": StandardScaler,
    "OneHotEncoder": OneHotEncoder,
    "ColumnTransformer": ColumnTransformer,
    "compute_class_weight": compute_class_weight,
    "GroupKFold": GroupKFold,
    "accuracy_score": accuracy_score,
    "f1_score": f1_score,
    "precision_score": precision_score,
    "recall_score": recall_score,
    "classification_report": classification_report,
    "confusion_matrix": confusion_matrix,
    "ConfusionMatrixDisplay": ConfusionMatrixDisplay,
    "EarlyStopping": EarlyStopping,
    "ReduceLROnPlateau": ReduceLROnPlateau,
    }
        



    target_task = """
Build a multiclass target from these one-hot columns:
- study_group_healthy
- study_group_pre_diabetes_lifestyle_controlled
- study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled
- study_group_insulin_dependent

Requirements:
- Cast target columns to int
- Check row-wise sum across target columns
- Print how many rows are invalid where sum != 1
- Create a class_names list:
  ["healthy", "prediabetes", "oral_medicated", "insulin_dependent"]
- Print dataframe shape and column list before splitting
"""

    
    exec(generate_dataframe_code_agent(target_task), scope)
    exec(generate_target_code_agent(), scope)

    print("target_cols:", scope.get("target_cols"))
    print("len(target_cols):", len(scope.get("target_cols", [])))
    print("class_names:", scope.get("class_names"))
    print("matching cols in df:", [c for c in scope.get("target_cols", []) if c in df.columns])
    print("missing cols:", [c for c in scope.get("target_cols", []) if c not in df.columns])

    
    exec(splitting_code_agent(), scope)
    exec(generate_preprocessor_code_agent(), scope)

    ###############
    mlp_code= generate_best_mlp_agent(task = "Find the best MLP for this multiclass tabular classification task")
    exec(mlp_code, scope)

    print(type(scope["X_train"]))
    print(type(scope["y_train"]))

    #########################################
    exec(generate_groupkfold_code_agent(), scope)
    cv_summary = scope["cv_summary"]
    cv_feedback = scope["cv_feedback"]
    round_score = scope["round_score"]

    mlp_code = revise_mlp_agent(
    task="Improve the MLP",
    prior_code=mlp_code,
    cv_summary=cv_summary,
    cv_feedback=cv_feedback
    )

    print(scope["best_params"])
    print(type(scope["best_params"]["hidden_units"][0]))
    print(scope["best_params"]["hidden_units"])

    exec(mlp_code, scope)

    ###############################
    feedback_result = run_mlp_feedback_loop(
        scope=scope,
        initial_mlp_code=mlp_code,
        n_rounds=3,
        task="Find the best MLP for this multiclass tabular classification task",
    )

    best_mlp_code = feedback_result["best_code"]

    #scope = globals().copy()
    exec(best_mlp_code, scope)

    build_mlp = scope["build_mlp"]
    best_params = scope["best_params"]

    print("Best CV summary:")
    print(feedback_result["best_cv_summary"])

    ##########################
    exec(generate_final_training_code_agent(), scope)
    exec(generate_test_evaluation_code_agent(), scope)

    return scope

# %% [markdown]
# K

# %%
scope = run_generated_pipeline(df)
# Out:
# DataFrame shape: (1077, 56)
# Columns: ['participant_id', 'Age', 'study_group_healthy', 'study_group_insulin_dependent', 'study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled', 'study_group_pre_diabetes_lifestyle_controlled', 'split_test', 'split_train', 'split_val', 'Heart Rate Pulse', 'Oxygen Saturation', 'Physical Activity', 'Sleep', 'Stress', 'Respiratory Rate', 'Blood Glucose', 'PR Interval', 'Age-Related Macular Degeneration (Am', 'Arthritis (Joint Pain)', 'Cancer (Any Type)', 'Cataracts (In One Or Both Eyes)', 'Chronic Pulmonary (Lung) Problems (E', 'Circulation Problems (Examples: Art', "Dementia (Examples: Alzheimer'S Disea", 'Diabetic Retinopathy (In One Or Both', 'Digestive Problems (Examples: Stomach', 'Do You Use Marijuana Now?', 'Dry Eye (In One Or Both Eyes)', 'Elevated A1C Levels (Elevated Blood Sugar', 'Glaucoma (In One Or Both Eyes)', 'Hearing Impairment', 'Heart Attack', 'High Blood Cholesterol', 'High Blood Pressure', 'Kidney Problems', 'Low Blood Pressure', 'Mild Cognitive Impairment (Known As', 'Multiple Sclerosis', 'Obesity', 'Osteoporosis', 'Other Heart Issues (Examples: Pace', 'Other Neurological Conditions', "Parkinson'S Disease", 'Pre-Diabetes', 'Retinal Vascular Occlusion ("Stroke', 'Stroke', 'Type Ii Diabetes', 'Urinary Problems (Examples: Urinary T', 'BMI', 'Cholesterol', 'Glucose', 'HbA1c', 'Height', 'Insulin', 'RBC', 'WBC']
# Invalid rows with sum != 1: 0
# y value counts:
# 0 (healthy): 375
# 1 (prediabetes): 244
# 2 (oral_medicated): 327
# 3 (insulin_dependent): 131
# 1    1077
# Name: count, dtype: int64
# 1    1077
# Name: count, dtype: int64
# Bad rows (sum!=1): 0
# just before split section df columns (n): 56
# ['participant_id', 'Age', 'study_group_healthy', 'study_group_insulin_dependent', 'study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled', 'study_group_pre_diabetes_lifestyle_controlled', 'split_test', 'split_train', 'split_val', 'Heart Rate Pulse', 'Oxygen Saturation', 'Physical Activity', 'Sleep', 'Stress', 'Respiratory Rate', 'Blood Glucose', 'PR Interval', 'Age-Related Macular Degeneration (Am', 'Arthritis (Joint Pain)', 'Cancer (Any Type)', 'Cataracts (In One Or Both Eyes)', 'Chronic Pulmonary (Lung) Problems (E', 'Circulation Problems (Examples: Art', "Dementia (Examples: Alzheimer'S Disea", 'Diabetic Retinopathy (In One Or Both', 'Digestive Problems (Examples: Stomach', 'Do You Use Marijuana Now?', 'Dry Eye (In One Or Both Eyes)', 'Elevated A1C Levels (Elevated Blood Sugar', 'Glaucoma (In One Or Both Eyes)', 'Hearing Impairment', 'Heart Attack', 'High Blood Cholesterol', 'High Blood Pressure', 'Kidney Problems', 'Low Blood Pressure', 'Mild Cognitive Impairment (Known As', 'Multiple Sclerosis', 'Obesity', 'Osteoporosis', 'Other Heart Issues (Examples: Pace', 'Other Neurological Conditions', "Parkinson'S Disease", 'Pre-Diabetes', 'Retinal Vascular Occlusion ("Stroke', 'Stroke', 'Type Ii Diabetes', 'Urinary Problems (Examples: Urinary T', 'BMI', 'Cholesterol', 'Glucose', 'HbA1c', 'Height', 'Insulin', 'RBC', 'WBC']
# target_cols: ['study_group_healthy', 'study_group_pre_diabetes_lifestyle_controlled', 'study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled', 'study_group_insulin_dependent']
# len(target_cols): 4
# class_names: ['healthy', 'prediabetes', 'oral_medicated', 'insulin_dependent']
# matching cols in df: ['study_group_healthy', 'study_group_pre_diabetes_lifestyle_controlled', 'study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled', 'study_group_insulin_dependent']
# missing cols: []
# X_train shape: (755, 48)
# y_train shape: (755,)
# groups_train shape: (755,)
# X_val shape: (161, 48)
# y_val shape: (161,)
# X_test shape: (161, 48)
# y_test shape: (161,)
# class names: ['study_group_healthy', 'study_group_pre_diabetes_lifestyle_controlled', 'study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled', 'study_group_insulin_dependent']
# X_train columns: ['Age', 'Heart Rate Pulse', 'Oxygen Saturation', 'Physical Activity', 'Sleep', 'Stress', 'Respiratory Rate', 'Blood Glucose', 'PR Interval', 'Age-Related Macular Degeneration (Am', 'Arthritis (Joint Pain)', 'Cancer (Any Type)', 'Cataracts (In One Or Both Eyes)', 'Chronic Pulmonary (Lung) Problems (E', 'Circulation Problems (Examples: Art', "Dementia (Examples: Alzheimer'S Disea", 'Diabetic Retinopathy (In One Or Both', 'Digestive Problems (Examples: Stomach', 'Do You Use Marijuana Now?', 'Dry Eye (In One Or Both Eyes)', 'Elevated A1C Levels (Elevated Blood Sugar', 'Glaucoma (In One Or Both Eyes)', 'Hearing Impairment', 'Heart Attack', 'High Blood Cholesterol', 'High Blood Pressure', 'Kidney Problems', 'Low Blood Pressure', 'Mild Cognitive Impairment (Known As', 'Multiple Sclerosis', 'Obesity', 'Osteoporosis', 'Other Heart Issues (Examples: Pace', 'Other Neurological Conditions', "Parkinson'S Disease", 'Pre-Diabetes', 'Retinal Vascular Occlusion ("Stroke', 'Stroke', 'Type Ii Diabetes', 'Urinary Problems (Examples: Urinary T', 'BMI', 'Cholesterol', 'Glucose', 'HbA1c', 'Height', 'Insulin', 'RBC', 'WBC']
# Numeric features count: 48
# First 20 numeric features: ['Age', 'Heart Rate Pulse', 'Oxygen Saturation', 'Physical Activity', 'Sleep', 'Stress', 'Respiratory Rate', 'Blood Glucose', 'PR Interval', 'Age-Related Macular Degeneration (Am', 'Arthritis (Joint Pain)', 'Cancer (Any Type)', 'Cataracts (In One Or Both Eyes)', 'Chronic Pulmonary (Lung) Problems (E', 'Circulation Problems (Examples: Art', "Dementia (Examples: Alzheimer'S Disea", 'Diabetic Retinopathy (In One Or Both', 'Digestive Problems (Examples: Stomach', 'Do You Use Marijuana Now?', 'Dry Eye (In One Or Both Eyes)']
# Categorical features count: 0
# First 20 categorical features: []
# Class distribution: [295 164 238  58]
# Target sums: {'study_group_healthy': 295, 'study_group_pre_diabetes_lifestyle_controlled': 164, 'study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled': 238, 'study_group_insulin_dependent': 58}
# config: hu=[256, 128, 64], dr=[0.3, 0.3, 0.2], act=relu, norm=batch, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7039
# config: hu=[256, 128, 64], dr=[0.3, 0.3, 0.2], act=relu, norm=batch, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.6891
# config: hu=[256, 128, 64], dr=[0.3, 0.3, 0.2], act=relu, norm=layer, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7332
# config: hu=[256, 128, 64], dr=[0.3, 0.3, 0.2], act=relu, norm=layer, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.6975
# config: hu=[256, 128, 64], dr=[0.3, 0.3, 0.2], act=elu, norm=batch, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7142
# config: hu=[256, 128, 64], dr=[0.3, 0.3, 0.2], act=elu, norm=batch, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7064
# config: hu=[256, 128, 64], dr=[0.3, 0.3, 0.2], act=elu, norm=layer, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7568
# config: hu=[256, 128, 64], dr=[0.3, 0.3, 0.2], act=elu, norm=layer, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7390
# config: hu=[256, 128, 64], dr=[0.2, 0.2], act=relu, norm=batch, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.6962
# config: hu=[256, 128, 64], dr=[0.2, 0.2], act=relu, norm=batch, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7315
# config: hu=[256, 128, 64], dr=[0.2, 0.2], act=relu, norm=layer, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7199
# config: hu=[256, 128, 64], dr=[0.2, 0.2], act=relu, norm=layer, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7097
# config: hu=[256, 128, 64], dr=[0.2, 0.2], act=elu, norm=batch, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7015
# config: hu=[256, 128, 64], dr=[0.2, 0.2], act=elu, norm=batch, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7321
# config: hu=[256, 128, 64], dr=[0.2, 0.2], act=elu, norm=layer, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7020
# config: hu=[256, 128, 64], dr=[0.2, 0.2], act=elu, norm=layer, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7327
# config: hu=[128, 64], dr=[0.3, 0.3, 0.2], act=relu, norm=batch, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7223
# config: hu=[128, 64], dr=[0.3, 0.3, 0.2], act=relu, norm=batch, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.6955
# config: hu=[128, 64], dr=[0.3, 0.3, 0.2], act=relu, norm=layer, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7484
# config: hu=[128, 64], dr=[0.3, 0.3, 0.2], act=relu, norm=layer, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7559
# config: hu=[128, 64], dr=[0.3, 0.3, 0.2], act=elu, norm=batch, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7081
# config: hu=[128, 64], dr=[0.3, 0.3, 0.2], act=elu, norm=batch, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7316
# config: hu=[128, 64], dr=[0.3, 0.3, 0.2], act=elu, norm=layer, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7317
# config: hu=[128, 64], dr=[0.3, 0.3, 0.2], act=elu, norm=layer, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7285
# config: hu=[128, 64], dr=[0.2, 0.2], act=relu, norm=batch, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.6978
# config: hu=[128, 64], dr=[0.2, 0.2], act=relu, norm=batch, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.6687
# config: hu=[128, 64], dr=[0.2, 0.2], act=relu, norm=layer, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7434
# config: hu=[128, 64], dr=[0.2, 0.2], act=relu, norm=layer, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7138
# config: hu=[128, 64], dr=[0.2, 0.2], act=elu, norm=batch, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.6951
# config: hu=[128, 64], dr=[0.2, 0.2], act=elu, norm=batch, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7186
# config: hu=[128, 64], dr=[0.2, 0.2], act=elu, norm=layer, opt=adam, lr=0.001, bs=64 -> val_macro_f1=0.7510
# config: hu=[128, 64], dr=[0.2, 0.2], act=elu, norm=layer, opt=nadam, lr=0.001, bs=64 -> val_macro_f1=0.7312
#
# Best hyperparameter configuration:
#   hidden_units: [256, 128, 64]
#   dropout_rates: [0.3, 0.3, 0.2]
#   activation: elu
#   normalization: layer
#   lr: 0.001
#   optimizer_name: adam
#   loss_name: sparse_categorical_crossentropy
#   batch_size: 64
# Validation macro F1: 0.7568
# Test macro F1:       0.7194
#
# Summary: Selected the configuration that yielded the highest validation macro F1. It balances model capacity and regularization (dropout + normalization), optimizing minority-class performance while ensuring stable convergence via early stopping.
# <class 'pandas.DataFrame'>
# <class 'numpy.ndarray'>
# Fold 1 class_weight: {np.int64(0): np.float64(0.6239669421487604), np.int64(1): np.float64(1.1984126984126984), np.int64(2): np.float64(0.7947368421052632), np.int64(3): np.float64(3.282608695652174)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Fold 1 threshold 0.2: insulin recall = 0.583
# Fold 1 threshold 0.25: insulin recall = 0.500
# Fold 1 threshold 0.3: insulin recall = 0.417
# Fold 1 threshold 0.35: insulin recall = 0.333
# Fold 1 threshold 0.2: insulin P/R/F1 = 0.241/0.583/0.341
# Fold 1 threshold 0.25: insulin P/R/F1 = 0.222/0.500/0.308
# Fold 1 threshold 0.3: insulin P/R/F1 = 0.200/0.417/0.270
# Fold 1 threshold 0.35: insulin P/R/F1 = 0.190/0.333/0.242
# Fold 2 class_weight: {np.int64(0): np.float64(0.6452991452991453), np.int64(1): np.float64(1.143939393939394), np.int64(2): np.float64(0.7905759162303665), np.int64(3): np.float64(3.2127659574468086)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Fold 2 threshold 0.2: insulin recall = 0.727
# Fold 2 threshold 0.25: insulin recall = 0.727
# Fold 2 threshold 0.3: insulin recall = 0.636
# Fold 2 threshold 0.35: insulin recall = 0.636
# Fold 2 threshold 0.2: insulin P/R/F1 = 0.276/0.727/0.400
# Fold 2 threshold 0.25: insulin P/R/F1 = 0.286/0.727/0.410
# Fold 2 threshold 0.3: insulin P/R/F1 = 0.269/0.636/0.378
# Fold 2 threshold 0.35: insulin P/R/F1 = 0.304/0.636/0.412
# Fold 3 class_weight: {np.int64(0): np.float64(0.6593886462882096), np.int64(1): np.float64(1.1615384615384616), np.int64(2): np.float64(0.7743589743589744), np.int64(3): np.float64(3.02)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Fold 3 threshold 0.2: insulin recall = 0.625
# Fold 3 threshold 0.25: insulin recall = 0.500
# Fold 3 threshold 0.3: insulin recall = 0.500
# Fold 3 threshold 0.35: insulin recall = 0.375
# Fold 3 threshold 0.2: insulin P/R/F1 = 0.143/0.625/0.233
# Fold 3 threshold 0.25: insulin P/R/F1 = 0.129/0.500/0.205
# Fold 3 threshold 0.3: insulin P/R/F1 = 0.143/0.500/0.222
# Fold 3 threshold 0.35: insulin P/R/F1 = 0.115/0.375/0.176
# Fold 4 class_weight: {np.int64(0): np.float64(0.6239669421487604), np.int64(1): np.float64(1.143939393939394), np.int64(2): np.float64(0.8162162162162162), np.int64(3): np.float64(3.3555555555555556)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step
# Fold 4 threshold 0.2: insulin recall = 0.538
# Fold 4 threshold 0.25: insulin recall = 0.538
# Fold 4 threshold 0.3: insulin recall = 0.538
# Fold 4 threshold 0.35: insulin recall = 0.462
# Fold 4 threshold 0.2: insulin P/R/F1 = 0.206/0.538/0.298
# Fold 4 threshold 0.25: insulin P/R/F1 = 0.226/0.538/0.318
# Fold 4 threshold 0.3: insulin P/R/F1 = 0.259/0.538/0.350
# Fold 4 threshold 0.35: insulin P/R/F1 = 0.231/0.462/0.308
# Fold 5 class_weight: {np.int64(0): np.float64(0.648068669527897), np.int64(1): np.float64(1.1102941176470589), np.int64(2): np.float64(0.7905759162303665), np.int64(3): np.float64(3.4318181818181817)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Fold 5 threshold 0.2: insulin recall = 0.929
# Fold 5 threshold 0.25: insulin recall = 0.929
# Fold 5 threshold 0.3: insulin recall = 0.929
# Fold 5 threshold 0.35: insulin recall = 0.929
# Fold 5 threshold 0.2: insulin P/R/F1 = 0.302/0.929/0.456
# Fold 5 threshold 0.25: insulin P/R/F1 = 0.351/0.929/0.510
# Fold 5 threshold 0.3: insulin P/R/F1 = 0.406/0.929/0.565
# Fold 5 threshold 0.35: insulin P/R/F1 = 0.448/0.929/0.605
# CV Accuracy: 0.743 +/- 0.023
# CV Weighted F1: 0.751 +/- 0.024
# Mean insulin precision (t=0.30): 0.256
# Mean insulin recall (t=0.30): 0.604
# Mean insulin f1 (t=0.30): 0.357
# {'hidden_units': [256, 128, 64], 'dropout_rates': [0.3, 0.3, 0.2], 'activation': 'elu', 'normalization': 'layer', 'lr': 0.001, 'optimizer_name': 'adam', 'loss_name': 'sparse_categorical_crossentropy', 'batch_size': 64}
# <class 'int'>
# [256, 128, 64]
#
# === Feedback round 1 ===
# Fold 1 class_weight: {np.int64(0): np.float64(0.6239669421487604), np.int64(1): np.float64(1.1984126984126984), np.int64(2): np.float64(0.7947368421052632), np.int64(3): np.float64(3.282608695652174)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Fold 1 threshold 0.20 insulin recall: 0.5833333333333334
# Fold 1 threshold 0.25 insulin recall: 0.5833333333333334
# Fold 1 threshold 0.30 insulin recall: 0.5833333333333334
# Fold 1 threshold 0.35 insulin recall: 0.5
# Fold 1 threshold 0.20 insulin P/R/F1: 0.21212121212121213 0.5833333333333334 0.3111111111111111
# Fold 1 threshold 0.25 insulin P/R/F1: 0.21875 0.5833333333333334 0.3181818181818182
# Fold 1 threshold 0.30 insulin P/R/F1: 0.2413793103448276 0.5833333333333334 0.34146341463414637
# Fold 1 threshold 0.35 insulin P/R/F1: 0.23076923076923078 0.5 0.3157894736842105
# Fold 2 class_weight: {np.int64(0): np.float64(0.6452991452991453), np.int64(1): np.float64(1.143939393939394), np.int64(2): np.float64(0.7905759162303665), np.int64(3): np.float64(3.2127659574468086)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step
# Fold 2 threshold 0.20 insulin recall: 0.7272727272727273
# Fold 2 threshold 0.25 insulin recall: 0.7272727272727273
# Fold 2 threshold 0.30 insulin recall: 0.5454545454545454
# Fold 2 threshold 0.35 insulin recall: 0.5454545454545454
# Fold 2 threshold 0.20 insulin P/R/F1: 0.34782608695652173 0.7272727272727273 0.47058823529411764
# Fold 2 threshold 0.25 insulin P/R/F1: 0.38095238095238093 0.7272727272727273 0.5
# Fold 2 threshold 0.30 insulin P/R/F1: 0.3157894736842105 0.5454545454545454 0.4
# Fold 2 threshold 0.35 insulin P/R/F1: 0.3157894736842105 0.5454545454545454 0.4
# Fold 3 class_weight: {np.int64(0): np.float64(0.6593886462882096), np.int64(1): np.float64(1.1615384615384616), np.int64(2): np.float64(0.7743589743589744), np.int64(3): np.float64(3.02)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Fold 3 threshold 0.20 insulin recall: 0.625
# Fold 3 threshold 0.25 insulin recall: 0.625
# Fold 3 threshold 0.30 insulin recall: 0.5
# Fold 3 threshold 0.35 insulin recall: 0.5
# Fold 3 threshold 0.20 insulin P/R/F1: 0.15625 0.625 0.25
# Fold 3 threshold 0.25 insulin P/R/F1: 0.16129032258064516 0.625 0.2564102564102564
# Fold 3 threshold 0.30 insulin P/R/F1: 0.16 0.5 0.24242424242424243
# Fold 3 threshold 0.35 insulin P/R/F1: 0.18181818181818182 0.5 0.26666666666666666
# Fold 4 class_weight: {np.int64(0): np.float64(0.6239669421487604), np.int64(1): np.float64(1.143939393939394), np.int64(2): np.float64(0.8162162162162162), np.int64(3): np.float64(3.3555555555555556)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Fold 4 threshold 0.20 insulin recall: 0.6153846153846154
# Fold 4 threshold 0.25 insulin recall: 0.6153846153846154
# Fold 4 threshold 0.30 insulin recall: 0.6153846153846154
# Fold 4 threshold 0.35 insulin recall: 0.6153846153846154
# Fold 4 threshold 0.20 insulin P/R/F1: 0.18604651162790697 0.6153846153846154 0.2857142857142857
# Fold 4 threshold 0.25 insulin P/R/F1: 0.20512820512820512 0.6153846153846154 0.3076923076923077
# Fold 4 threshold 0.30 insulin P/R/F1: 0.25806451612903225 0.6153846153846154 0.36363636363636365
# Fold 4 threshold 0.35 insulin P/R/F1: 0.2857142857142857 0.6153846153846154 0.3902439024390244
# Fold 5 class_weight: {np.int64(0): np.float64(0.648068669527897), np.int64(1): np.float64(1.1102941176470589), np.int64(2): np.float64(0.7905759162303665), np.int64(3): np.float64(3.4318181818181817)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Fold 5 threshold 0.20 insulin recall: 0.9285714285714286
# Fold 5 threshold 0.25 insulin recall: 0.9285714285714286
# Fold 5 threshold 0.30 insulin recall: 0.9285714285714286
# Fold 5 threshold 0.35 insulin recall: 0.8571428571428571
# Fold 5 threshold 0.20 insulin P/R/F1: 0.37142857142857144 0.9285714285714286 0.5306122448979592
# Fold 5 threshold 0.25 insulin P/R/F1: 0.41935483870967744 0.9285714285714286 0.5777777777777777
# Fold 5 threshold 0.30 insulin P/R/F1: 0.48148148148148145 0.9285714285714286 0.6341463414634146
# Fold 5 threshold 0.35 insulin P/R/F1: 0.5 0.8571428571428571 0.631578947368421
# CV Accuracy: mean = 0.7456953642384107 std = 0.044837909615392746
# CV Weighted F1: mean = 0.752651957404965 std = 0.04132285828950135
# cv_summary: {'mean_acc': np.float64(0.7456953642384107), 'std_acc': np.float64(0.044837909615392746), 'mean_f1': np.float64(0.752651957404965), 'std_f1': np.float64(0.04132285828950135), 'mean_insulin_recall_030': np.float64(0.6345487845487845), 'mean_insulin_precision_030': np.float64(0.29134295632791035), 'mean_insulin_f1_030': np.float64(0.39633407243163343)}
# cv_feedback: {'main_issue': 'low insulin recall', 'priority': 'improve class 3 recall without collapsing precision', 'fold_f1': [0.7381529859008535, 0.7931936641228485, 0.7381835081381961, 0.6902621428689896, 0.8034674859939372]}
# round_score: 0.752651957404965
#
# === Feedback round 2 ===
# Fold 1 class_weight: {np.int64(0): np.float64(0.6239669421487604), np.int64(1): np.float64(1.1984126984126984), np.int64(2): np.float64(0.7947368421052632), np.int64(3): np.float64(3.282608695652174)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Threshold 0.20 insulin recall: 0.417
# Threshold 0.25 insulin recall: 0.417
# Threshold 0.30 insulin recall: 0.333
# Threshold 0.35 insulin recall: 0.250
# Threshold 0.20 insulin P/R/F1: 0.238/0.417/0.303
# Threshold 0.25 insulin P/R/F1: 0.250/0.417/0.312
# Threshold 0.30 insulin P/R/F1: 0.250/0.333/0.286
# Threshold 0.35 insulin P/R/F1: 0.231/0.250/0.240
# Fold 2 class_weight: {np.int64(0): np.float64(0.6452991452991453), np.int64(1): np.float64(1.143939393939394), np.int64(2): np.float64(0.7905759162303665), np.int64(3): np.float64(3.2127659574468086)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Threshold 0.20 insulin recall: 0.909
# Threshold 0.25 insulin recall: 0.818
# Threshold 0.30 insulin recall: 0.818
# Threshold 0.35 insulin recall: 0.818
# Threshold 0.20 insulin P/R/F1: 0.417/0.909/0.571
# Threshold 0.25 insulin P/R/F1: 0.429/0.818/0.562
# Threshold 0.30 insulin P/R/F1: 0.450/0.818/0.581
# Threshold 0.35 insulin P/R/F1: 0.474/0.818/0.600
# Fold 3 class_weight: {np.int64(0): np.float64(0.6593886462882096), np.int64(1): np.float64(1.1615384615384616), np.int64(2): np.float64(0.7743589743589744), np.int64(3): np.float64(3.02)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Threshold 0.20 insulin recall: 0.500
# Threshold 0.25 insulin recall: 0.500
# Threshold 0.30 insulin recall: 0.375
# Threshold 0.35 insulin recall: 0.375
# Threshold 0.20 insulin P/R/F1: 0.154/0.500/0.235
# Threshold 0.25 insulin P/R/F1: 0.167/0.500/0.250
# Threshold 0.30 insulin P/R/F1: 0.130/0.375/0.194
# Threshold 0.35 insulin P/R/F1: 0.130/0.375/0.194
# Fold 4 class_weight: {np.int64(0): np.float64(0.6239669421487604), np.int64(1): np.float64(1.143939393939394), np.int64(2): np.float64(0.8162162162162162), np.int64(3): np.float64(3.3555555555555556)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Threshold 0.20 insulin recall: 0.538
# Threshold 0.25 insulin recall: 0.462
# Threshold 0.30 insulin recall: 0.462
# Threshold 0.35 insulin recall: 0.308
# Threshold 0.20 insulin P/R/F1: 0.304/0.538/0.389
# Threshold 0.25 insulin P/R/F1: 0.273/0.462/0.343
# Threshold 0.30 insulin P/R/F1: 0.316/0.462/0.375
# Threshold 0.35 insulin P/R/F1: 0.267/0.308/0.286
# Fold 5 class_weight: {np.int64(0): np.float64(0.648068669527897), np.int64(1): np.float64(1.1102941176470589), np.int64(2): np.float64(0.7905759162303665), np.int64(3): np.float64(3.4318181818181817)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step
# Threshold 0.20 insulin recall: 0.714
# Threshold 0.25 insulin recall: 0.643
# Threshold 0.30 insulin recall: 0.571
# Threshold 0.35 insulin recall: 0.571
# Threshold 0.20 insulin P/R/F1: 0.385/0.714/0.500
# Threshold 0.25 insulin P/R/F1: 0.360/0.643/0.462
# Threshold 0.30 insulin P/R/F1: 0.421/0.571/0.485
# Threshold 0.35 insulin P/R/F1: 0.471/0.571/0.516
# CV Accuracy: 0.775 ± 0.032
# CV Weighted F1: 0.780 ± 0.030
# cv_summary: {'mean_acc': np.float64(0.775), 'std_acc': np.float64(0.032), 'mean_f1': np.float64(0.78), 'std_f1': np.float64(0.03), 'mean_insulin_recall_030': np.float64(0.512), 'mean_insulin_precision_030': np.float64(0.313), 'mean_insulin_f1_030': np.float64(0.384)}
# cv_feedback: {'main_issue': 'balanced', 'priority': 'improve class 3 recall without collapsing precision', 'fold_f1': [0.7748198386802138, 0.8391312298388647, 0.7592045144282072, 0.7554238012847285, 0.7737101002546262]}
# round_score: 0.78
#
# === Feedback round 3 ===
# Fold 1
# class_weight: {np.int64(0): np.float64(0.6239669421487604), np.int64(1): np.float64(1.1984126984126984), np.int64(2): np.float64(0.7947368421052632), np.int64(3): np.float64(3.282608695652174)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# threshold 0.2: insulin recall = 0.417
# threshold 0.25: insulin recall = 0.417
# threshold 0.3: insulin recall = 0.417
# threshold 0.35: insulin recall = 0.417
# threshold 0.2: insulin precision = 0.179, recall = 0.417, f1 = 0.250
# threshold 0.25: insulin precision = 0.179, recall = 0.417, f1 = 0.250
# threshold 0.3: insulin precision = 0.217, recall = 0.417, f1 = 0.286
# threshold 0.35: insulin precision = 0.250, recall = 0.417, f1 = 0.312
# Fold 2
# class_weight: {np.int64(0): np.float64(0.6452991452991453), np.int64(1): np.float64(1.143939393939394), np.int64(2): np.float64(0.7905759162303665), np.int64(3): np.float64(3.2127659574468086)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step
# threshold 0.2: insulin recall = 0.818
# threshold 0.25: insulin recall = 0.727
# threshold 0.3: insulin recall = 0.455
# threshold 0.35: insulin recall = 0.455
# threshold 0.2: insulin precision = 0.375, recall = 0.818, f1 = 0.514
# threshold 0.25: insulin precision = 0.348, recall = 0.727, f1 = 0.471
# threshold 0.3: insulin precision = 0.250, recall = 0.455, f1 = 0.323
# threshold 0.35: insulin precision = 0.250, recall = 0.455, f1 = 0.323
# Fold 3
# class_weight: {np.int64(0): np.float64(0.6593886462882096), np.int64(1): np.float64(1.1615384615384616), np.int64(2): np.float64(0.7743589743589744), np.int64(3): np.float64(3.02)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step
# threshold 0.2: insulin recall = 0.375
# threshold 0.25: insulin recall = 0.375
# threshold 0.3: insulin recall = 0.375
# threshold 0.35: insulin recall = 0.250
# threshold 0.2: insulin precision = 0.150, recall = 0.375, f1 = 0.214
# threshold 0.25: insulin precision = 0.167, recall = 0.375, f1 = 0.231
# threshold 0.3: insulin precision = 0.167, recall = 0.375, f1 = 0.231
# threshold 0.35: insulin precision = 0.143, recall = 0.250, f1 = 0.182
# Fold 4
# class_weight: {np.int64(0): np.float64(0.6239669421487604), np.int64(1): np.float64(1.143939393939394), np.int64(2): np.float64(0.8162162162162162), np.int64(3): np.float64(3.3555555555555556)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# threshold 0.2: insulin recall = 0.462
# threshold 0.25: insulin recall = 0.462
# threshold 0.3: insulin recall = 0.385
# threshold 0.35: insulin recall = 0.385
# threshold 0.2: insulin precision = 0.300, recall = 0.462, f1 = 0.364
# threshold 0.25: insulin precision = 0.300, recall = 0.462, f1 = 0.364
# threshold 0.3: insulin precision = 0.278, recall = 0.385, f1 = 0.323
# threshold 0.35: insulin precision = 0.278, recall = 0.385, f1 = 0.323
# Fold 5
# class_weight: {np.int64(0): np.float64(0.648068669527897), np.int64(1): np.float64(1.1102941176470589), np.int64(2): np.float64(0.7905759162303665), np.int64(3): np.float64(3.4318181818181817)}
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step
# threshold 0.2: insulin recall = 0.786
# threshold 0.25: insulin recall = 0.786
# threshold 0.3: insulin recall = 0.714
# threshold 0.35: insulin recall = 0.714
# threshold 0.2: insulin precision = 0.407, recall = 0.786, f1 = 0.537
# threshold 0.25: insulin precision = 0.423, recall = 0.786, f1 = 0.550
# threshold 0.3: insulin precision = 0.400, recall = 0.714, f1 = 0.513
# threshold 0.35: insulin precision = 0.417, recall = 0.714, f1 = 0.526
# CV Accuracy: mean=0.755, std=0.022
# CV Weighted F1: mean=0.763, std=0.024
# cv_summary: {'mean_acc': np.float64(0.755), 'std_acc': np.float64(0.022), 'mean_f1': np.float64(0.763), 'std_f1': np.float64(0.024), 'mean_insulin_precision_030': np.float64(0.262), 'mean_insulin_recall_030': np.float64(0.469), 'mean_insulin_f1_030': np.float64(0.335)}
# cv_feedback: {'main_issue': 'low insulin recall', 'priority': 'improve class 3 recall without collapsing precision', 'fold_f1': [0.7653983793344576, 0.7766547545232525, 0.782626940660392, 0.7172646025198898, 0.7728214830838912]}
# round_score: 0.763
# Best CV summary:
# {'mean_acc': np.float64(0.775), 'std_acc': np.float64(0.032), 'mean_f1': np.float64(0.78), 'std_f1': np.float64(0.03), 'mean_insulin_recall_030': np.float64(0.512), 'mean_insulin_precision_030': np.float64(0.313), 'mean_insulin_f1_030': np.float64(0.384)}
# Predicted class counts: [43 35 66 17]
# True class counts:      [40 40 41 40]
# Artifacts saved to artifacts/
# Final Held-out Test Results
# Test Accuracy: 0.677
# Test Weighted F1 Score: 0.664
#                                                                                  precision    recall  f1-score   support
#
#                                                             study_group_healthy      0.930     1.000     0.964        40
#                                   study_group_pre_diabetes_lifestyle_controlled      0.800     0.700     0.747        40
# study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled      0.455     0.732     0.561        41
#                                                   study_group_insulin_dependent      0.647     0.275     0.386        40
#
#                                                                        accuracy                          0.677       161
#                                                                       macro avg      0.708     0.677     0.664       161
#                                                                    weighted avg      0.706     0.677     0.664       161

# %% [markdown]
# ## PART 3B

# %%
def planner_agent(topic: str, model: str = "gpt-4o-mini") -> list[str]:
    """
    Generates a step-by-step plan for a classification task for a .

    Args:
        topic (str): Research topic or question to investigate.
        model (str): Language model to use.

    Returns:
        list[str]: A valid Python list of executable step strings.
    """
    user_prompt = f"""
You are a planning agent responsible for organizing a hypothesis-testing workflow
for a Type 2 Diabetes Mellitus (T2DM) severity classification project.

Topic:
{topic}

Available agents:
- A data understanding agent that identifies relevant variables in the dataset.
- A model loading agent that loads the trained classifier and preprocessing objects.
- A fake patient agent that creates a baseline synthetic patient from dataset averages or medians.
- A hypothesis application agent that modifies the synthetic patient according to the hypothesis.
- A prediction agent that gets class probabilities from the trained model.
- A comparison agent that compares baseline vs modified predictions.
- A conclusion agent that writes a natural language interpretation of the results.

Your job:
Write a clear, step-by-step plan as a valid Python list, where each step is a short executable string.

Rules:
- Return ONLY a valid Python list.
- Each item must be a string.
- Keep steps atomic and in logical order.
- Do not include explanations outside the list.
- The plan should fit a workflow that tests how a hypothesis changes predicted T2DM severity.

Example style:
[
    "Identify the relevant variables mentioned in the topic.",
    "Load the trained model and preprocessing pipeline.",
    "Create a baseline synthetic patient from dataset averages.",
    "Apply the hypothesis conditions to the synthetic patient.",
    "Generate predictions for the baseline and modified patients.",
    "Compare the class probabilities.",
    "Write a natural language conclusion."
]
"""

    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": user_prompt}],
        temperature=0
    )

    plan_text = response.choices[0].message.content.strip()

    try:
        plan = eval(plan_text)
        if isinstance(plan, list) and all(isinstance(step, str) for step in plan):
            return plan
        else:
            raise ValueError("Response was not a valid list of strings.")
    except Exception as e:
        raise ValueError(f"Failed to parse planner output: {e}\nRaw output:\n{plan_text}")

# %%
model = scope["final_mlp"]
preprocessor = scope["preprocessor"]
class_names = scope["class_names"]

# %%
def load_trained_model_agent(topic: str, model: str = "openai:o4-mini") -> list[str]:

    user_prompt = f"""
You are a machine learning planning agent responsible for loading a trained model
and running predictions.

Context:
A trained neural network model and preprocessing pipeline were previously done

The model architecture must be rebuilt using build_mlp before loading weights.

Your job:
Produce a Python list of executable steps describing how to:

1. Load the preprocessing pipeline.
2. Load class names.
3. Rebuild the model architecture using build_mlp.
4. Load the trained model weights.
5. Prepare new input data using the preprocessor.
6. Run model predictions.
7. Convert predicted class indices into class names.
8. Summarize the prediction results.

Rules:
- Each step must be atomic.
- Return ONLY a valid Python list.
- Do not include explanations.

Task: "{topic}"
"""

# %%
import pandas as pd

def create_standard_patient_agent(
    df: pd.DataFrame,
    target_cols: list[str] | None = None
) -> dict:
    """
    Create a standard patient profile for model inference.

    Numeric columns -> median
    Non-numeric columns -> mode
    Excludes target columns.

    Args:
        df (pd.DataFrame): Training dataframe.
        target_cols (list[str] | None): Columns to exclude, such as labels.

    Returns:
        dict: One-row synthetic patient profile.
    """
    if target_cols is None:
        target_cols = []

    feature_df = df.drop(columns=target_cols, errors="ignore")
    patient = {}

    for col in feature_df.columns:
        series = feature_df[col].dropna()

        if len(series) == 0:
            patient[col] = None
        elif pd.api.types.is_numeric_dtype(series):
            patient[col] = float(series.median())
        else:
            mode_vals = series.mode()
            patient[col] = mode_vals.iloc[0] if not mode_vals.empty else None

    return patient

# %%
target_cols = [
    "study_group_healthy",
    "study_group_insulin_dependent",
    "study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled",
    "study_group_pre_diabetes_lifestyle_controlled"
]

standard_patient = create_standard_patient_agent(df)
print(type(standard_patient))
print(list(standard_patient.items())[:10])
# Out:
# <class 'dict'>
# [('participant_id', 4157.0), ('Age', 60.0), ('study_group_healthy', 0.0), ('study_group_insulin_dependent', 0.0), ('study_group_oral_medication_and_or_non_insulin_injectable_medication_controlled', 0.0), ('study_group_pre_diabetes_lifestyle_controlled', 0.0), ('split_test', 0.0), ('split_train', 1.0), ('split_val', 0.0), ('Heart Rate Pulse', 74.25)]

# %%
def apply_hypothesis_agent(hypothesis: str) -> dict:
    edits = {}
    parts = hypothesis.split("AND")

    for part in parts:
        part = part.strip()
        if "=" in part:
            feature, level = part.split("=", 1)
            edits[feature.strip()] = level.strip().upper()

    return edits

# %%
def level_to_value(feature: str, level: str, boundaries: dict) -> float:
    """
    Convert LOW / MID / HIGH into a numeric value using feature boundaries.
    """
    if feature not in boundaries:
        raise KeyError(f"Feature '{feature}' not found in BOUNDARIES")

    low, high = boundaries[feature]
    mid = (low + high) / 2

    level = str(level).strip().upper()

    if level == "LOW":
        return low
    elif level in ["MID", "MEDIUM", "NORMAL", "AVERAGE"]:
        return mid
    elif level == "HIGH":
        return high
    else:
        # if already numeric, try to use it directly
        try:
            return float(level)
        except ValueError:
            raise ValueError(
                f"Unsupported level '{level}' for feature '{feature}'. "
                "Use LOW, MID/MEDIUM/NORMAL, HIGH, or a numeric value."
            )

# %%
def apply_changes(patient_dict: dict, edits: dict, boundaries: dict = BOUNDARIES) -> dict:
    """
    Apply hypothesis edits to a patient dictionary.
    
    Example:
    edits = {"Physical Activity": "HIGH", "Heart Rate Pulse": "LOW"}
    """
    updated = patient_dict.copy()

    for feature, level in edits.items():
        if feature in boundaries:
            updated[feature] = level_to_value(feature, level, boundaries)
        else:
            # if the feature is not in boundaries, just write the raw value
            updated[feature] = level

    return updated

# %%
def compare_predictions_agent(topic: str, model: str = "openai:o4-mini") -> str:    
    """
    Compares model predictions before and after applying a hypothesis
    and explains how the predicted T2DM severity changed.

    Args:
        task (str): Description of baseline prediction and modified prediction.
        model (str): Language model to use.

    Returns:
        str: Explanation of prediction differences.
    """

    print("==================================")
    print("📊 Compare Predictions Agent")
    print("==================================")

    system_prompt = """
You are a model interpretation agent for a medical machine learning workflow.

Your job is to compare predictions from a classifier before and after
a hypothesis is applied to a patient profile.

Focus on:
- the predicted class
- prediction probabilities
- confidence changes
- whether severity increased, decreased, or stayed similar

Guidelines:
- Be concise and factual.
- Use the evidence provided in the task.
- Do not invent numbers that are not given.
- Clearly describe the direction of change in prediction.
"""

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
           
            {"role": "user", "content": topic}
        ],
        temperature=1
    )

    return response.choices[0].message.content

# %%
def generate_natural_language_conclusion_agent(task: str, model: str = "openai:o4-mini") -> str:    
    """
    Generates a polished natural-language conclusion for a T2DM hypothesis
    based on model comparison results and supporting evidence.

    Args:
        task (str): Structured evidence about the hypothesis, prediction changes,
                    certainty, and reliability.
        model (str): Language model to use.

    Returns:
        str: Final natural-language conclusion.
    """
    print("==================================")
    print("📝 Natural Language Conclusion Agent")
    print("==================================")

    system_prompt = """
You are a natural language conclusion agent for a medical machine learning workflow.

Your role is to turn structured model findings into a clear, polished final conclusion
about whether a hypothesis meaningfully affects predicted Type 2 Diabetes Mellitus (T2DM)
likelihood or severity.

You must base your conclusion ONLY on the provided evidence.
Do not invent facts, numbers, or effects that are not given.
If evidence is weak or mixed, say so clearly.

Return the answer in exactly this format:

In the OpenAI model,

(<hypothesis>) is <description1> to change the predicted T2DM severity.

The first variable showed:
<brief summary of the first variable's individual effect>

The second variable showed:
<brief summary of the second variable's individual effect>

The combination of the variables showed:
<brief summary of the combined effect>

Therefore, this hypothesis is <description2> to meaningfully affect likelihood of T2DM.

Prediction certainty: <High / Moderate / Low>
Model reliability: <High / Moderate / Low>

Rules:
- Keep the wording cautious, concise, and evidence-based.
- "description1" should be one of:
  likely, somewhat likely, unlikely, not clearly likely, plausibly associated
- "description2" should be one of:
  likely, moderately supported, weakly supported, unlikely, insufficiently supported
- If one variable is clearly stronger than the other, say so.
- If the combination is mostly driven by one variable, say so.
- Do not add markdown headings or bullet points.
"""

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": task}
        ],
        temperature=1
    )

    return response.choices[0].message.content

# %%
import pandas as pd
import numpy as np

def predict_one(patient_dict, model, preprocessor, class_names):
    """
    Predict one patient record.

    Args:
        patient_dict (dict): One patient as a dictionary.
        model: Trained classifier.
        preprocessor: Fitted preprocessing pipeline.
        class_names (list): Class names in model output order.

    Returns:
        dict: Predicted class, confidence, and probabilities.
    """
    # Convert to one-row DataFrame
    X_one = pd.DataFrame([patient_dict])

    # Apply preprocessing
    X_one_p = preprocessor.transform(X_one)

    # Predict probabilities
    if hasattr(model, "predict_proba"):
        probs = model.predict_proba(X_one_p)[0]
    else:
        X_one_p = X_one_p.toarray() if hasattr(X_one_p, "toarray") else X_one_p
        probs = model.predict(X_one_p, verbose=0)[0]
    
    # Top class
    top_idx = int(np.argmax(probs))
    top_class = class_names[top_idx]
    confidence = float(probs[top_idx])

    return {
        "top_class": top_class,
        "confidence": confidence,
        "probs": {class_names[i]: float(probs[i]) for i in range(len(class_names))}
    }

# %%
def run_hypothesis_pipeline(topic, hypothesis):
    print("==================================")
    print("🚀 Starting Hypothesis Pipeline")
    print("==================================")

    print("\n[1] Running planner_agent...")
    plan = planner_agent(topic)
    print("Done.")

    print("\n📋 Plan:")
    for step in plan:
        print("-", step)

    print("\n[2] Running create_standard_patient_agent...")
    standard_patient = create_standard_patient_agent(df, target_cols)
    print("Done.")

    print("\n[3] Running apply_hypothesis_agent...")
    edits = apply_hypothesis_agent(hypothesis)
    print("Done.")

    print("\n[4] Running apply_changes...")
    modified_patient = apply_changes(standard_patient.copy(), edits)
    print("Done.")

    print("\n[5] Running baseline prediction...")
    baseline_pred = predict_one(standard_patient, model, preprocessor, class_names)
    print("Done.")

    print("\n[6] Running changed prediction...")
    changed_pred = predict_one(modified_patient, model, preprocessor, class_names)
    print("Done.")

    print("\n[7] Running compare_predictions_agent...")
    comparison_task = f'''
Baseline prediction:
{baseline_pred}

Prediction after applying hypothesis:
{changed_pred}

Hypothesis:
{hypothesis}

Explain the change in model predictions.
'''
    comparison = compare_predictions_agent(comparison_task)
    print("Done.")

    print("\n[8] Running generate_natural_language_conclusion_agent...")
    final_task = f'''
Hypothesis:
{hypothesis}

Prediction comparison:
{comparison}

Baseline prediction:
{baseline_pred}

Changed prediction:
{changed_pred}
'''
    conclusion = generate_natural_language_conclusion_agent(final_task)
    print("Done.")

    print("\n==================================")
    print("✅ Final Conclusion")
    print("==================================")
    print(conclusion)

    return conclusion

# %%
topic = "Investigate whether physical activity and other variables affect T2DM severity"

pipeline_results = []

for idx, hypothesis in enumerate(question_list, start=1):

    print("\n" + "="*70)
    print(f"Running pipeline for Question {idx}")
    print(hypothesis)
    print("="*70)

    result = run_hypothesis_pipeline(topic, hypothesis)

    pipeline_results.append({
        "question_num": idx,
        "hypothesis": hypothesis,
        "result": result
    })
# Out:
# ======================================================================
# Running pipeline for Question 1
# Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ==================================
# 🚀 Starting Hypothesis Pipeline
# ==================================
#
# [1] Running planner_agent...
# Done.
#
# 📋 Plan:
# - Identify the relevant variables in the dataset related to T2DM severity and physical activity.
# - Load the trained classifier and preprocessing objects.
# - Create a baseline synthetic patient using dataset averages or medians.
# - Modify the synthetic patient according to the hypothesis regarding physical activity and other variables.
# - Generate predictions for the baseline synthetic patient.
# - Generate predictions for the modified synthetic patient.
# - Compare the class probabilities of the baseline and modified predictions.
# - Write a natural language interpretation of the results.
#
# [2] Running create_standard_patient_agent...
# Done.
#
# [3] Running apply_hypothesis_agent...
# Done.
#
# [4] Running apply_changes...
# Done.
#
# [5] Running baseline prediction...
# Done.
#
# [6] Running changed prediction...
# Done.
#
# [7] Running compare_predictions_agent...
# ==================================
# 📊 Compare Predictions Agent
# ==================================
# Done.
#
# [8] Running generate_natural_language_conclusion_agent...
# ==================================
# 📝 Natural Language Conclusion Agent
# ==================================
# Done.
#
# ==================================
# ✅ Final Conclusion
# ==================================
# In the OpenAI model,
#
# (HIGH PR Interval AND HIGH Cholesterol) is unlikely to change the predicted T2DM severity.
#
# The first variable showed: high PR interval alone did not alter the predicted class probabilities.
#
# The second variable showed: high cholesterol alone did not alter the predicted class probabilities.
#
# The combination of the variables showed: no change in top class (“study_group_healthy”), confidence (0.7735), or any class probability.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: High
#
# ======================================================================
# Running pipeline for Question 2
# Does Heart Attack AND Age-Related Macular Degeneration (Am affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ==================================
# 🚀 Starting Hypothesis Pipeline
# ==================================
#
# [1] Running planner_agent...
# Done.
#
# 📋 Plan:
# - Identify the relevant variables related to physical activity and T2DM severity.
# - Load the trained classifier and preprocessing objects.
# - Create a baseline synthetic patient using dataset averages or medians.
# - Modify the synthetic patient according to the hypothesis regarding physical activity.
# - Generate predictions for the baseline synthetic patient.
# - Generate predictions for the modified synthetic patient.
# - Compare the class probabilities of the baseline and modified predictions.
# - Write a natural language interpretation of the results.
#
# [2] Running create_standard_patient_agent...
# Done.
#
# [3] Running apply_hypothesis_agent...
# Done.
#
# [4] Running apply_changes...
# Done.
#
# [5] Running baseline prediction...
# Done.
#
# [6] Running changed prediction...
# Done.
#
# [7] Running compare_predictions_agent...
# ==================================
# 📊 Compare Predictions Agent
# ==================================
# Done.
#
# [8] Running generate_natural_language_conclusion_agent...
# ==================================
# 📝 Natural Language Conclusion Agent
# ==================================
# Done.
#
# ==================================
# ✅ Final Conclusion
# ==================================
# In the OpenAI model,
#
# (Heart Attack AND Age-Related Macular Degeneration) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# Heart Attack alone did not alter the model’s predicted class or probabilities for T2DM.
#
# The second variable showed:
# Age-Related Macular Degeneration alone did not alter the model’s predicted class or probabilities for T2DM.
#
# The combination of the variables showed:
# Adding both conditions together left the top class, confidence, and all class probabilities unchanged.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
#
# ======================================================================
# Running pipeline for Question 3
# Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ==================================
# 🚀 Starting Hypothesis Pipeline
# ==================================
#
# [1] Running planner_agent...
# Done.
#
# 📋 Plan:
# - Identify the relevant variables in the dataset related to T2DM severity and physical activity.
# - Load the trained classifier and preprocessing objects.
# - Create a baseline synthetic patient using dataset averages or medians.
# - Modify the synthetic patient according to the hypothesis regarding physical activity and other variables.
# - Generate predictions for the baseline synthetic patient.
# - Generate predictions for the modified synthetic patient.
# - Compare the class probabilities of the baseline and modified predictions.
# - Write a natural language interpretation of the results.
#
# [2] Running create_standard_patient_agent...
# Done.
#
# [3] Running apply_hypothesis_agent...
# Done.
#
# [4] Running apply_changes...
# Done.
#
# [5] Running baseline prediction...
# Done.
#
# [6] Running changed prediction...
# Done.
#
# [7] Running compare_predictions_agent...
# ==================================
# 📊 Compare Predictions Agent
# ==================================
# Done.
#
# [8] Running generate_natural_language_conclusion_agent...
# ==================================
# 📝 Natural Language Conclusion Agent
# ==================================
# Done.
#
# ==================================
# ✅ Final Conclusion
# ==================================
# In the OpenAI model,
#
# (HIGH Blood Glucose AND None) is unlikely to change the predicted T2DM severity.
#
# The first variable showed: HIGH Blood Glucose alone produced no shift in class or probabilities.
# The second variable showed: None alone produced no shift in class or probabilities.
# The combination of the variables showed: identical class and probabilities to baseline, with no change in confidence or severity.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
#
# ======================================================================
# Running pipeline for Question 4
# Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ==================================
# 🚀 Starting Hypothesis Pipeline
# ==================================
#
# [1] Running planner_agent...
# Done.
#
# 📋 Plan:
# - Identify the relevant variables related to physical activity and T2DM severity.
# - Load the trained classifier and preprocessing objects.
# - Create a baseline synthetic patient using dataset averages or medians.
# - Modify the synthetic patient according to the hypothesis regarding physical activity.
# - Generate predictions for the baseline synthetic patient.
# - Generate predictions for the modified synthetic patient.
# - Compare the class probabilities of the baseline and modified predictions.
# - Write a natural language interpretation of the results.
#
# [2] Running create_standard_patient_agent...
# Done.
#
# [3] Running apply_hypothesis_agent...
# Done.
#
# [4] Running apply_changes...
# Done.
#
# [5] Running baseline prediction...
# Done.
#
# [6] Running changed prediction...
# Done.
#
# [7] Running compare_predictions_agent...
# ==================================
# 📊 Compare Predictions Agent
# ==================================
# Done.
#
# [8] Running generate_natural_language_conclusion_agent...
# ==================================
# 📝 Natural Language Conclusion Agent
# ==================================
# Done.
#
# ==================================
# ✅ Final Conclusion
# ==================================
# In the OpenAI model,
#
# (HIGH Sleep AND None) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# HIGH Sleep alone did not alter the predicted class, confidence, or any class probabilities.
#
# The second variable showed:
# None alone did not alter the predicted class, confidence, or any class probabilities.
#
# The combination of the variables showed:
# No change in predicted class, confidence, or class probabilities compared to the baseline.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: High
#
# ======================================================================
# Running pipeline for Question 5
# Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?
# ======================================================================
# ==================================
# 🚀 Starting Hypothesis Pipeline
# ==================================
#
# [1] Running planner_agent...
# Done.
#
# 📋 Plan:
# - Identify the relevant variables in the dataset related to T2DM severity and physical activity.
# - Load the trained classifier and preprocessing objects.
# - Create a baseline synthetic patient using dataset averages or medians.
# - Modify the synthetic patient according to the hypothesis regarding physical activity and other variables.
# - Generate predictions for the baseline synthetic patient.
# - Generate predictions for the modified synthetic patient.
# - Compare the class probabilities of the baseline and modified predictions.
# - Write a natural language interpretation of the results.
#
# [2] Running create_standard_patient_agent...
# Done.
#
# [3] Running apply_hypothesis_agent...
# Done.
#
# [4] Running apply_changes...
# Done.
#
# [5] Running baseline prediction...
# Done.
#
# [6] Running changed prediction...
# Done.
#
# [7] Running compare_predictions_agent...
# ==================================
# 📊 Compare Predictions Agent
# ==================================
# Done.
#
# [8] Running generate_natural_language_conclusion_agent...
# ==================================
# 📝 Natural Language Conclusion Agent
# ==================================
# Done.
#
# ==================================
# ✅ Final Conclusion
# ==================================
# In the OpenAI model,
#
# (HIGH Glucose AND Retinal Vascular Occlusion (“Stroke”)) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# no detectable change in the predicted T2DM severity when added.
#
# The second variable showed:
# no detectable change in the predicted T2DM severity when added.
#
# The combination of the variables showed:
# no change in top‐predicted class or class probabilities.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate

# %%
pipeline_df = pd.DataFrame(pipeline_results)

pipeline_df.to_csv("pipeline_results_5_questions.csv", index=False)

# %% [markdown]
# # Summarising of all 3 parts

# %%
def build_full_hypothesis_summary(
    hypothesis_text,
    part_a_text,
    part_a_summary,
    part_b_text,
    part_c_text
):
    """
    Combine Part A, Part B, and Part C into one clinician-readable summary block.
    """

    final_text = f"""
============================================

🌟Final Summary

============================================

⭐Hypothesis: {hypothesis_text}

============================================

⚫In Part A…

Raw Part A report:
{part_a_text}
{part_a_summary}
============================================

⚫In Part B…

{part_b_text}
============================================

⚫In Part C…

{part_c_text}
============================================
""".strip()

    return final_text

# %%
def clean_hypothesis_text(r):
    left = f"{r['level1']} {r['var1']}" if r["level1"] is not None else r["var1"]
    right = f"{r['level2']} {r['var2']}" if r["level2"] is not None else r["var2"]
    return f"Does {left} AND {right} affect your likelihood of Type 2 Diabetes?"

# %%
for i in range(5):

    r = results[i]

    hypothesis_text = clean_hypothesis_text(r)

    part_a_text = r["report"]
    part_a_summary = PartA_conclusion_results[i]["conclusion"]
    part_b_text = all_final_outputs[i]["final_output"]      # or executor_runs[i]["final_markdown"], depending on what you want
    part_c_text = pipeline_results[i]["result"]

    full_summary = build_full_hypothesis_summary(
        hypothesis_text=hypothesis_text,
        part_a_text=part_a_text,
        part_a_summary=part_a_summary,
        part_b_text=part_b_text,
        part_c_text=part_c_text
    )

    print("\n" + "=" * 80)
    print(full_summary)
# Out:
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH PR Interval AND HIGH Cholesterol affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH PR Interval:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH PR Interval (923 patients), the predicted class distribution is: healthy: 326/923 (35.3%), oral_medicated: 261/923 (28.3%), prediabetes: 230/923 (24.9%), insulin_dependent: 106/923 (11.5%).
#   Out of all predicted patients:
#     - healthy: 326/376 (86.7%) have HIGH PR Interval
#     - prediabetes: 230/285 (80.7%) have HIGH PR Interval
#     - oral_medicated: 261/317 (82.3%) have HIGH PR Interval
#     - insulin_dependent: 106/99 (107.1%) have HIGH PR Interval
#
# Effect of HIGH Cholesterol:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Cholesterol (1072 patients), the predicted class distribution is: healthy: 369/1072 (34.4%), oral_medicated: 312/1072 (29.1%), prediabetes: 262/1072 (24.4%), insulin_dependent: 129/1072 (12.0%).
#   Out of all predicted patients:
#     - healthy: 369/376 (98.1%) have HIGH Cholesterol
#     - prediabetes: 262/285 (91.9%) have HIGH Cholesterol
#     - oral_medicated: 312/317 (98.4%) have HIGH Cholesterol
#     - insulin_dependent: 129/99 (130.3%) have HIGH Cholesterol
#
# Combined effect of HIGH PR Interval AND HIGH Cholesterol:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH PR Interval AND HIGH Cholesterol (919 patients), the predicted class distribution is: healthy: 323/919 (35.1%), oral_medicated: 261/919 (28.4%), prediabetes: 229/919 (24.9%), insulin_dependent: 106/919 (11.5%).
#   Out of all predicted patients:
#     - healthy: 323/376 (85.9%) have HIGH PR Interval AND HIGH Cholesterol
#     - prediabetes: 229/285 (80.4%) have HIGH PR Interval AND HIGH Cholesterol
#     - oral_medicated: 261/317 (82.3%) have HIGH PR Interval AND HIGH Cholesterol
#     - insulin_dependent: 106/99 (107.1%) have HIGH PR Interval AND HIGH Cholesterol
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.88) [Δhealthy=-0.00, Δpred=+0.00, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.84) [Δhealthy=-0.00, Δpred=+0.01, Δoral=-0.00, Δins=-0.00]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.61) [Δhealthy=+0.01, Δpred=+0.08, Δoral=-0.09, Δins=+0.01]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.60) [Δhealthy=+0.01, Δpred=+0.05, Δoral=-0.05, Δins=-0.01]
#
#
# === Conclusion ===============================
#
# In this model,
# (PR Interval=HIGH AND Cholesterol=HIGH) is unlikely to change the predicted T2DM severity
# (Severity: 0.121 → 0.083, Δ=-0.038).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (mixed) probability shifts, (no) class transitions, and (no) increase in severity.
# The subgroup size (n=919) provides (strong) evidential strength.
# Therefore, this hypothesis is **UNLIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.92, margin=0.86)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?) is not clearly likely to change the predicted T2DM severity.
#
# The first variable showed:
# The PR interval, particularly when prolonged, is associated with adverse cardiovascular outcomes such as increased mortality and heart failure. However, there is no direct evidence linking a high PR interval to an increased likelihood of Type 2 Diabetes Mellitus.
#
# The second variable showed:
# High cholesterol, especially elevated LDL cholesterol, is strongly associated with coronary heart disease. While lifestyle modifications for cholesterol management are crucial, there is no direct evidence provided linking high cholesterol to an increased likelihood of Type 2 Diabetes Mellitus.
#
# The combination of the variables showed:
# There is no clear evidence or research provided that directly links the combination of a high PR interval and high cholesterol to an increased likelihood of Type 2 Diabetes Mellitus. The effects on cardiovascular health are noted, but not specifically on T2DM.
#
# Therefore, this hypothesis is insufficiently supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH PR Interval AND HIGH Cholesterol) is unlikely to change the predicted T2DM severity.
#
# The first variable showed: high PR interval alone did not alter the predicted class probabilities.
#
# The second variable showed: high cholesterol alone did not alter the predicted class probabilities.
#
# The combination of the variables showed: no change in top class (“study_group_healthy”), confidence (0.7735), or any class probability.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: High
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does Heart Attack AND Age-Related Macular Degeneration (Am affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does Heart Attack AND Age-Related Macular Degeneration (Am affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of Heart Attack:
#   Predicted class: healthy (conf=0.80)
#   Delta to baseline: Low (-0.08)
#   Among patients with Heart Attack (68 patients), the predicted class distribution is: oral_medicated: 32/68 (47.1%), insulin_dependent: 19/68 (27.9%), healthy: 9/68 (13.2%), prediabetes: 8/68 (11.8%).
#   Out of all predicted patients:
#     - healthy: 9/376 (2.4%) have Heart Attack
#     - prediabetes: 8/285 (2.8%) have Heart Attack
#     - oral_medicated: 32/317 (10.1%) have Heart Attack
#     - insulin_dependent: 19/99 (19.2%) have Heart Attack
#
# Effect of Age-Related Macular Degeneration (Am:
#   Predicted class: healthy (conf=0.87)
#   Delta to baseline: Low (-0.01)
#   Among patients with Age-Related Macular Degeneration (Am (60 patients), the predicted class distribution is: insulin_dependent: 18/60 (30.0%), healthy: 18/60 (30.0%), prediabetes: 14/60 (23.3%), oral_medicated: 10/60 (16.7%).
#   Out of all predicted patients:
#     - healthy: 18/376 (4.8%) have Age-Related Macular Degeneration (Am
#     - prediabetes: 14/285 (4.9%) have Age-Related Macular Degeneration (Am
#     - oral_medicated: 10/317 (3.2%) have Age-Related Macular Degeneration (Am
#     - insulin_dependent: 18/99 (18.2%) have Age-Related Macular Degeneration (Am
#
# Combined effect of Heart Attack AND Age-Related Macular Degeneration (Am:
#   Predicted class: healthy (conf=0.69)
#   Delta to baseline: Moderate (-0.19)
#   Among patients with Heart Attack AND Age-Related Macular Degeneration (Am (11 patients), the predicted class distribution is: oral_medicated: 5/11 (45.5%), insulin_dependent: 4/11 (36.4%), healthy: 2/11 (18.2%).
#   Out of all predicted patients:
#     - healthy: 2/376 (0.5%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - prediabetes: 0/285 (0.0%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - oral_medicated: 5/317 (1.6%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - insulin_dependent: 4/99 (4.0%) have Heart Attack AND Age-Related Macular Degeneration (Am
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.73) [Δhealthy=-0.15, Δpred=+0.11, Δoral=+0.03, Δins=+0.01]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.77) [Δhealthy=-0.00, Δpred=-0.06, Δoral=+0.08, Δins=-0.02]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.54) [Δhealthy=+0.04, Δpred=+0.10, Δoral=-0.16, Δins=+0.03]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.51) [Δhealthy=+0.03, Δpred=+0.08, Δoral=-0.14, Δins=+0.02]
#
#
# === Conclusion ===============================
#
# In this model,
# (Heart Attack=None AND Age-Related Macular Degeneration (Am=None) very strongly increases the predicted T2DM severity
# (Severity: 0.121 → 0.312, Δ=+0.191).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (substantial) probability shifts, (no) class transitions, and (large) increase in severity.
# The subgroup size (n=11) provides (weak) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Moderate (top_conf=0.69, margin=0.52)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does Heart Attack AND Age-Related Macular Degeneration (AMD) affect your likelihood of Type 2 Diabetes?) is not clearly likely to change the predicted T2DM severity.
#
# The first variable showed:
# Heart attacks are associated with risk factors such as high LDL cholesterol levels, high blood pressure, smoking, physical inactivity, obesity, and diabetes, which are significant contributors to cardiovascular risk.
#
# The second variable showed:
# Age-related macular degeneration is influenced by older age, lifestyle factors like smoking and dietary habits, and genetic factors. There is no direct evidence linking AMD to T2DM in the provided context.
#
# The combination of the variables showed:
# There is no clear evidence in the provided context that the combination of heart attack and AMD directly affects the likelihood of developing T2DM. The shared risk factors like smoking and obesity may indirectly relate to T2DM, but this is not explicitly supported by the evidence.
#
# Therefore, this hypothesis is insufficiently supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (Heart Attack AND Age-Related Macular Degeneration) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# Heart Attack alone did not alter the model’s predicted class or probabilities for T2DM.
#
# The second variable showed:
# Age-Related Macular Degeneration alone did not alter the model’s predicted class or probabilities for T2DM.
#
# The combination of the variables showed:
# Adding both conditions together left the top class, confidence, and all class probabilities unchanged.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH Blood Glucose affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Blood Glucose:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Blood Glucose (948 patients), the predicted class distribution is: healthy: 364/948 (38.4%), oral_medicated: 258/948 (27.2%), prediabetes: 253/948 (26.7%), insulin_dependent: 73/948 (7.7%).
#   Out of all predicted patients:
#     - healthy: 364/376 (96.8%) have HIGH Blood Glucose
#     - prediabetes: 253/285 (88.8%) have HIGH Blood Glucose
#     - oral_medicated: 258/317 (81.4%) have HIGH Blood Glucose
#     - insulin_dependent: 73/99 (73.7%) have HIGH Blood Glucose
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.87) [Δhealthy=-0.01, Δpred=+0.01, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.83) [Δhealthy=-0.00, Δpred=-0.00, Δoral=-0.00, Δins=+0.00]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.67) [Δhealthy=+0.01, Δpred=+0.02, Δoral=-0.02, Δins=+0.00]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.58) [Δhealthy=+0.00, Δpred=+0.02, Δoral=-0.06, Δins=+0.04]
#
#
# === Conclusion ===============================
#
# In this model,
# (Blood Glucose=HIGH AND None=None) increases the predicted T2DM severity
# (Severity: 0.121 → 0.216, Δ=+0.095).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (mixed) probability shifts, (no) class transitions, and (moderate) increase in severity.
# The subgroup size (n=948) provides (strong) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.78, margin=0.68)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?) is likely to change the predicted T2DM severity.
#
# The first variable showed:
# High blood glucose levels are crucial for energy production and are tightly regulated in the body. Chronic elevations in blood glucose, or hyperglycemia, are linked to diabetes mellitus and its complications, such as heart disease, stroke, and kidney failure.
#
# The second variable showed:
# The term "None" is unclear in this context, but it seems to imply the absence of other comorbid conditions. There is no direct evidence provided on how the absence of comorbid conditions alone affects T2DM likelihood.
#
# The combination of the variables showed:
# The combination of high blood glucose with no additional comorbid conditions primarily highlights the impact of hyperglycemia on diabetes severity. The effect is mostly driven by the high blood glucose levels.
#
# Therefore, this hypothesis is moderately supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Moderate
#
# Model reliability: Moderate
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH Blood Glucose AND None) is unlikely to change the predicted T2DM severity.
#
# The first variable showed: HIGH Blood Glucose alone produced no shift in class or probabilities.
# The second variable showed: None alone produced no shift in class or probabilities.
# The combination of the variables showed: identical class and probabilities to baseline, with no change in confidence or severity.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH Sleep affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Sleep:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Sleep (328 patients), the predicted class distribution is: healthy: 116/328 (35.4%), oral_medicated: 106/328 (32.3%), prediabetes: 78/328 (23.8%), insulin_dependent: 28/328 (8.5%).
#   Out of all predicted patients:
#     - healthy: 116/376 (30.9%) have HIGH Sleep
#     - prediabetes: 78/285 (27.4%) have HIGH Sleep
#     - oral_medicated: 106/317 (33.4%) have HIGH Sleep
#     - insulin_dependent: 28/99 (28.3%) have HIGH Sleep
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.88) [Δhealthy=-0.00, Δpred=-0.00, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.82) [Δhealthy=+0.00, Δpred=-0.01, Δoral=+0.00, Δins=+0.01]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.68) [Δhealthy=+0.00, Δpred=+0.02, Δoral=-0.01, Δins=-0.01]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.62) [Δhealthy=+0.00, Δpred=+0.01, Δoral=-0.02, Δins=+0.01]
#
#
# === Conclusion ===============================
#
# In this model,
# (Sleep=HIGH AND None=None) is unlikely to change the predicted T2DM severity
# (Severity: 0.121 → 0.127, Δ=+0.006).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (minimal) probability shifts, (no) class transitions, and (minimal) increase in severity.
# The subgroup size (n=328) provides (strong) evidential strength.
# Therefore, this hypothesis is **UNLIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.87, margin=0.80)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# High sleep duration, typically more than 9 hours, was not directly linked to increased T2DM risk. Most research focuses on short sleep duration as a risk factor.
#
# The second variable showed:
# The absence of additional medical conditions was intended to isolate the effect of sleep duration, but no specific evidence was provided regarding its impact on T2DM risk.
#
# The combination of the variables showed:
# There is insufficient evidence to suggest that high sleep duration without other medical conditions significantly affects T2DM likelihood. The focus on short sleep duration as a risk factor is more prevalent in existing research.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH Sleep AND None) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# HIGH Sleep alone did not alter the predicted class, confidence, or any class probabilities.
#
# The second variable showed:
# None alone did not alter the predicted class, confidence, or any class probabilities.
#
# The combination of the variables showed:
# No change in predicted class, confidence, or class probabilities compared to the baseline.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: High
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Glucose:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Glucose (870 patients), the predicted class distribution is: healthy: 354/870 (40.7%), prediabetes: 245/870 (28.2%), oral_medicated: 208/870 (23.9%), insulin_dependent: 63/870 (7.2%).
#   Out of all predicted patients:
#     - healthy: 354/376 (94.1%) have HIGH Glucose
#     - prediabetes: 245/285 (86.0%) have HIGH Glucose
#     - oral_medicated: 208/317 (65.6%) have HIGH Glucose
#     - insulin_dependent: 63/99 (63.6%) have HIGH Glucose
#
# Effect of Retinal Vascular Occlusion ("Stroke:
#   Predicted class: prediabetes (conf=0.55)
#   Delta to baseline: High (-0.33)
#   Among patients with Retinal Vascular Occlusion ("Stroke (15 patients), the predicted class distribution is: insulin_dependent: 7/15 (46.7%), prediabetes: 3/15 (20.0%), healthy: 3/15 (20.0%), oral_medicated: 2/15 (13.3%).
#   Out of all predicted patients:
#     - healthy: 3/376 (0.8%) have Retinal Vascular Occlusion ("Stroke
#     - prediabetes: 3/285 (1.1%) have Retinal Vascular Occlusion ("Stroke
#     - oral_medicated: 2/317 (0.6%) have Retinal Vascular Occlusion ("Stroke
#     - insulin_dependent: 7/99 (7.1%) have Retinal Vascular Occlusion ("Stroke
#
# Combined effect of HIGH Glucose AND Retinal Vascular Occlusion ("Stroke:
#   Predicted class: prediabetes (conf=0.55)
#   Delta to baseline: High (-0.33)
#   Among patients with HIGH Glucose AND Retinal Vascular Occlusion ("Stroke (10 patients), the predicted class distribution is: insulin_dependent: 3/10 (30.0%), prediabetes: 3/10 (30.0%), healthy: 3/10 (30.0%), oral_medicated: 1/10 (10.0%).
#   Out of all predicted patients:
#     - healthy: 3/376 (0.8%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - prediabetes: 3/285 (1.1%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - oral_medicated: 1/317 (0.3%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - insulin_dependent: 3/99 (3.0%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → prediabetes (0.74) [Δhealthy=-0.67, Δpred=+0.65, Δoral=+0.01, Δins=+0.01]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.90) [Δhealthy=-0.00, Δpred=+0.07, Δoral=-0.05, Δins=-0.02]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.47) [Δhealthy=-0.01, Δpred=+0.04, Δoral=-0.23, Δins=+0.19]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → insulin_dependent (0.50) [Δhealthy=-0.01, Δpred=-0.01, Δoral=-0.20, Δins=+0.22]
#
#
# === Conclusion ===============================
#
# In this model,
# (Glucose=HIGH AND Retinal Vascular Occlusion ("Stroke=None) very strongly increases the predicted T2DM severity
# (Severity: 0.121 → 0.624, Δ=+0.503).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (substantial) probability shifts, (some) class transitions, and (large) increase in severity.
# The subgroup size (n=10) provides (weak) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low (top_conf=0.54, margin=0.17)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# Persistent hyperglycemia is linked to diabetic retinopathy and retinal vascular occlusion through inflammation and endothelial dysfunction, indicating a connection to retinal diseases but not directly altering T2DM severity.
#
# The second variable showed:
# Retinal vascular occlusion is influenced by metabolic factors like insulin resistance and elevated homocysteine levels, which are risk factors for retinal diseases but do not directly impact T2DM severity.
#
# The combination of the variables showed:
# While both high glucose levels and retinal vascular occlusion are associated with retinal diseases, there is no clear evidence that their combination directly affects the likelihood or severity of T2DM.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Moderate
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH Glucose AND Retinal Vascular Occlusion (“Stroke”)) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# no detectable change in the predicted T2DM severity when added.
#
# The second variable showed:
# no detectable change in the predicted T2DM severity when added.
#
# The combination of the variables showed:
# no change in top‐predicted class or class probabilities.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
# ============================================

# %% [markdown]
# # Saving to an excel file

# %%
for i in range(5):

    r = results[i]

    hypothesis_text = clean_hypothesis_text(r)

    part_a_text = r["report"]
    part_a_summary = PartA_conclusion_results[i]["conclusion"]
    part_b_text = all_final_outputs[i]["final_output"]      # or executor_runs[i]["final_markdown"], depending on what you want
    part_c_text = pipeline_results[i]["result"]

    full_summary = build_full_hypothesis_summary(
        hypothesis_text=hypothesis_text,
        part_a_text=part_a_text,
        part_a_summary=part_a_summary,
        part_b_text=part_b_text,
        part_c_text=part_c_text
    )

    print("\n" + "=" * 80)
    print(full_summary)
# Out:
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH PR Interval AND HIGH Cholesterol affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH PR Interval:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH PR Interval (923 patients), the predicted class distribution is: healthy: 326/923 (35.3%), oral_medicated: 261/923 (28.3%), prediabetes: 230/923 (24.9%), insulin_dependent: 106/923 (11.5%).
#   Out of all predicted patients:
#     - healthy: 326/376 (86.7%) have HIGH PR Interval
#     - prediabetes: 230/285 (80.7%) have HIGH PR Interval
#     - oral_medicated: 261/317 (82.3%) have HIGH PR Interval
#     - insulin_dependent: 106/99 (107.1%) have HIGH PR Interval
#
# Effect of HIGH Cholesterol:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Cholesterol (1072 patients), the predicted class distribution is: healthy: 369/1072 (34.4%), oral_medicated: 312/1072 (29.1%), prediabetes: 262/1072 (24.4%), insulin_dependent: 129/1072 (12.0%).
#   Out of all predicted patients:
#     - healthy: 369/376 (98.1%) have HIGH Cholesterol
#     - prediabetes: 262/285 (91.9%) have HIGH Cholesterol
#     - oral_medicated: 312/317 (98.4%) have HIGH Cholesterol
#     - insulin_dependent: 129/99 (130.3%) have HIGH Cholesterol
#
# Combined effect of HIGH PR Interval AND HIGH Cholesterol:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH PR Interval AND HIGH Cholesterol (919 patients), the predicted class distribution is: healthy: 323/919 (35.1%), oral_medicated: 261/919 (28.4%), prediabetes: 229/919 (24.9%), insulin_dependent: 106/919 (11.5%).
#   Out of all predicted patients:
#     - healthy: 323/376 (85.9%) have HIGH PR Interval AND HIGH Cholesterol
#     - prediabetes: 229/285 (80.4%) have HIGH PR Interval AND HIGH Cholesterol
#     - oral_medicated: 261/317 (82.3%) have HIGH PR Interval AND HIGH Cholesterol
#     - insulin_dependent: 106/99 (107.1%) have HIGH PR Interval AND HIGH Cholesterol
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.88) [Δhealthy=-0.00, Δpred=+0.00, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.84) [Δhealthy=-0.00, Δpred=+0.01, Δoral=-0.00, Δins=-0.00]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.61) [Δhealthy=+0.01, Δpred=+0.08, Δoral=-0.09, Δins=+0.01]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.60) [Δhealthy=+0.01, Δpred=+0.05, Δoral=-0.05, Δins=-0.01]
#
#
# === Conclusion ===============================
#
# In this model,
# (PR Interval=HIGH AND Cholesterol=HIGH) is unlikely to change the predicted T2DM severity
# (Severity: 0.121 → 0.083, Δ=-0.038).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (mixed) probability shifts, (no) class transitions, and (no) increase in severity.
# The subgroup size (n=919) provides (strong) evidential strength.
# Therefore, this hypothesis is **UNLIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.92, margin=0.86)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?) is not clearly likely to change the predicted T2DM severity.
#
# The first variable showed:
# The PR interval, particularly when prolonged, is associated with adverse cardiovascular outcomes such as increased mortality and heart failure. However, there is no direct evidence linking a high PR interval to an increased likelihood of Type 2 Diabetes Mellitus.
#
# The second variable showed:
# High cholesterol, especially elevated LDL cholesterol, is strongly associated with coronary heart disease. While lifestyle modifications for cholesterol management are crucial, there is no direct evidence provided linking high cholesterol to an increased likelihood of Type 2 Diabetes Mellitus.
#
# The combination of the variables showed:
# There is no clear evidence or research provided that directly links the combination of a high PR interval and high cholesterol to an increased likelihood of Type 2 Diabetes Mellitus. The effects on cardiovascular health are noted, but not specifically on T2DM.
#
# Therefore, this hypothesis is insufficiently supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH PR Interval AND HIGH Cholesterol) is unlikely to change the predicted T2DM severity.
#
# The first variable showed: high PR interval alone did not alter the predicted class probabilities.
#
# The second variable showed: high cholesterol alone did not alter the predicted class probabilities.
#
# The combination of the variables showed: no change in top class (“study_group_healthy”), confidence (0.7735), or any class probability.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: High
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does Heart Attack AND Age-Related Macular Degeneration (Am affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does Heart Attack AND Age-Related Macular Degeneration (Am affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of Heart Attack:
#   Predicted class: healthy (conf=0.80)
#   Delta to baseline: Low (-0.08)
#   Among patients with Heart Attack (68 patients), the predicted class distribution is: oral_medicated: 32/68 (47.1%), insulin_dependent: 19/68 (27.9%), healthy: 9/68 (13.2%), prediabetes: 8/68 (11.8%).
#   Out of all predicted patients:
#     - healthy: 9/376 (2.4%) have Heart Attack
#     - prediabetes: 8/285 (2.8%) have Heart Attack
#     - oral_medicated: 32/317 (10.1%) have Heart Attack
#     - insulin_dependent: 19/99 (19.2%) have Heart Attack
#
# Effect of Age-Related Macular Degeneration (Am:
#   Predicted class: healthy (conf=0.87)
#   Delta to baseline: Low (-0.01)
#   Among patients with Age-Related Macular Degeneration (Am (60 patients), the predicted class distribution is: insulin_dependent: 18/60 (30.0%), healthy: 18/60 (30.0%), prediabetes: 14/60 (23.3%), oral_medicated: 10/60 (16.7%).
#   Out of all predicted patients:
#     - healthy: 18/376 (4.8%) have Age-Related Macular Degeneration (Am
#     - prediabetes: 14/285 (4.9%) have Age-Related Macular Degeneration (Am
#     - oral_medicated: 10/317 (3.2%) have Age-Related Macular Degeneration (Am
#     - insulin_dependent: 18/99 (18.2%) have Age-Related Macular Degeneration (Am
#
# Combined effect of Heart Attack AND Age-Related Macular Degeneration (Am:
#   Predicted class: healthy (conf=0.69)
#   Delta to baseline: Moderate (-0.19)
#   Among patients with Heart Attack AND Age-Related Macular Degeneration (Am (11 patients), the predicted class distribution is: oral_medicated: 5/11 (45.5%), insulin_dependent: 4/11 (36.4%), healthy: 2/11 (18.2%).
#   Out of all predicted patients:
#     - healthy: 2/376 (0.5%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - prediabetes: 0/285 (0.0%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - oral_medicated: 5/317 (1.6%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - insulin_dependent: 4/99 (4.0%) have Heart Attack AND Age-Related Macular Degeneration (Am
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.73) [Δhealthy=-0.15, Δpred=+0.11, Δoral=+0.03, Δins=+0.01]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.77) [Δhealthy=-0.00, Δpred=-0.06, Δoral=+0.08, Δins=-0.02]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.54) [Δhealthy=+0.04, Δpred=+0.10, Δoral=-0.16, Δins=+0.03]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.51) [Δhealthy=+0.03, Δpred=+0.08, Δoral=-0.14, Δins=+0.02]
#
#
# === Conclusion ===============================
#
# In this model,
# (Heart Attack=None AND Age-Related Macular Degeneration (Am=None) very strongly increases the predicted T2DM severity
# (Severity: 0.121 → 0.312, Δ=+0.191).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (substantial) probability shifts, (no) class transitions, and (large) increase in severity.
# The subgroup size (n=11) provides (weak) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Moderate (top_conf=0.69, margin=0.52)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does Heart Attack AND Age-Related Macular Degeneration (AMD) affect your likelihood of Type 2 Diabetes?) is not clearly likely to change the predicted T2DM severity.
#
# The first variable showed:
# Heart attacks are associated with risk factors such as high LDL cholesterol levels, high blood pressure, smoking, physical inactivity, obesity, and diabetes, which are significant contributors to cardiovascular risk.
#
# The second variable showed:
# Age-related macular degeneration is influenced by older age, lifestyle factors like smoking and dietary habits, and genetic factors. There is no direct evidence linking AMD to T2DM in the provided context.
#
# The combination of the variables showed:
# There is no clear evidence in the provided context that the combination of heart attack and AMD directly affects the likelihood of developing T2DM. The shared risk factors like smoking and obesity may indirectly relate to T2DM, but this is not explicitly supported by the evidence.
#
# Therefore, this hypothesis is insufficiently supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (Heart Attack AND Age-Related Macular Degeneration) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# Heart Attack alone did not alter the model’s predicted class or probabilities for T2DM.
#
# The second variable showed:
# Age-Related Macular Degeneration alone did not alter the model’s predicted class or probabilities for T2DM.
#
# The combination of the variables showed:
# Adding both conditions together left the top class, confidence, and all class probabilities unchanged.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH Blood Glucose affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Blood Glucose:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Blood Glucose (948 patients), the predicted class distribution is: healthy: 364/948 (38.4%), oral_medicated: 258/948 (27.2%), prediabetes: 253/948 (26.7%), insulin_dependent: 73/948 (7.7%).
#   Out of all predicted patients:
#     - healthy: 364/376 (96.8%) have HIGH Blood Glucose
#     - prediabetes: 253/285 (88.8%) have HIGH Blood Glucose
#     - oral_medicated: 258/317 (81.4%) have HIGH Blood Glucose
#     - insulin_dependent: 73/99 (73.7%) have HIGH Blood Glucose
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.87) [Δhealthy=-0.01, Δpred=+0.01, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.83) [Δhealthy=-0.00, Δpred=-0.00, Δoral=-0.00, Δins=+0.00]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.67) [Δhealthy=+0.01, Δpred=+0.02, Δoral=-0.02, Δins=+0.00]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.58) [Δhealthy=+0.00, Δpred=+0.02, Δoral=-0.06, Δins=+0.04]
#
#
# === Conclusion ===============================
#
# In this model,
# (Blood Glucose=HIGH AND None=None) increases the predicted T2DM severity
# (Severity: 0.121 → 0.216, Δ=+0.095).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (mixed) probability shifts, (no) class transitions, and (moderate) increase in severity.
# The subgroup size (n=948) provides (strong) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.78, margin=0.68)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?) is likely to change the predicted T2DM severity.
#
# The first variable showed:
# High blood glucose levels are crucial for energy production and are tightly regulated in the body. Chronic elevations in blood glucose, or hyperglycemia, are linked to diabetes mellitus and its complications, such as heart disease, stroke, and kidney failure.
#
# The second variable showed:
# The term "None" is unclear in this context, but it seems to imply the absence of other comorbid conditions. There is no direct evidence provided on how the absence of comorbid conditions alone affects T2DM likelihood.
#
# The combination of the variables showed:
# The combination of high blood glucose with no additional comorbid conditions primarily highlights the impact of hyperglycemia on diabetes severity. The effect is mostly driven by the high blood glucose levels.
#
# Therefore, this hypothesis is moderately supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Moderate
#
# Model reliability: Moderate
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH Blood Glucose AND None) is unlikely to change the predicted T2DM severity.
#
# The first variable showed: HIGH Blood Glucose alone produced no shift in class or probabilities.
# The second variable showed: None alone produced no shift in class or probabilities.
# The combination of the variables showed: identical class and probabilities to baseline, with no change in confidence or severity.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH Sleep affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Sleep:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Sleep (328 patients), the predicted class distribution is: healthy: 116/328 (35.4%), oral_medicated: 106/328 (32.3%), prediabetes: 78/328 (23.8%), insulin_dependent: 28/328 (8.5%).
#   Out of all predicted patients:
#     - healthy: 116/376 (30.9%) have HIGH Sleep
#     - prediabetes: 78/285 (27.4%) have HIGH Sleep
#     - oral_medicated: 106/317 (33.4%) have HIGH Sleep
#     - insulin_dependent: 28/99 (28.3%) have HIGH Sleep
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.88) [Δhealthy=-0.00, Δpred=-0.00, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.82) [Δhealthy=+0.00, Δpred=-0.01, Δoral=+0.00, Δins=+0.01]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.68) [Δhealthy=+0.00, Δpred=+0.02, Δoral=-0.01, Δins=-0.01]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.62) [Δhealthy=+0.00, Δpred=+0.01, Δoral=-0.02, Δins=+0.01]
#
#
# === Conclusion ===============================
#
# In this model,
# (Sleep=HIGH AND None=None) is unlikely to change the predicted T2DM severity
# (Severity: 0.121 → 0.127, Δ=+0.006).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (minimal) probability shifts, (no) class transitions, and (minimal) increase in severity.
# The subgroup size (n=328) provides (strong) evidential strength.
# Therefore, this hypothesis is **UNLIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.87, margin=0.80)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# High sleep duration, typically more than 9 hours, was not directly linked to increased T2DM risk. Most research focuses on short sleep duration as a risk factor.
#
# The second variable showed:
# The absence of additional medical conditions was intended to isolate the effect of sleep duration, but no specific evidence was provided regarding its impact on T2DM risk.
#
# The combination of the variables showed:
# There is insufficient evidence to suggest that high sleep duration without other medical conditions significantly affects T2DM likelihood. The focus on short sleep duration as a risk factor is more prevalent in existing research.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH Sleep AND None) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# HIGH Sleep alone did not alter the predicted class, confidence, or any class probabilities.
#
# The second variable showed:
# None alone did not alter the predicted class, confidence, or any class probabilities.
#
# The combination of the variables showed:
# No change in predicted class, confidence, or class probabilities compared to the baseline.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: High
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Glucose:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Glucose (870 patients), the predicted class distribution is: healthy: 354/870 (40.7%), prediabetes: 245/870 (28.2%), oral_medicated: 208/870 (23.9%), insulin_dependent: 63/870 (7.2%).
#   Out of all predicted patients:
#     - healthy: 354/376 (94.1%) have HIGH Glucose
#     - prediabetes: 245/285 (86.0%) have HIGH Glucose
#     - oral_medicated: 208/317 (65.6%) have HIGH Glucose
#     - insulin_dependent: 63/99 (63.6%) have HIGH Glucose
#
# Effect of Retinal Vascular Occlusion ("Stroke:
#   Predicted class: prediabetes (conf=0.55)
#   Delta to baseline: High (-0.33)
#   Among patients with Retinal Vascular Occlusion ("Stroke (15 patients), the predicted class distribution is: insulin_dependent: 7/15 (46.7%), prediabetes: 3/15 (20.0%), healthy: 3/15 (20.0%), oral_medicated: 2/15 (13.3%).
#   Out of all predicted patients:
#     - healthy: 3/376 (0.8%) have Retinal Vascular Occlusion ("Stroke
#     - prediabetes: 3/285 (1.1%) have Retinal Vascular Occlusion ("Stroke
#     - oral_medicated: 2/317 (0.6%) have Retinal Vascular Occlusion ("Stroke
#     - insulin_dependent: 7/99 (7.1%) have Retinal Vascular Occlusion ("Stroke
#
# Combined effect of HIGH Glucose AND Retinal Vascular Occlusion ("Stroke:
#   Predicted class: prediabetes (conf=0.55)
#   Delta to baseline: High (-0.33)
#   Among patients with HIGH Glucose AND Retinal Vascular Occlusion ("Stroke (10 patients), the predicted class distribution is: insulin_dependent: 3/10 (30.0%), prediabetes: 3/10 (30.0%), healthy: 3/10 (30.0%), oral_medicated: 1/10 (10.0%).
#   Out of all predicted patients:
#     - healthy: 3/376 (0.8%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - prediabetes: 3/285 (1.1%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - oral_medicated: 1/317 (0.3%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - insulin_dependent: 3/99 (3.0%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → prediabetes (0.74) [Δhealthy=-0.67, Δpred=+0.65, Δoral=+0.01, Δins=+0.01]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.90) [Δhealthy=-0.00, Δpred=+0.07, Δoral=-0.05, Δins=-0.02]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.47) [Δhealthy=-0.01, Δpred=+0.04, Δoral=-0.23, Δins=+0.19]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → insulin_dependent (0.50) [Δhealthy=-0.01, Δpred=-0.01, Δoral=-0.20, Δins=+0.22]
#
#
# === Conclusion ===============================
#
# In this model,
# (Glucose=HIGH AND Retinal Vascular Occlusion ("Stroke=None) very strongly increases the predicted T2DM severity
# (Severity: 0.121 → 0.624, Δ=+0.503).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (substantial) probability shifts, (some) class transitions, and (large) increase in severity.
# The subgroup size (n=10) provides (weak) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low (top_conf=0.54, margin=0.17)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# Persistent hyperglycemia is linked to diabetic retinopathy and retinal vascular occlusion through inflammation and endothelial dysfunction, indicating a connection to retinal diseases but not directly altering T2DM severity.
#
# The second variable showed:
# Retinal vascular occlusion is influenced by metabolic factors like insulin resistance and elevated homocysteine levels, which are risk factors for retinal diseases but do not directly impact T2DM severity.
#
# The combination of the variables showed:
# While both high glucose levels and retinal vascular occlusion are associated with retinal diseases, there is no clear evidence that their combination directly affects the likelihood or severity of T2DM.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Moderate
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH Glucose AND Retinal Vascular Occlusion (“Stroke”)) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# no detectable change in the predicted T2DM severity when added.
#
# The second variable showed:
# no detectable change in the predicted T2DM severity when added.
#
# The combination of the variables showed:
# no change in top‐predicted class or class probabilities.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
# ============================================

# %%
import pandas as pd

final_summary_rows = []

for i in range(5):

    r = results[i]

    hypothesis_text = clean_hypothesis_text(r)

    part_a_text = r["report"]
    part_a_summary = PartA_conclusion_results[i]["conclusion"]
    part_b_text = all_final_outputs[i]["final_output"]
    part_c_text = pipeline_results[i]["result"]

    full_summary = build_full_hypothesis_summary(
        hypothesis_text=hypothesis_text,
        part_a_text=part_a_text,
        part_a_summary=part_a_summary,
        part_b_text=part_b_text,
        part_c_text=part_c_text
    )

    print("\n" + "=" * 80)
    print(full_summary)

    final_summary_rows.append({
        "question_num": i + 1,
        "hypothesis": hypothesis_text,
        "part_a_summary": part_a_summary,
        "part_b_summary": part_b_text,
        "part_c_summary": part_c_text,
        "full_summary": full_summary
    })
# Out:
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH PR Interval AND HIGH Cholesterol affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH PR Interval:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH PR Interval (923 patients), the predicted class distribution is: healthy: 326/923 (35.3%), oral_medicated: 261/923 (28.3%), prediabetes: 230/923 (24.9%), insulin_dependent: 106/923 (11.5%).
#   Out of all predicted patients:
#     - healthy: 326/376 (86.7%) have HIGH PR Interval
#     - prediabetes: 230/285 (80.7%) have HIGH PR Interval
#     - oral_medicated: 261/317 (82.3%) have HIGH PR Interval
#     - insulin_dependent: 106/99 (107.1%) have HIGH PR Interval
#
# Effect of HIGH Cholesterol:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Cholesterol (1072 patients), the predicted class distribution is: healthy: 369/1072 (34.4%), oral_medicated: 312/1072 (29.1%), prediabetes: 262/1072 (24.4%), insulin_dependent: 129/1072 (12.0%).
#   Out of all predicted patients:
#     - healthy: 369/376 (98.1%) have HIGH Cholesterol
#     - prediabetes: 262/285 (91.9%) have HIGH Cholesterol
#     - oral_medicated: 312/317 (98.4%) have HIGH Cholesterol
#     - insulin_dependent: 129/99 (130.3%) have HIGH Cholesterol
#
# Combined effect of HIGH PR Interval AND HIGH Cholesterol:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH PR Interval AND HIGH Cholesterol (919 patients), the predicted class distribution is: healthy: 323/919 (35.1%), oral_medicated: 261/919 (28.4%), prediabetes: 229/919 (24.9%), insulin_dependent: 106/919 (11.5%).
#   Out of all predicted patients:
#     - healthy: 323/376 (85.9%) have HIGH PR Interval AND HIGH Cholesterol
#     - prediabetes: 229/285 (80.4%) have HIGH PR Interval AND HIGH Cholesterol
#     - oral_medicated: 261/317 (82.3%) have HIGH PR Interval AND HIGH Cholesterol
#     - insulin_dependent: 106/99 (107.1%) have HIGH PR Interval AND HIGH Cholesterol
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.88) [Δhealthy=-0.00, Δpred=+0.00, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.84) [Δhealthy=-0.00, Δpred=+0.01, Δoral=-0.00, Δins=-0.00]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.61) [Δhealthy=+0.01, Δpred=+0.08, Δoral=-0.09, Δins=+0.01]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.60) [Δhealthy=+0.01, Δpred=+0.05, Δoral=-0.05, Δins=-0.01]
#
#
# === Conclusion ===============================
#
# In this model,
# (PR Interval=HIGH AND Cholesterol=HIGH) is unlikely to change the predicted T2DM severity
# (Severity: 0.121 → 0.083, Δ=-0.038).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (mixed) probability shifts, (no) class transitions, and (no) increase in severity.
# The subgroup size (n=919) provides (strong) evidential strength.
# Therefore, this hypothesis is **UNLIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.92, margin=0.86)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH PR Interval AND HIGH Cholesterol affect your likelihood of Type 2 Diabetes?) is not clearly likely to change the predicted T2DM severity.
#
# The first variable showed:
# The PR interval, particularly when prolonged, is associated with adverse cardiovascular outcomes such as increased mortality and heart failure. However, there is no direct evidence linking a high PR interval to an increased likelihood of Type 2 Diabetes Mellitus.
#
# The second variable showed:
# High cholesterol, especially elevated LDL cholesterol, is strongly associated with coronary heart disease. While lifestyle modifications for cholesterol management are crucial, there is no direct evidence provided linking high cholesterol to an increased likelihood of Type 2 Diabetes Mellitus.
#
# The combination of the variables showed:
# There is no clear evidence or research provided that directly links the combination of a high PR interval and high cholesterol to an increased likelihood of Type 2 Diabetes Mellitus. The effects on cardiovascular health are noted, but not specifically on T2DM.
#
# Therefore, this hypothesis is insufficiently supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH PR Interval AND HIGH Cholesterol) is unlikely to change the predicted T2DM severity.
#
# The first variable showed: high PR interval alone did not alter the predicted class probabilities.
#
# The second variable showed: high cholesterol alone did not alter the predicted class probabilities.
#
# The combination of the variables showed: no change in top class (“study_group_healthy”), confidence (0.7735), or any class probability.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: High
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does Heart Attack AND Age-Related Macular Degeneration (Am affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does Heart Attack AND Age-Related Macular Degeneration (Am affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of Heart Attack:
#   Predicted class: healthy (conf=0.80)
#   Delta to baseline: Low (-0.08)
#   Among patients with Heart Attack (68 patients), the predicted class distribution is: oral_medicated: 32/68 (47.1%), insulin_dependent: 19/68 (27.9%), healthy: 9/68 (13.2%), prediabetes: 8/68 (11.8%).
#   Out of all predicted patients:
#     - healthy: 9/376 (2.4%) have Heart Attack
#     - prediabetes: 8/285 (2.8%) have Heart Attack
#     - oral_medicated: 32/317 (10.1%) have Heart Attack
#     - insulin_dependent: 19/99 (19.2%) have Heart Attack
#
# Effect of Age-Related Macular Degeneration (Am:
#   Predicted class: healthy (conf=0.87)
#   Delta to baseline: Low (-0.01)
#   Among patients with Age-Related Macular Degeneration (Am (60 patients), the predicted class distribution is: insulin_dependent: 18/60 (30.0%), healthy: 18/60 (30.0%), prediabetes: 14/60 (23.3%), oral_medicated: 10/60 (16.7%).
#   Out of all predicted patients:
#     - healthy: 18/376 (4.8%) have Age-Related Macular Degeneration (Am
#     - prediabetes: 14/285 (4.9%) have Age-Related Macular Degeneration (Am
#     - oral_medicated: 10/317 (3.2%) have Age-Related Macular Degeneration (Am
#     - insulin_dependent: 18/99 (18.2%) have Age-Related Macular Degeneration (Am
#
# Combined effect of Heart Attack AND Age-Related Macular Degeneration (Am:
#   Predicted class: healthy (conf=0.69)
#   Delta to baseline: Moderate (-0.19)
#   Among patients with Heart Attack AND Age-Related Macular Degeneration (Am (11 patients), the predicted class distribution is: oral_medicated: 5/11 (45.5%), insulin_dependent: 4/11 (36.4%), healthy: 2/11 (18.2%).
#   Out of all predicted patients:
#     - healthy: 2/376 (0.5%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - prediabetes: 0/285 (0.0%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - oral_medicated: 5/317 (1.6%) have Heart Attack AND Age-Related Macular Degeneration (Am
#     - insulin_dependent: 4/99 (4.0%) have Heart Attack AND Age-Related Macular Degeneration (Am
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.73) [Δhealthy=-0.15, Δpred=+0.11, Δoral=+0.03, Δins=+0.01]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.77) [Δhealthy=-0.00, Δpred=-0.06, Δoral=+0.08, Δins=-0.02]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.54) [Δhealthy=+0.04, Δpred=+0.10, Δoral=-0.16, Δins=+0.03]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.51) [Δhealthy=+0.03, Δpred=+0.08, Δoral=-0.14, Δins=+0.02]
#
#
# === Conclusion ===============================
#
# In this model,
# (Heart Attack=None AND Age-Related Macular Degeneration (Am=None) very strongly increases the predicted T2DM severity
# (Severity: 0.121 → 0.312, Δ=+0.191).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (substantial) probability shifts, (no) class transitions, and (large) increase in severity.
# The subgroup size (n=11) provides (weak) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Moderate (top_conf=0.69, margin=0.52)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does Heart Attack AND Age-Related Macular Degeneration (AMD) affect your likelihood of Type 2 Diabetes?) is not clearly likely to change the predicted T2DM severity.
#
# The first variable showed:
# Heart attacks are associated with risk factors such as high LDL cholesterol levels, high blood pressure, smoking, physical inactivity, obesity, and diabetes, which are significant contributors to cardiovascular risk.
#
# The second variable showed:
# Age-related macular degeneration is influenced by older age, lifestyle factors like smoking and dietary habits, and genetic factors. There is no direct evidence linking AMD to T2DM in the provided context.
#
# The combination of the variables showed:
# There is no clear evidence in the provided context that the combination of heart attack and AMD directly affects the likelihood of developing T2DM. The shared risk factors like smoking and obesity may indirectly relate to T2DM, but this is not explicitly supported by the evidence.
#
# Therefore, this hypothesis is insufficiently supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (Heart Attack AND Age-Related Macular Degeneration) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# Heart Attack alone did not alter the model’s predicted class or probabilities for T2DM.
#
# The second variable showed:
# Age-Related Macular Degeneration alone did not alter the model’s predicted class or probabilities for T2DM.
#
# The combination of the variables showed:
# Adding both conditions together left the top class, confidence, and all class probabilities unchanged.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH Blood Glucose affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Blood Glucose:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Blood Glucose (948 patients), the predicted class distribution is: healthy: 364/948 (38.4%), oral_medicated: 258/948 (27.2%), prediabetes: 253/948 (26.7%), insulin_dependent: 73/948 (7.7%).
#   Out of all predicted patients:
#     - healthy: 364/376 (96.8%) have HIGH Blood Glucose
#     - prediabetes: 253/285 (88.8%) have HIGH Blood Glucose
#     - oral_medicated: 258/317 (81.4%) have HIGH Blood Glucose
#     - insulin_dependent: 73/99 (73.7%) have HIGH Blood Glucose
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.87) [Δhealthy=-0.01, Δpred=+0.01, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.83) [Δhealthy=-0.00, Δpred=-0.00, Δoral=-0.00, Δins=+0.00]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.67) [Δhealthy=+0.01, Δpred=+0.02, Δoral=-0.02, Δins=+0.00]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.58) [Δhealthy=+0.00, Δpred=+0.02, Δoral=-0.06, Δins=+0.04]
#
#
# === Conclusion ===============================
#
# In this model,
# (Blood Glucose=HIGH AND None=None) increases the predicted T2DM severity
# (Severity: 0.121 → 0.216, Δ=+0.095).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (mixed) probability shifts, (no) class transitions, and (moderate) increase in severity.
# The subgroup size (n=948) provides (strong) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.78, margin=0.68)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH Blood Glucose AND None affect your likelihood of Type 2 Diabetes?) is likely to change the predicted T2DM severity.
#
# The first variable showed:
# High blood glucose levels are crucial for energy production and are tightly regulated in the body. Chronic elevations in blood glucose, or hyperglycemia, are linked to diabetes mellitus and its complications, such as heart disease, stroke, and kidney failure.
#
# The second variable showed:
# The term "None" is unclear in this context, but it seems to imply the absence of other comorbid conditions. There is no direct evidence provided on how the absence of comorbid conditions alone affects T2DM likelihood.
#
# The combination of the variables showed:
# The combination of high blood glucose with no additional comorbid conditions primarily highlights the impact of hyperglycemia on diabetes severity. The effect is mostly driven by the high blood glucose levels.
#
# Therefore, this hypothesis is moderately supported to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Moderate
#
# Model reliability: Moderate
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH Blood Glucose AND None) is unlikely to change the predicted T2DM severity.
#
# The first variable showed: HIGH Blood Glucose alone produced no shift in class or probabilities.
# The second variable showed: None alone produced no shift in class or probabilities.
# The combination of the variables showed: identical class and probabilities to baseline, with no change in confidence or severity.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH Sleep affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Sleep:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Sleep (328 patients), the predicted class distribution is: healthy: 116/328 (35.4%), oral_medicated: 106/328 (32.3%), prediabetes: 78/328 (23.8%), insulin_dependent: 28/328 (8.5%).
#   Out of all predicted patients:
#     - healthy: 116/376 (30.9%) have HIGH Sleep
#     - prediabetes: 78/285 (27.4%) have HIGH Sleep
#     - oral_medicated: 106/317 (33.4%) have HIGH Sleep
#     - insulin_dependent: 28/99 (28.3%) have HIGH Sleep
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → healthy (0.88) [Δhealthy=-0.00, Δpred=-0.00, Δoral=+0.00, Δins=+0.00]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.82) [Δhealthy=+0.00, Δpred=-0.01, Δoral=+0.00, Δins=+0.01]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.68) [Δhealthy=+0.00, Δpred=+0.02, Δoral=-0.01, Δins=-0.01]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → oral_medicated (0.62) [Δhealthy=+0.00, Δpred=+0.01, Δoral=-0.02, Δins=+0.01]
#
#
# === Conclusion ===============================
#
# In this model,
# (Sleep=HIGH AND None=None) is unlikely to change the predicted T2DM severity
# (Severity: 0.121 → 0.127, Δ=+0.006).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (minimal) probability shifts, (no) class transitions, and (minimal) increase in severity.
# The subgroup size (n=328) provides (strong) evidential strength.
# Therefore, this hypothesis is **UNLIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High (top_conf=0.87, margin=0.80)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH Sleep AND None affect your likelihood of Type 2 Diabetes?) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# High sleep duration, typically more than 9 hours, was not directly linked to increased T2DM risk. Most research focuses on short sleep duration as a risk factor.
#
# The second variable showed:
# The absence of additional medical conditions was intended to isolate the effect of sleep duration, but no specific evidence was provided regarding its impact on T2DM risk.
#
# The combination of the variables showed:
# There is insufficient evidence to suggest that high sleep duration without other medical conditions significantly affects T2DM likelihood. The focus on short sleep duration as a risk factor is more prevalent in existing research.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Low
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH Sleep AND None) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# HIGH Sleep alone did not alter the predicted class, confidence, or any class probabilities.
#
# The second variable showed:
# None alone did not alter the predicted class, confidence, or any class probabilities.
#
# The combination of the variables showed:
# No change in predicted class, confidence, or class probabilities compared to the baseline.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: High
# ============================================
#
# ================================================================================
# ============================================
#
# 🌟Final Summary
#
# ============================================
#
# ⭐Hypothesis: Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?
#
# ============================================
#
# ⚫In Part A…
#
# Raw Part A report:
# Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect likelihood of T2DM category?Baseline prediction for average patient: healthy (conf=0.88)
#
# Effect of HIGH Glucose:
#   Predicted class: healthy (conf=0.88)
#   Delta to baseline: Low (0.00)
#   Among patients with HIGH Glucose (870 patients), the predicted class distribution is: healthy: 354/870 (40.7%), prediabetes: 245/870 (28.2%), oral_medicated: 208/870 (23.9%), insulin_dependent: 63/870 (7.2%).
#   Out of all predicted patients:
#     - healthy: 354/376 (94.1%) have HIGH Glucose
#     - prediabetes: 245/285 (86.0%) have HIGH Glucose
#     - oral_medicated: 208/317 (65.6%) have HIGH Glucose
#     - insulin_dependent: 63/99 (63.6%) have HIGH Glucose
#
# Effect of Retinal Vascular Occlusion ("Stroke:
#   Predicted class: prediabetes (conf=0.55)
#   Delta to baseline: High (-0.33)
#   Among patients with Retinal Vascular Occlusion ("Stroke (15 patients), the predicted class distribution is: insulin_dependent: 7/15 (46.7%), prediabetes: 3/15 (20.0%), healthy: 3/15 (20.0%), oral_medicated: 2/15 (13.3%).
#   Out of all predicted patients:
#     - healthy: 3/376 (0.8%) have Retinal Vascular Occlusion ("Stroke
#     - prediabetes: 3/285 (1.1%) have Retinal Vascular Occlusion ("Stroke
#     - oral_medicated: 2/317 (0.6%) have Retinal Vascular Occlusion ("Stroke
#     - insulin_dependent: 7/99 (7.1%) have Retinal Vascular Occlusion ("Stroke
#
# Combined effect of HIGH Glucose AND Retinal Vascular Occlusion ("Stroke:
#   Predicted class: prediabetes (conf=0.55)
#   Delta to baseline: High (-0.33)
#   Among patients with HIGH Glucose AND Retinal Vascular Occlusion ("Stroke (10 patients), the predicted class distribution is: insulin_dependent: 3/10 (30.0%), prediabetes: 3/10 (30.0%), healthy: 3/10 (30.0%), oral_medicated: 1/10 (10.0%).
#   Out of all predicted patients:
#     - healthy: 3/376 (0.8%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - prediabetes: 3/285 (1.1%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - oral_medicated: 1/317 (0.3%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#     - insulin_dependent: 3/99 (3.0%) have HIGH Glucose AND Retinal Vascular Occlusion ("Stroke
#
# Fake patients by TRUE subgroup (before → after applying question):
#   - Prototype TRUE healthy: healthy (0.88) → prediabetes (0.74) [Δhealthy=-0.67, Δpred=+0.65, Δoral=+0.01, Δins=+0.01]
#   - Prototype TRUE prediabetes: prediabetes (0.83) → prediabetes (0.90) [Δhealthy=-0.00, Δpred=+0.07, Δoral=-0.05, Δins=-0.02]
#   - Prototype TRUE oral_medicated: oral_medicated (0.69) → oral_medicated (0.47) [Δhealthy=-0.01, Δpred=+0.04, Δoral=-0.23, Δins=+0.19]
#   - Prototype TRUE insulin_dependent: oral_medicated (0.64) → insulin_dependent (0.50) [Δhealthy=-0.01, Δpred=-0.01, Δoral=-0.20, Δins=+0.22]
#
#
# === Conclusion ===============================
#
# In this model,
# (Glucose=HIGH AND Retinal Vascular Occlusion ("Stroke=None) very strongly increases the predicted T2DM severity
# (Severity: 0.121 → 0.624, Δ=+0.503).
#
# Both controlled model probes and real-patient subgroup analysis showed
# (substantial) probability shifts, (some) class transitions, and (large) increase in severity.
# The subgroup size (n=10) provides (weak) evidential strength.
# Therefore, this hypothesis is **LIKELY** to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low (top_conf=0.54, margin=0.17)
# Model reliability: Moderate (test_acc=0.67)
#
# ==============================================
# ============================================
#
# ⚫In Part B…
#
# In the OpenAI model,
#
# (Does HIGH Glucose AND Retinal Vascular Occlusion ("Stroke affect your likelihood of Type 2 Diabetes?) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# Persistent hyperglycemia is linked to diabetic retinopathy and retinal vascular occlusion through inflammation and endothelial dysfunction, indicating a connection to retinal diseases but not directly altering T2DM severity.
#
# The second variable showed:
# Retinal vascular occlusion is influenced by metabolic factors like insulin resistance and elevated homocysteine levels, which are risk factors for retinal diseases but do not directly impact T2DM severity.
#
# The combination of the variables showed:
# While both high glucose levels and retinal vascular occlusion are associated with retinal diseases, there is no clear evidence that their combination directly affects the likelihood or severity of T2DM.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: Low
#
# Model reliability: Moderate
# ============================================
#
# ⚫In Part C…
#
# In the OpenAI model,
#
# (HIGH Glucose AND Retinal Vascular Occlusion (“Stroke”)) is unlikely to change the predicted T2DM severity.
#
# The first variable showed:
# no detectable change in the predicted T2DM severity when added.
#
# The second variable showed:
# no detectable change in the predicted T2DM severity when added.
#
# The combination of the variables showed:
# no change in top‐predicted class or class probabilities.
#
# Therefore, this hypothesis is unlikely to meaningfully affect likelihood of T2DM.
#
# Prediction certainty: High
# Model reliability: Moderate
# ============================================

# %%
df_summary = pd.DataFrame(final_summary_rows)

# %%
pd.DataFrame({
    "full_summary":[row["full_summary"] for row in final_summary_rows]
}).to_csv("t2dm_full_summaries.csv", index=False)

pd.DataFrame(final_summary_rows).to_csv(
    "t2dm_hypothesis_summaries.csv",
    index=False
)

df_summary.to_csv("t2dm_hypothesis_summaries.csv", index=False)

# %% [markdown]
# # Overall Outcome

# %%
from openai import OpenAI

client = OpenAI()

def build_full_hypothesis_summary(
    hypothesis_text,
    part_a_text,
    part_a_summary,
    part_b_text,
    part_c_text,
    model="gpt-4o-mini"
):
    """
    Builds a final synthesis summary combining results from Part A, B, and C agents.
    """

    prompt = f"""
You are a scientific synthesis agent.

Your job is to combine the findings from three analysis agents
into ONE clear overall conclusion sentence.

The sentence should:
• Begin with "Overall, across the three agents..."
• Be 25–40 words
• Mention whether the evidence is consistent, mixed, weak, or strong
• Refer to the hypothesis
• Be written in a neutral scientific tone

Hypothesis:
{hypothesis_text}

Part A conclusion:
{part_a_summary}

Part B conclusion:
{part_b_text}

Part C conclusion:
{part_c_text}

Write ONE final synthesis sentence.
"""

    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=0.2
    )

    final_sentence = response.choices[0].message.content.strip()

    return final_sentence

# %%
import pandas as pd

final_summary_rows = []

n = min(
    len(results),
    len(PartA_conclusion_results),
    len(all_final_outputs),
    len(pipeline_results)
)

for i in range(n):
    r = results[i]

    hypothesis_text = clean_hypothesis_text(r)

    part_a_text = r["report"]
    part_a_summary = PartA_conclusion_results[i]["conclusion"]
    part_b_text = all_final_outputs[i]["final_output"]
    part_c_text = pipeline_results[i]["result"]

    full_summary = build_full_hypothesis_summary(
        hypothesis_text=hypothesis_text,
        part_a_text=part_a_text,
        part_a_summary=part_a_summary,
        part_b_text=part_b_text,
        part_c_text=part_c_text
    )

    print("\n" + "=" * 80)
    print(full_summary)

    final_summary_rows.append({
        "question_num": i + 1,
        "hypothesis": hypothesis_text,
        "part_a_summary": part_a_summary,
        "part_b_summary": part_b_text,
        "part_c_summary": part_c_text,
        "full_summary": full_summary
    })

final_summary_df = pd.DataFrame(final_summary_rows)
print(final_summary_df.shape)
# Out:
# ================================================================================
# Overall, across the three agents, the evidence is consistent in suggesting that the combination of high PR interval and high cholesterol is unlikely to meaningfully affect the likelihood of Type 2 Diabetes, thus not supporting the hypothesis.
#
# ================================================================================
# Overall, across the three agents, the evidence regarding the hypothesis that Heart Attack and Age-Related Macular Degeneration affect the likelihood of Type 2 Diabetes is mixed, with some suggesting a likely impact while others indicate insufficient support for a meaningful effect.
#
# ================================================================================
# Overall, across the three agents, the evidence regarding the hypothesis that HIGH Blood Glucose AND None affect the likelihood of Type 2 Diabetes is mixed, with two agents suggesting a likely impact on severity while one indicates no meaningful change.
#
# ================================================================================
# Overall, across the three agents, the evidence is consistent in suggesting that the hypothesis that HIGH Sleep AND None significantly affects the likelihood of Type 2 Diabetes is unlikely to be supported, given minimal changes in predicted severity and class probabilities.
#
# ================================================================================
# Overall, across the three agents, the evidence is mixed regarding the hypothesis that high glucose and retinal vascular occlusion affect the likelihood of type 2 diabetes, with findings ranging from likely meaningful effects to no significant impact on T2DM severity.
# (5, 6)

# %% [markdown]
# # Evaluation

# %%
def evaluate_hypothesis_output(output_text, reference_text=None):
    results = {}

    # 1. Correctness (LLM self-check or judge)
    results["correctness"] = evaluate_correctness_llm(output_text)

    # 2. LLM-as-a-judge
    results["llm_judge"] = llm_judge_score(output_text, reference_text)

    # 3. Text metrics (if reference exists)
    if reference_text:
        results["rouge2"] = compute_rouge2(output_text, reference_text)
        results["bleu"] = compute_bleu(output_text, reference_text)

    # 4. Clinical / domain metrics
    results["clinical_precision"] = evaluate_medical_precision(output_text)

    return results

# %%
def evaluate_correctness_llm(text):
    prompt = f"""
    Is the following medical statement factually correct?
    Answer YES or NO and explain briefly.

    {text}
    """
    return call_llm(prompt)

# %%
def llm_judge_score(prediction, reference):
    prompt = f"""
    You are a clinical expert.

    Compare the following:

    Prediction:
    {prediction}

    Reference (gold standard):
    {reference}

    Score from 0 to 1 based on:
    - clinical correctness
    - reasoning quality
    - safety

    Output JSON with score and explanation.
    """
    return call_llm(prompt)

# %%
from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu

def compute_rouge2(pred, ref):
    scorer = rouge_scorer.RougeScorer(['rouge2'], use_stemmer=True)
    return scorer.score(ref, pred)['rouge2'].fmeasure

def compute_bleu(pred, ref):
    return sentence_bleu([ref.split()], pred.split())

# %%
def evaluate_medical_precision(text):
    keywords = ["glucose", "insulin", "diabetes", "HbA1c"]
    hits = sum(1 for k in keywords if k.lower() in text.lower())
    return hits / len(keywords)

# %%
from openai import OpenAI

client = OpenAI()

def call_llm(prompt):
    response = client.chat.completions.create(
        model="gpt-4o-mini",   # or whatever you're using
        messages=[
            {"role": "system", "content": "You are a clinical reasoning expert."},
            {"role": "user", "content": prompt}
        ],
        temperature=0
    )
    return response.choices[0].message.content

# %%
n = min(
    len(results),
    len(PartA_conclusion_results),
    len(all_final_outputs),
    len(pipeline_results)
)

for i in range(n):
    r = results[i]

    hypothesis_text = clean_hypothesis_text(r)
    part_a_text = r["report"]
    part_a_summary = PartA_conclusion_results[i]["conclusion"]
    part_b_text = all_final_outputs[i]["final_output"]
    part_c_text = pipeline_results[i]["result"]

    full_summary = build_full_hypothesis_summary(
        hypothesis_text=hypothesis_text,
        part_a_text=part_a_text,
        part_a_summary=part_a_summary,
        part_b_text=part_b_text,
        part_c_text=part_c_text
    )

    eval_results = evaluate_hypothesis_output(
        output_text=full_summary,
        reference_text=None
    )

    print(full_summary)
    print("\n📊 Evaluation:", eval_results)

# %%
import pandas as pd

rows = []

n = min(
    len(results),
    len(PartA_conclusion_results),
    len(all_final_outputs),
    len(pipeline_results)
)

for i in range(n):
    r = results[i]

    hypothesis_text = clean_hypothesis_text(r)

    part_a_text = r["report"]
    part_a_summary = PartA_conclusion_results[i]["conclusion"]
    part_b_text = all_final_outputs[i]["final_output"]
    part_c_text = pipeline_results[i]["result"]

    full_summary = build_full_hypothesis_summary(
        hypothesis_text=hypothesis_text,
        part_a_text=part_a_text,
        part_a_summary=part_a_summary,
        part_b_text=part_b_text,
        part_c_text=part_c_text
    )

    eval_results = evaluate_hypothesis_output(
        output_text=full_summary,
        reference_text=None
    )

    rows.append({
        "hypothesis": hypothesis_text,
        "output": full_summary,
        **eval_results
    })

df_eval = pd.DataFrame(rows)
df_eval.to_csv("evaluation_results.csv", index=False)

print("✅ Saved to evaluation_results.csv")
